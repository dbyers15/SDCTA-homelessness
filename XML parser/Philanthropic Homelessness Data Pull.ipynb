# %%
# import packages
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET
import requests
from bs4 import BeautifulSoup
import time
import lxml
import re
import string

# %% [markdown]
# # Parsing XML Files from ProPublica

# %% [markdown]
# ## Background

# %% [markdown]
# Within San Diego County, there is an increasing homelessness crisis. The funding to help take the next steps towards ending this crisis comes from the government, county funding, city funding, and funding from nonprofit organizations. Each nonprofit organization has a service to aid the homeless, yet a lot of money has been put towards the issue and there hasn't been much progress.
#
# In order to fully understand how much money is put towards homelessness within San Diego County, we are creating a dataset that includes all four sources of funding. The overarching goal of this project and dataset is to see how much money is put towards homelessness services within San Diego County with the intent that eventually we can get a better idea of how much money it would take to bring a single person out of homelessness.
#
# For this branch of this homelessness project, compiling the philanthropic data will help identify how much money is put towards homelessness services in San Diego and the sources of funding for each nonprofit organization.
#
# The *Philanthropic Homelessness Data Pull* is a script that pulls data from ProPublica, a tax site that uploads tax returns for nonprofit organizations, searchable through the organization's unique EIN. Compiling this data together, we can get the total philanthropic dollars for homelessness within recent years given that we have the full EIN list.

# %% [markdown]
# ### Maintaining Data

# %% [markdown]
# We have code that pulls the 990 XML files for each provider from ProPublica. We have a list of provider’s EIN numbers that our script pulls from. This list is based on the providers that we have identified from the city contracts and county contracts. There are organizations that perform homelessness services but do not take government dollars. Some of these organizations are not contained and should be added once they are identified.
#
# It is important to note that the parser code we have does it through the 990 XML files under a tax year on ProPublica, but some of the earlier years (like 2014 or 2015) for some EINs don’t have an XML file, so there are some years that has data that’s not collected via the parser code. To correct this, the manual-pull dataset was used to fill in the data that was missing and was manually checked for any data that needed to be added. You can just use the most up-to-date dataset and run through the code function to do this.

# %% [markdown]
# ### Code Upkeep

# %% [markdown]
# The Master EIN List on Google Sheets should be continuously updated with new nonprofits found and updated within the jupyter or GitHub folder. Be sure you're using the updated list for the code.
#
# The most recent dataset should be used under the 'Getting Manual Pull Rows that aren't included in the Scraped Data' section of the code. This is important because there isn't an XML file for some of the older years and that data would be missed without the merging of the dataset within that code.
#
# The csv files can be overwritten as it's moreso a way to keep progress without recalling the grabber() function or messing with the data, but keep the final 'Phil Dataset.csv', 'Phil Dataset - Analysis.csv', and the csv sheets that were pulled from Google Sheets.

# %% [markdown]
# ### Methods

# %% [markdown]
# `scrape_website(url, attempts=0)`
# - Takes a URL and returns the response object if successful. Retries three times on failure
#
# `info_grabber(fp, url=True)`
# - Takes the URL/filepath of an XML file. The `url` parameter indicates whether the given filepath is a URL or local
# - Returns a dictionary of the row information for section VIII (along with a couple other columns)
# - Older (prior to 2013) XML files have different tags and thus can't be read. Results in a row of all zeroes and `'Not Found'` in the `ba` column
# - Of successfully scraped columns, has ~1.5% error rate for rows (0.13% of cells are inaccurate), only in the `Fundraising Events` column due to inconsistent labeling in XMLs
#     - This error rate is lower than the human error rate
# - In 2013, they had a different way of tagging zip codes, so all 2013 zips will be 0
#
# `contact_grabber(fp, url=True)`
# - Returns a dataframe of each contact in the 990 form, according to section VII
# - Incomplete and edge cases aren't tested fully, as we didn't need the function.
#
# `get_xmls(ein)`
# - Takes the EIN of a company and returns a list of the URLs for each XML file that is linked on the ProPublica page for that given company
#
# `grabber(eins, verbose=False, clean=False)`
# - Takes a list of EINs and uses `get_xmls()` to find each XML file, then uses `info_grabber()` to scrape each XML for the relevant information.
# - Returns a pandas DataFrame, doesn't automatically save as csv.
# - Takes around 22 minutes on my laptop for 71 businesses
# - The `clean` parameter automatically cleans the dataframe by removing empty rows
#
# `find_errors(info)`
# - Data columns are supposed to add up to the total, if it doesn't this method will find it
# - Takes a dataframe of 990 rows from `grabber` and returns a tuple of incides that didn't properly grab all of the data
#     - Preferably indiced on `EIN_YEAR`
#
# ##### Helper Methods
# `standardize_text(text)`
# - Removes any unwanted punction and turns inputted text to upper-case to standardize it. Used for the dataframes.
#
# `replace_corrected_data_and_standardize(df1, df2, concat=False)`
# - Used for replacing the information in 'df2' that appears in 'df1' so that the new corrected information in 'df2' is present in the full dataframe 'df1'.
#     - This is used after the double filtering of the errors to replace the incorrect information with the corrected information.
# - Standardizes the text in both dataframes for accurate replacement.
# - The concat input can be set to true to standardize and combine dataframes to add new information from 'df2' instead of just replacing.
#     - This was added to add any missing information that was on the 990 manual pull but not the generated dataset.
#
# `distribute_values_fiscal_year(row)`
# - Expand fiscal years into months based on 'Tax End Date' column and divides columns with dollar values by the number of months
#     - apply to df by doing expanded_data_fiscal_year = df.apply(distribute_values_fiscal_year, axis=1)
#     - expanded_data_fiscal_year =  pd.DataFrame([item for sublist in expanded_data_fiscal_year for item in sublist])

# %% [markdown]
# #### XML Parsing methods

# %% [markdown]
# #### `scrape_website`

# %%
def scrape_website(url, attempts=0):
    '''
    Takes a URL and returns the response object if successful. Retries three times on failure
    '''
    # Send GET request to the website
    response = requests.get(url)
    time.sleep(1)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        if attempts > 0:
            print('Success')
        return response
    elif attempts < 3:
        print("Error:", response.status_code, "Trying again.")
        time.sleep(1)
        return scrape_website(url, attempts + 1)
    else:
        # Handle the request error
        print("Error: ", response.status_code, 'Failed on:', url)
        return None

# %% [markdown]
# #### `info_grabber`

# %%
def info_grabber(fp, url=True, errors=False):
    ''' 
    - Takes the URL/filepath of an XML file. The url parameter indicates whether the given filepath is a URL or local
    - Returns a dictionary of the row information for section VIII (along with a couple other columns)
    - Older (prior to 2013) XML files have different tags and thus can't be read. Results in a row of all zeroes and 'Not Found' in the ba column
    - Of successfully scraped columns, has ~1.5% error rate for rows (0.13% of cells are inaccurate), only in the Fundraising Events column due to inconsistent labeling in XMLs
    - This error rate is lower than the human error rate
    - In 2013, they had a different way of tagging zip codes, so all 2013 zips will be 0
    '''
    # Use scrape_website(url) to get XML or read file
    if url:
        xml = scrape_website(fp)
        xml.encoding = 'UTF-8'
        xml = xml.text.strip()
    else:
        try:
            with open(fp, 'r') as file:
                xml = file.read()
        except FileNotFoundError:
            print(f"File not found: {fp}")
            return dict()
    if xml is None:
        return dict()
    
    soup = BeautifulSoup(xml, 'xml')
    
    # Assigning dict values to tags scraped from pulled XML file
    row = dict()
    row['ba'] = soup.find('BusinessName')
    row['EIN'] = soup.find('EIN')
    row['Tax Year'] = soup.find('TaxPeriodBeginDt')
    row['Tax End Date'] = soup.find('TaxPeriodEndDt')
    row['Location (Zipcode)'] = soup.find('USAddress')
    row['Federate Campaigns'] = soup.find('FederatedCampaignsAmt')
    row['Membership Dues'] = soup.find('MembershipDuesAmt')
    row['Fundraising Events'] = soup.find('ContriRptFundraisingEventAmt')
    
    row['Related Organizations'] = soup.find('RelatedOrganizationsAmt')
    row['Government Grants'] = soup.find('GovernmentGrantsAmt')
    row['All Other Contributions'] = soup.find('AllOtherContributionsAmt')
    row['Noncash Contributions'] = soup.find('NoncashContributionsAmt')
    row['Total'] = soup.find('TotalContributionsAmt')

    # tries different tag
    if row['Location (Zipcode)'] is not None:
        row['Location (Zipcode)'] = row['Location (Zipcode)'].find('ZIPCd')
    else:
        row['Location (Zipcode)'] = None

    # organizes dict properly
    row = dict(map(lambda item: (item[0], item[1].text if item[1] is not None else None), row.items()))

    if row['ba'] is not None:
        row['ba'] = row['ba'].strip()
    else:
        row['ba'] = 'Not found'
    # correcting 'Tax Year' format
    if row['Tax Year'] is not None:
        row['Tax Year'] = pd.Timestamp(row['Tax Year']).year
    else:
        row['Tax Year'] = np.nan
    # correcting 'Tax End Date' format
    if row['Tax End Date'] is not None:
        row['Tax End Date'] = pd.to_datetime(row['Tax End Date']).strftime("%m-%d-%Y")
    else:
        row['Tax End Date'] = np.nan
    
    # use errors=True on EINs that returned incorrect sums on the first grabber() call
    # calculates sum with new fundraising tag to see if it fixes the errors
    if errors:
        sumKeys = ['Federate Campaigns', 'Membership Dues', 'Related Organizations', 'Government Grants', 'All Other Contributions']
        sumAmt = sum(float(row[key]) for key in sumKeys if key in row and row[key] is not None)
        fundAmt_element = soup.find('FundraisingAmt')
        fundAmt = int(fundAmt_element.text) if fundAmt_element is not None else 0
        sumAmt += fundAmt

        # See if the other fundraising tag fixes error and if it does, then replace it
        if sumAmt is None or row['Total'] is None:
            pass
        elif int(sumAmt) == int(row['Total']):
            row['Fundraising Events'] = fundAmt
        else:
            pass
    # cleaning format
    row = dict(map(lambda item: (item[0], item[1] if item[1] is not None else 0), row.items()))

    return row

# %% [markdown]
# #### `contact_grabber`

# %%
def contact_grabber(fp, url=True):
    '''
    Returns a dataframe of each contact in the 990 form, according to section VII
    Incomplete and edge cases aren't tested fully, as we didn't need the function.

    :param fp: filepath of the xml file
    :param url: Whether the fp is a url or not. Default = True
    '''

    # If 'url' is True, assume 'fp' is a URL and call a function 'scrape_website' to retrieve the XML data.
    # If 'url' is False, assume 'fp' is a file path and try to fetch the file contents using 'requests'.
    if url:
        xml = scrape_website(fp)
    else:
        xml = requests.get(fp)

    # If 'xml' is None, return an empty dictionary and exit the function.
    if xml is None:
        return dict()

    # Set the encoding of 'xml' to 'UTF-8' and strip any leading/trailing whitespace.
    xml.encoding = 'UTF-8'
    xml = xml.text.strip()

    # Parse the 'xml' data using BeautifulSoup with an 'xml' parser.
    soup = BeautifulSoup(xml, 'xml')

    # Find all elements with the tag 'Form990PartVIISectionAGrp' in the parsed XML.
    people = soup.find_all('Form990PartVIISectionAGrp')

    # Create lists 'names' and 'titles' containing text from 'PersonNm' and 'TitleTxt' elements, respectively,
    # for each 'Form990PartVIISectionAGrp' element that has these sub-elements.
    names = [x.find('PersonNm').text for x in people if x.find('PersonNm') is not None]
    titles = [x.find('TitleTxt').text for x in people if x.find('TitleTxt') is not None]

    # Try to find the organization's name by looking for the 'BusinessName' element.
    # If not found, set 'organization' to 'Not found' for each contact.
    try:
        organization = [soup.find('BusinessName').text.strip()] * len(names)
    except AttributeError:
        organization = ['Not found'] * len(names)

    # Try to find the year by parsing the 'TaxPeriodBeginDt' element and extracting the year.
    # If not found, set 'year' to 0 for each contact.
    try:
        year = [pd.Timestamp(soup.find('TaxPeriodBeginDt').text).year] * len(names)
    except AttributeError:
        year = [0] * len(names)

    # Return a Pandas DataFrame containing the extracted data: organization, year, names, and titles.
    return pd.DataFrame({'organization': organization, 'year': year, 'names': names, 'titles': titles})

# %% [markdown]
# #### `get_xmls`

# %%
def get_xmls(ein):
    '''
    Return a list of xml urls from ProRepublica based on an organization's EIN

    :param ein: Employer Identification number as String or Int
    '''

    # Create a URL using the given 'ein' to fetch information from ProPublica's website.
    url = f'https://projects.propublica.org/nonprofits/organizations/{ein}'

    # Call a function 'scrape_website' to retrieve the HTML content of the URL.
    html = scrape_website(url)

    # If 'html' is None (indicating an error or empty response), return an empty list.
    if html is None:
        return []

    # Parse the HTML content using BeautifulSoup.
    soup = BeautifulSoup(html.text)

    # Find all anchor elements ('a') with the class 'action xml' in the parsed HTML.
    links = soup.find_all('a', class_='action xml')

    # Define the base URL for constructing the complete XML URLs.
    base_url = 'https://projects.propublica.org'

    # Extract XML URLs for 990 forms from the found anchor elements.
    # The condition 'if x.text == '990'' filters for links with the text '990'.
    urls = [base_url + x.get('href') for x in links if x.text == '990']

    # Alternatively, you can achieve the same result using a regular expression to filter links.
    # This section replaces the previous one.
    urls = [x for x in soup.find_all(class_='action xml') if re.search(r'990\b', x.text)]
    urls = [base_url + x.get('href') if x.name == 'a' else base_url + x.select_one('select.action.xml option[data-href]').get('data-href') for x in urls]

    # Return the list of extracted XML URLs.
    return urls

# %% [markdown]
# #### For errors

# %% [markdown]
# *use `grabber(errors = True)` to correct errors after calling find_errors(df)*

# %% [markdown]
# #### `grabber`

# %%
def grabber(eins, verbose=False, clean=False, errors=False):
    '''
    - Takes a list of EINs and uses get_xmls() to find each XML file, then uses info_grabber() to scrape each XML for the relevant information.
    - Returns a pandas DataFrame, doesn't automatically save as csv.
    - Takes around 22 minutes on my laptop for 71 businesses
    - The clean parameter automatically cleans the dataframe by removing empty rows
    '''

    # Check if 'eins' is of type int, and if so, convert it to a list containing that int.
    if type(eins) == int:
        eins = [eins]

    # Create an empty list 'data' to store the scraped data.
    data = []

    # Initialize an 'overall_index' variable to keep track of the overall progress.
    overall_index = 0

    # Loop through each EIN in the 'eins' list.
    for index, ein in enumerate(eins):
        print(str(index) + (' / ') + str(len(eins)))

        # Call the 'get_xmls' function to retrieve XML URLs for the current EIN.
        xmls = get_xmls(ein)

        # Loop through each XML URL.
        for xml in xmls:
            if verbose:
                print(f'{overall_index} {xml}')

            # If 'errors' is True, call the grabber() function with 'errors=True'.
            # This is used when double filtering errors already found by calling 'find_errors(df)'.
            if errors:
                data.append(info_grabber(xml, errors=True))
            else:
                data.append(info_grabber(xml))

            # Increment the 'overall_index' to keep track of progress across all EINs.
            overall_index += 1

    # Print the total number of EINs processed.
    print(str(len(eins)) + (' / ') + str(len(eins)))

    # Create a DataFrame 'info' containing the collected data.
    info = pd.DataFrame(data)

    # If 'clean' is False, return the DataFrame 'info' as is.
    if not clean:
        return info

    # If 'clean' is True, perform data cleaning operations on the DataFrame 'info'.
    # Remove rows with missing values (NaN), convert certain columns to integers, and create an 'EIN_YEAR' column.
    no_error = info.dropna().reset_index(drop=True)
    no_error.loc[:, 'EIN':'Total'] = no_error.loc[:, 'EIN':'Total'].astype(int)
    no_error.loc[:, 'EIN_YEAR'] = no_error['EIN'].astype(str) + '_' + no_error['Tax Year'].astype(str)
    no_error = no_error.set_index('EIN_YEAR')

    # Return the cleaned DataFrame 'no_error'.
    return no_error

# %% [markdown]
# #### `find_errors`

# %%
def find_errors(info):
    '''
    Takes a dataframe of 990 rows and returns a tuple of the indices where it failed to grab the data properly

    :param info: The dataframe of 990 rows
    '''
    # Calculate a Boolean Series 'accurate' by checking if the sum of certain columns equals the 'Total' column.
    accurate = info[['Federate Campaigns', 'Membership Dues', 'Fundraising Events', 'Related Organizations', 'Government Grants', 'All Other Contributions']].sum(axis=1) == info['Total']
    # Return a tuple containing the indices (row numbers) where 'accurate' is False.
    return tuple(accurate[~accurate].index)

# %% [markdown]
# #### Standardize text in dataframe

# %% [markdown]
# #### `standardize_text`

# %%
def standardize_text(text):
    '''
    Removes any unwanted punction and turns inputted text to upper-case to standardize it. Used for the dataframes.
    '''
    return re.sub(r'[{}\'‘’]'.format(string.punctuation), '', text).upper().strip().replace('\n',' ')

# %% [markdown]
# #### Update dataframe with corrections from new dataframe

# %% [markdown]
# Use after `find_errors(df)` and output from `grabber(errors=True)`

# %% [markdown]
# #### `replace_corrected_data_and_standardize`

# %%
def replace_corrected_data_and_standardize(df1, df2, concat=False):
    '''
    Expand fiscal years into months based on 'Tax End Date' column and divides columns with dollar values by the number of months
    - apply to df by doing expanded_data_fiscal_year = df.apply(distribute_values_fiscal_year, axis=1)
      expanded_data_fiscal_year = pd.DataFrame([item for sublist in expanded_data_fiscal_year for item in sublist])
    '''

    # Define a list of columns that should be standardized (excluding 'Tax End Date').
    to_std = ['Organization Name', 'EIN', 'Tax Year', 'Location (Zipcode)', 'Federate Campaigns', 'Membership Dues',
              'Fundraising Events', 'Related Organizations', 'Government Grants', 'All Other Contributions',
              'Noncash Contributions', 'Total']

    # Reset the index of both input DataFrames 'df1' and 'df2'.
    df1 = df1.reset_index()
    df2 = df2.reset_index()

    # Standardize text values in the selected columns for both 'df1' and 'df2'.
    for col in to_std:
        if col != 'Tax End Date':
            df1[col] = df1[col].apply(lambda x: standardize_text(x) if isinstance(x, str) else x)
            df2[col] = df2[col].apply(lambda x: standardize_text(x) if isinstance(x, str) else x)

    # Replace errors in 'df1' with corrected information from 'df2' based on matching EIN_YEAR values.
    for index_value, corrected_row in df2.iterrows():
        ein_year = corrected_row['EIN_YEAR']
        matching_rows = df1['EIN_YEAR'] == ein_year
        for column in df1.columns:
            df1.loc[matching_rows, column] = corrected_row[column]

    # If 'concat' is False, assign 'df1' to 'combined_df'. Otherwise, concatenate 'df1' and 'df2'.
    if not concat:
        combined_df = df1
    else:
        combined_df = pd.concat([df1, df2])

    # Calculate a new column 'Philanthropic_Total' by subtracting 'Government Grants' from 'Total'.
    combined_df['Philanthropic_Total'] = combined_df['Total'] - combined_df['Government Grants']

    # Return the combined DataFrame 'combined_df'.
    return combined_df

# %% [markdown]
# #### Expand by months

# %% [markdown]
# #### `distribute_values_fiscal_year`

# %%
def distribute_values_fiscal_year(row):
    # Calculate the start and end dates of the fiscal year based on the 'Tax End Date' column.
    fiscal_year_start_date = pd.Timestamp(year=row['Tax End Date'].year - 1, month=row['Tax End Date'].month, day=row['Tax End Date'].day) + pd.DateOffset(days=1)
    fiscal_year_end_date = fiscal_year_start_date + pd.DateOffset(years=1, days=-1)

    # Calculate the number of months in the fiscal year.
    num_months = (fiscal_year_end_date.year - fiscal_year_start_date.year) * 12 + fiscal_year_end_date.month - fiscal_year_start_date.month + 1

    # Calculate the values to distribute (including the last two columns) by dividing by the number of months.
    values_to_distribute = row[7:] / num_months

    # Generate a date range for each month within the fiscal year.
    date_range = pd.date_range(start=fiscal_year_start_date, end=fiscal_year_end_date, freq='M')

    # Create a list 'new_rows' to store the new rows for each month.
    new_rows = []

    # Iterate over the date range and create a new row for each month.
    for date in date_range:
        new_row = row.copy()
        
        # Update the 'Tax End Date' column with the current date in 'MM-DD-YYYY' format.
        new_row['Tax End Date'] = date.strftime('%m-%d-%Y')
        
        # Update all columns from the 7th column onwards with the values to distribute.
        new_row[7:] = values_to_distribute
        
        # Append the new row to the 'new_rows' list.
        new_rows.append(new_row)

    # Return the list of new rows, effectively expanding the fiscal year data into monthly data.
    return new_rows

# %% [markdown]
# ### Using the `grabber()` method

# %% [markdown]
# `grabber()` takes a list of EINs. This was curated from the old "990 Manual Pull" spreadsheet by pasting and splitting the entire `EIN` column and putting it into a set.

# %%
all_eins = '''113723093
113723093
204374795
237161267
237279074
237334012
261712580
261712580
263405689
270447059
270447059
270865318
270865318
272917644
273390797
330006089
330008269
330008269
330122462
330210280
330215585
330215585
330217339
330317950
330433314
330492304
330492304
330496092
330497515
330553621
330553621
330553621
330602842
330602842
330618893
330623634
330902617
330902617
331029843
331029843
331146733
331146733
465055513
465055513
550806460
562613191
571162424
571162424
571162424
571214920
571214920
571214920
821946283
822363154
931008369
941676390
942358632
942358632
951644024
951648184
951869806
951874073
951944230
951945256
952039198
952039198
952111196
952157559
952157559
952213995
952422704
952422704
952457354
952457354
952648050
952653869
952693142
952693142
952794253
952794253
952794253
952833205
952833205
952833205
952850121
952877102
952880426
952880426
952949636
953031682
953138268
953138268
953140767
953140767
953244085
953244085
953248148
953248148
953302967
953302967
953315571
953368020
953497926
953649525
953649525
953750738
953782164
953782164
953798088
953837714
953837714
953950196
953950196
953950196
956379598
204374795
311750839
330553704
330498557
880279721
330352148
330352148
951729734
237332048'''

# %%
eins = list(set(all_eins.split()))

# %% [markdown]
# <b>Warning</b>: `grabber()` takes a long time. The following cell will take about 20 minutes.

# %% [markdown]
# # 990 - Manual Pull Testing

# %%
info990 = grabber(eins, verbose=True)
# Out:
# 0 / 83
# 0 https://projects.propublica.org/nonprofits/download-xml?object_id=202341239349300104
# 1 https://projects.propublica.org/nonprofits/download-xml?object_id=202200889349300050
# 2 https://projects.propublica.org/nonprofits/download-xml?object_id=202110429349301336
# 3 https://projects.propublica.org/nonprofits/download-xml?object_id=202030799349300613
# 4 https://projects.propublica.org/nonprofits/download-xml?object_id=201900109349301975
# 5 https://projects.propublica.org/nonprofits/download-xml?object_id=201733489349300023
# 6 https://projects.propublica.org/nonprofits/download-xml?object_id=201740139349301144
# 7 https://projects.propublica.org/nonprofits/download-xml?object_id=201600409349301435
# 1 / 83
# 8 https://projects.propublica.org/nonprofits/download-xml?object_id=202203159349307235
# 9 https://projects.propublica.org/nonprofits/download-xml?object_id=202113199349316051
# 2 / 83
# 10 https://projects.propublica.org/nonprofits/download-xml?object_id=202301359349318435
# 11 https://projects.propublica.org/nonprofits/download-xml?object_id=202211369349314251
# 12 https://projects.propublica.org/nonprofits/download-xml?object_id=202121129349301542
# 13 https://projects.propublica.org/nonprofits/download-xml?object_id=202021229349301037
# 14 https://projects.propublica.org/nonprofits/download-xml?object_id=201910589349300616
# 15 https://projects.propublica.org/nonprofits/download-xml?object_id=201743199349318604
# 16 https://projects.propublica.org/nonprofits/download-xml?object_id=201801389349300430
# 17 https://projects.propublica.org/nonprofits/download-xml?object_id=201641379349309289
# 18 https://projects.propublica.org/nonprofits/download-xml?object_id=201511359349306771
# 19 https://projects.propublica.org/nonprofits/download-xml?object_id=201400989349300535
# 20 https://projects.propublica.org/nonprofits/download-xml?object_id=201300719349300625
# 21 https://projects.propublica.org/nonprofits/download-xml?object_id=201123229349300807
# 3 / 83
# 22 https://projects.propublica.org/nonprofits/download-xml?object_id=202231329349307723
# 23 https://projects.propublica.org/nonprofits/download-xml?object_id=202002939349300685
# 24 https://projects.propublica.org/nonprofits/download-xml?object_id=202031779349300148
# 25 https://projects.propublica.org/nonprofits/download-xml?object_id=201901339349305115
# 26 https://projects.propublica.org/nonprofits/download-xml?object_id=201703389349300415
# 27 https://projects.propublica.org/nonprofits/download-xml?object_id=201710629349300321
# 28 https://projects.propublica.org/nonprofits/download-xml?object_id=201600129349300520
# 4 / 83
# 29 https://projects.propublica.org/nonprofits/download-xml?object_id=202242219349300434
# 30 https://projects.propublica.org/nonprofits/download-xml?object_id=202100399349301120
# 31 https://projects.propublica.org/nonprofits/download-xml?object_id=202031209349301218
# 32 https://projects.propublica.org/nonprofits/download-xml?object_id=201920439349301277
# 33 https://projects.propublica.org/nonprofits/download-xml?object_id=201800309349300115
# 34 https://projects.propublica.org/nonprofits/download-xml?object_id=201613559349300771
# 35 https://projects.propublica.org/nonprofits/download-xml?object_id=201630429349302213
# 5 / 83
# 36 https://projects.propublica.org/nonprofits/download-xml?object_id=202232219349301203
# 37 https://projects.propublica.org/nonprofits/download-xml?object_id=202141049349301424
# 38 https://projects.propublica.org/nonprofits/download-xml?object_id=202020739349301002
# 39 https://projects.propublica.org/nonprofits/download-xml?object_id=201920849349301507
# 40 https://projects.propublica.org/nonprofits/download-xml?object_id=201821219349301477
# 41 https://projects.propublica.org/nonprofits/download-xml?object_id=201731799349300028
# 42 https://projects.propublica.org/nonprofits/download-xml?object_id=201611359349301251
# 43 https://projects.propublica.org/nonprofits/download-xml?object_id=201541949349300819
# 6 / 83
# 44 https://projects.propublica.org/nonprofits/download-xml?object_id=202310589349301711
# 45 https://projects.propublica.org/nonprofits/download-xml?object_id=202240459349300229
# 46 https://projects.propublica.org/nonprofits/download-xml?object_id=202100349349301560
# 47 https://projects.propublica.org/nonprofits/download-xml?object_id=202010449349300941
# 48 https://projects.propublica.org/nonprofits/download-xml?object_id=201920429349301232
# 49 https://projects.propublica.org/nonprofits/download-xml?object_id=201840519349301264
# 50 https://projects.propublica.org/nonprofits/download-xml?object_id=201700879349300610
# 51 https://projects.propublica.org/nonprofits/download-xml?object_id=201612219349301556
# 52 https://projects.propublica.org/nonprofits/download-xml?object_id=201531339349305568
# 53 https://projects.propublica.org/nonprofits/download-xml?object_id=201421219349301317
# 54 https://projects.propublica.org/nonprofits/download-xml?object_id=201310469349302701
# 55 https://projects.propublica.org/nonprofits/download-xml?object_id=201202089349301000
# 56 https://projects.propublica.org/nonprofits/download-xml?object_id=201122109349300347
# 7 / 83
# 57 https://projects.propublica.org/nonprofits/download-xml?object_id=202340559349301554
# 58 https://projects.propublica.org/nonprofits/download-xml?object_id=202200559349301665
# 59 https://projects.propublica.org/nonprofits/download-xml?object_id=202120499349300842
# 60 https://projects.propublica.org/nonprofits/download-xml?object_id=201933129349303383
# 61 https://projects.propublica.org/nonprofits/download-xml?object_id=201822299349300642
# 62 https://projects.propublica.org/nonprofits/download-xml?object_id=201712419349300236
# 63 https://projects.propublica.org/nonprofits/download-xml?object_id=201632429349300913
# 64 https://projects.propublica.org/nonprofits/download-xml?object_id=201532179349301303
# 65 https://projects.propublica.org/nonprofits/download-xml?object_id=201442339349300719
# 66 https://projects.propublica.org/nonprofits/download-xml?object_id=201332269349304258
# 67 https://projects.propublica.org/nonprofits/download-xml?object_id=201231509349300523
# 68 https://projects.propublica.org/nonprofits/download-xml?object_id=201112169349300831
# 8 / 83
# 69 https://projects.propublica.org/nonprofits/download-xml?object_id=202310909349300301
# 70 https://projects.propublica.org/nonprofits/download-xml?object_id=202220849349300607
# 71 https://projects.propublica.org/nonprofits/download-xml?object_id=202131249349300508
# 9 / 83
# 72 https://projects.propublica.org/nonprofits/download-xml?object_id=202243489349301124
# 73 https://projects.propublica.org/nonprofits/download-xml?object_id=202143269349301334
# 74 https://projects.propublica.org/nonprofits/download-xml?object_id=202013579349300631
# 75 https://projects.propublica.org/nonprofits/download-xml?object_id=201923549349300542
# 76 https://projects.propublica.org/nonprofits/download-xml?object_id=201910649349300026
# 77 https://projects.propublica.org/nonprofits/download-xml?object_id=201743499349301374
# 78 https://projects.propublica.org/nonprofits/download-xml?object_id=201603209349309550
# 79 https://projects.propublica.org/nonprofits/download-xml?object_id=201503179349306455
# 80 https://projects.propublica.org/nonprofits/download-xml?object_id=201413189349309751
# 81 https://projects.propublica.org/nonprofits/download-xml?object_id=201302949349300725
# 82 https://projects.propublica.org/nonprofits/download-xml?object_id=201223259349300812
# 83 https://projects.propublica.org/nonprofits/download-xml?object_id=201133439349300703
# 84 https://projects.propublica.org/nonprofits/download-xml?object_id=201100329349301010
# 10 / 83
# 85 https://projects.propublica.org/nonprofits/download-xml?object_id=202311239349302956
# 86 https://projects.propublica.org/nonprofits/download-xml?object_id=202201309349302825
# 87 https://projects.propublica.org/nonprofits/download-xml?object_id=202131269349301773
# 88 https://projects.propublica.org/nonprofits/download-xml?object_id=202041719349301489
# 89 https://projects.propublica.org/nonprofits/download-xml?object_id=201920149349301167
# 90 https://projects.propublica.org/nonprofits/download-xml?object_id=201840129349301019
# 91 https://projects.propublica.org/nonprofits/download-xml?object_id=201741329349306744
# 92 https://projects.propublica.org/nonprofits/download-xml?object_id=201601349349305305
# 93 https://projects.propublica.org/nonprofits/download-xml?object_id=201521339349305167
# 94 https://projects.propublica.org/nonprofits/download-xml?object_id=201440279349300889
# 95 https://projects.propublica.org/nonprofits/download-xml?object_id=201330919349300318
# 96 https://projects.propublica.org/nonprofits/download-xml?object_id=201111259349301576
# 11 / 83
# 97 https://projects.propublica.org/nonprofits/download-xml?object_id=202341119349301419
# 98 https://projects.propublica.org/nonprofits/download-xml?object_id=202211239349301641
# 99 https://projects.propublica.org/nonprofits/download-xml?object_id=202032749349300628
# 12 / 83
# 100 https://projects.propublica.org/nonprofits/download-xml?object_id=202202279349302275
# 101 https://projects.propublica.org/nonprofits/download-xml?object_id=202112249349302051
# 102 https://projects.propublica.org/nonprofits/download-xml?object_id=202022309349302537
# 103 https://projects.propublica.org/nonprofits/download-xml?object_id=201922219349300012
# 104 https://projects.propublica.org/nonprofits/download-xml?object_id=201841769349301204
# 105 https://projects.propublica.org/nonprofits/download-xml?object_id=201721539349300132
# 106 https://projects.propublica.org/nonprofits/download-xml?object_id=201631419349300728
# 107 https://projects.propublica.org/nonprofits/download-xml?object_id=201521669349301202
# 108 https://projects.propublica.org/nonprofits/download-xml?object_id=201530169349300518
# 109 https://projects.propublica.org/nonprofits/download-xml?object_id=201301229349301350
# 110 https://projects.propublica.org/nonprofits/download-xml?object_id=201241319349301019
# 111 https://projects.propublica.org/nonprofits/download-xml?object_id=201101969349300425
# 13 / 83
# 112 https://projects.propublica.org/nonprofits/download-xml?object_id=202213189349309271
# 113 https://projects.propublica.org/nonprofits/download-xml?object_id=202113159349305206
# 114 https://projects.propublica.org/nonprofits/download-xml?object_id=202003219349313685
# 115 https://projects.propublica.org/nonprofits/download-xml?object_id=201943199349317894
# 116 https://projects.propublica.org/nonprofits/download-xml?object_id=201802989349301595
# 117 https://projects.propublica.org/nonprofits/download-xml?object_id=201723119349302897
# 118 https://projects.propublica.org/nonprofits/download-xml?object_id=201643209349310824
# 119 https://projects.propublica.org/nonprofits/download-xml?object_id=201403219349311755
# 120 https://projects.propublica.org/nonprofits/download-xml?object_id=201303199349309400
# 121 https://projects.propublica.org/nonprofits/download-xml?object_id=201223209349304657
# 122 https://projects.propublica.org/nonprofits/download-xml?object_id=201123199349309062
# 14 / 83
# 123 https://projects.propublica.org/nonprofits/download-xml?object_id=202311399349300126
# 124 https://projects.propublica.org/nonprofits/download-xml?object_id=202221369349313897
# 125 https://projects.propublica.org/nonprofits/download-xml?object_id=202141339349305394
# 15 / 83
# 126 https://projects.propublica.org/nonprofits/download-xml?object_id=202223219349301107
# 127 https://projects.propublica.org/nonprofits/download-xml?object_id=202220109349302012
# 128 https://projects.propublica.org/nonprofits/download-xml?object_id=202003289349300950
# 129 https://projects.propublica.org/nonprofits/download-xml?object_id=201902979349301020
# 130 https://projects.propublica.org/nonprofits/download-xml?object_id=201833549349300418
# 131 https://projects.propublica.org/nonprofits/download-xml?object_id=201742899349301329
# 132 https://projects.propublica.org/nonprofits/download-xml?object_id=201622649349300817
# 133 https://projects.propublica.org/nonprofits/download-xml?object_id=201512789349300546
# 134 https://projects.propublica.org/nonprofits/download-xml?object_id=201423149349300937
# 135 https://projects.propublica.org/nonprofits/download-xml?object_id=201442949349300029
# 16 / 83
# 136 https://projects.propublica.org/nonprofits/download-xml?object_id=202301329349305680
# 137 https://projects.propublica.org/nonprofits/download-xml?object_id=202201269349303180
# 138 https://projects.propublica.org/nonprofits/download-xml?object_id=202101349349307850
# 139 https://projects.propublica.org/nonprofits/download-xml?object_id=202031149349300423
# 140 https://projects.propublica.org/nonprofits/download-xml?object_id=201911349349304506
# 141 https://projects.propublica.org/nonprofits/download-xml?object_id=201840619349301029
# 142 https://projects.propublica.org/nonprofits/download-xml?object_id=201721329349303792
# 143 https://projects.propublica.org/nonprofits/download-xml?object_id=201601349349300245
# 144 https://projects.propublica.org/nonprofits/download-xml?object_id=201531049349300043
# 145 https://projects.propublica.org/nonprofits/download-xml?object_id=201400509349300220
# 146 https://projects.propublica.org/nonprofits/download-xml?object_id=201330889349300118
# 147 https://projects.propublica.org/nonprofits/download-xml?object_id=201231999349300043
# 148 https://projects.propublica.org/nonprofits/download-xml?object_id=201121299349302002
# 17 / 83
# 149 https://projects.propublica.org/nonprofits/download-xml?object_id=202202109349300815
# 150 https://projects.propublica.org/nonprofits/download-xml?object_id=202123169349313022
# 151 https://projects.propublica.org/nonprofits/download-xml?object_id=202022459349301022
# 152 https://projects.propublica.org/nonprofits/download-xml?object_id=201921369349300977
# 153 https://projects.propublica.org/nonprofits/download-xml?object_id=201821389349300647
# 154 https://projects.propublica.org/nonprofits/download-xml?object_id=201712069349301511
# 155 https://projects.propublica.org/nonprofits/download-xml?object_id=201641899349300624
# 156 https://projects.propublica.org/nonprofits/download-xml?object_id=201501699349300435
# 157 https://projects.propublica.org/nonprofits/download-xml?object_id=201431999349300348
# 158 https://projects.propublica.org/nonprofits/download-xml?object_id=201342049349300244
# 159 https://projects.propublica.org/nonprofits/download-xml?object_id=201213069349301121
# 160 https://projects.propublica.org/nonprofits/download-xml?object_id=201111549349300116
# 18 / 83
# 161 https://projects.propublica.org/nonprofits/download-xml?object_id=202213199349325486
# 162 https://projects.propublica.org/nonprofits/download-xml?object_id=202133199349326588
# 163 https://projects.propublica.org/nonprofits/download-xml?object_id=202003229349301425
# 164 https://projects.propublica.org/nonprofits/download-xml?object_id=201923189349313442
# 165 https://projects.propublica.org/nonprofits/download-xml?object_id=201813129349303426
# 166 https://projects.propublica.org/nonprofits/download-xml?object_id=201723189349309362
# 167 https://projects.propublica.org/nonprofits/download-xml?object_id=201603219349300605
# 168 https://projects.propublica.org/nonprofits/download-xml?object_id=201533209349315273
# 169 https://projects.propublica.org/nonprofits/download-xml?object_id=201443219349304469
# 170 https://projects.propublica.org/nonprofits/download-xml?object_id=201123199349306942
# 19 / 83
# 171 https://projects.propublica.org/nonprofits/download-xml?object_id=202203119349302685
# 172 https://projects.propublica.org/nonprofits/download-xml?object_id=202141039349301329
# 173 https://projects.propublica.org/nonprofits/download-xml?object_id=201923609349300807
# 174 https://projects.propublica.org/nonprofits/download-xml?object_id=201930799349300248
# 20 / 83
# 175 https://projects.propublica.org/nonprofits/download-xml?object_id=202232459349301428
# 176 https://projects.propublica.org/nonprofits/download-xml?object_id=202112949349302301
# 177 https://projects.propublica.org/nonprofits/download-xml?object_id=202022629349300747
# 178 https://projects.propublica.org/nonprofits/download-xml?object_id=201932529349301163
# 179 https://projects.propublica.org/nonprofits/download-xml?object_id=201822329349301072
# 180 https://projects.propublica.org/nonprofits/download-xml?object_id=201701999349300140
# 181 https://projects.propublica.org/nonprofits/download-xml?object_id=201602189349301250
# 182 https://projects.propublica.org/nonprofits/download-xml?object_id=201512329349301051
# 183 https://projects.propublica.org/nonprofits/download-xml?object_id=201412599349300806
# 184 https://projects.propublica.org/nonprofits/download-xml?object_id=201321339349304822
# 185 https://projects.propublica.org/nonprofits/download-xml?object_id=201242559349300804
# 186 https://projects.propublica.org/nonprofits/download-xml?object_id=201143129349300944
# 21 / 83
# 187 https://projects.propublica.org/nonprofits/download-xml?object_id=202213139349301966
# 188 https://projects.propublica.org/nonprofits/download-xml?object_id=202103139349304345
# 189 https://projects.propublica.org/nonprofits/download-xml?object_id=202043189349313114
# 190 https://projects.propublica.org/nonprofits/download-xml?object_id=202002479349300135
# 22 / 83
# 191 https://projects.propublica.org/nonprofits/download-xml?object_id=202201089349301025
# 192 https://projects.propublica.org/nonprofits/download-xml?object_id=202121269349302937
# 193 https://projects.propublica.org/nonprofits/download-xml?object_id=202001639349301315
# 194 https://projects.propublica.org/nonprofits/download-xml?object_id=201901349349309420
# 195 https://projects.propublica.org/nonprofits/download-xml?object_id=201831359349307543
# 196 https://projects.propublica.org/nonprofits/download-xml?object_id=201700459349301995
# 197 https://projects.propublica.org/nonprofits/download-xml?object_id=201640439349303284
# 198 https://projects.propublica.org/nonprofits/download-xml?object_id=201500419349300035
# 199 https://projects.propublica.org/nonprofits/download-xml?object_id=201440459349301904
# 200 https://projects.propublica.org/nonprofits/download-xml?object_id=201310399349301016
# 201 https://projects.propublica.org/nonprofits/download-xml?object_id=201211369349301826
# 202 https://projects.propublica.org/nonprofits/download-xml?object_id=201121369349304167
# 23 / 83
# 203 https://projects.propublica.org/nonprofits/download-xml?object_id=202210809349300966
# 204 https://projects.propublica.org/nonprofits/download-xml?object_id=202121099349301417
# 205 https://projects.propublica.org/nonprofits/download-xml?object_id=202010669349301306
# 206 https://projects.propublica.org/nonprofits/download-xml?object_id=201842969349300634
# 207 https://projects.propublica.org/nonprofits/download-xml?object_id=201841289349300714
# 208 https://projects.propublica.org/nonprofits/download-xml?object_id=201731319349305573
# 209 https://projects.propublica.org/nonprofits/download-xml?object_id=201621339349303402
# 24 / 83
# 210 https://projects.propublica.org/nonprofits/download-xml?object_id=202243559349300224
# 211 https://projects.propublica.org/nonprofits/download-xml?object_id=202103199349328120
# 212 https://projects.propublica.org/nonprofits/download-xml?object_id=202002539349301195
# 213 https://projects.propublica.org/nonprofits/download-xml?object_id=201942059349301014
# 214 https://projects.propublica.org/nonprofits/download-xml?object_id=201802419349300235
# 215 https://projects.propublica.org/nonprofits/download-xml?object_id=201713179349302491
# 216 https://projects.propublica.org/nonprofits/download-xml?object_id=201633209349306243
# 217 https://projects.propublica.org/nonprofits/download-xml?object_id=201512889349301466
# 218 https://projects.propublica.org/nonprofits/download-xml?object_id=201443219349304499
# 25 / 83
# 219 https://projects.propublica.org/nonprofits/download-xml?object_id=202232909349300938
# 220 https://projects.propublica.org/nonprofits/download-xml?object_id=202142499349300204
# 221 https://projects.propublica.org/nonprofits/download-xml?object_id=202012689349300236
# 222 https://projects.propublica.org/nonprofits/download-xml?object_id=201931639349300028
# 223 https://projects.propublica.org/nonprofits/download-xml?object_id=201801919349300140
# 224 https://projects.propublica.org/nonprofits/download-xml?object_id=201710939349301226
# 225 https://projects.propublica.org/nonprofits/download-xml?object_id=201621329349303557
# 26 / 83
# 226 https://projects.propublica.org/nonprofits/download-xml?object_id=202310769349300601
# 227 https://projects.propublica.org/nonprofits/download-xml?object_id=202201089349300815
# 228 https://projects.propublica.org/nonprofits/download-xml?object_id=202120709349301342
# 229 https://projects.propublica.org/nonprofits/download-xml?object_id=202010179349300211
# 230 https://projects.propublica.org/nonprofits/download-xml?object_id=201833199349304098
# 231 https://projects.propublica.org/nonprofits/download-xml?object_id=201820439349300147
# 232 https://projects.propublica.org/nonprofits/download-xml?object_id=201740469349303454
# 233 https://projects.propublica.org/nonprofits/download-xml?object_id=201620749349300872
# 234 https://projects.propublica.org/nonprofits/download-xml?object_id=201540899349300019
# 235 https://projects.propublica.org/nonprofits/download-xml?object_id=201420659349300632
# 236 https://projects.propublica.org/nonprofits/download-xml?object_id=201300809349300630
# 237 https://projects.propublica.org/nonprofits/download-xml?object_id=201231519349300628
# 238 https://projects.propublica.org/nonprofits/download-xml?object_id=201140409349300819
# 27 / 83
# 239 https://projects.propublica.org/nonprofits/download-xml?object_id=202331369349302653
# 240 https://projects.propublica.org/nonprofits/download-xml?object_id=202202069349300905
# 241 https://projects.propublica.org/nonprofits/download-xml?object_id=202121559349301112
# 242 https://projects.propublica.org/nonprofits/download-xml?object_id=202000579349301135
# 243 https://projects.propublica.org/nonprofits/download-xml?object_id=201902119349300910
# 244 https://projects.propublica.org/nonprofits/download-xml?object_id=201812069349300436
# 245 https://projects.propublica.org/nonprofits/download-xml?object_id=201742059349300119
# 28 / 83
# 246 https://projects.propublica.org/nonprofits/download-xml?object_id=202213149349305921
# 247 https://projects.propublica.org/nonprofits/download-xml?object_id=202103159349303515
# 248 https://projects.propublica.org/nonprofits/download-xml?object_id=202043219349312159
# 249 https://projects.propublica.org/nonprofits/download-xml?object_id=202023219349313507
# 250 https://projects.propublica.org/nonprofits/download-xml?object_id=201843259349300814
# 251 https://projects.propublica.org/nonprofits/download-xml?object_id=201703199349308005
# 252 https://projects.propublica.org/nonprofits/download-xml?object_id=201643209349313294
# 253 https://projects.propublica.org/nonprofits/download-xml?object_id=201523179349306627
# 254 https://projects.propublica.org/nonprofits/download-xml?object_id=201423189349304627
# 255 https://projects.propublica.org/nonprofits/download-xml?object_id=201303239349300710
# 256 https://projects.propublica.org/nonprofits/download-xml?object_id=201233209349309863
# 257 https://projects.propublica.org/nonprofits/download-xml?object_id=201103209349301110
# 29 / 83
# 258 https://projects.propublica.org/nonprofits/download-xml?object_id=202331329349309118
# 259 https://projects.propublica.org/nonprofits/download-xml?object_id=202201339349306085
# 260 https://projects.propublica.org/nonprofits/download-xml?object_id=202121319349304672
# 261 https://projects.propublica.org/nonprofits/download-xml?object_id=202021969349304702
# 262 https://projects.propublica.org/nonprofits/download-xml?object_id=201901359349313480
# 263 https://projects.propublica.org/nonprofits/download-xml?object_id=201811359349307736
# 264 https://projects.propublica.org/nonprofits/download-xml?object_id=201731289349302128
# 265 https://projects.propublica.org/nonprofits/download-xml?object_id=201641189349300539
# 266 https://projects.propublica.org/nonprofits/download-xml?object_id=201500989349300900
# 30 / 83
# 267 https://projects.propublica.org/nonprofits/download-xml?object_id=202211329349308361
# 268 https://projects.propublica.org/nonprofits/download-xml?object_id=202102519349300545
# 31 / 83
# 269 https://projects.propublica.org/nonprofits/download-xml?object_id=202321359349307407
# 270 https://projects.propublica.org/nonprofits/download-xml?object_id=202241369349305894
# 271 https://projects.propublica.org/nonprofits/download-xml?object_id=202130959349300348
# 272 https://projects.propublica.org/nonprofits/download-xml?object_id=202011969349302686
# 273 https://projects.propublica.org/nonprofits/download-xml?object_id=201911299349302346
# 274 https://projects.propublica.org/nonprofits/download-xml?object_id=201723529349300127
# 275 https://projects.propublica.org/nonprofits/download-xml?object_id=201603199349311485
# 276 https://projects.propublica.org/nonprofits/download-xml?object_id=201533209349307203
# 277 https://projects.propublica.org/nonprofits/download-xml?object_id=201423179349306362
# 278 https://projects.propublica.org/nonprofits/download-xml?object_id=201333189349306243
# 279 https://projects.propublica.org/nonprofits/download-xml?object_id=201203149349301865
# 280 https://projects.propublica.org/nonprofits/download-xml?object_id=201133149349301708
# 32 / 83
# 281 https://projects.propublica.org/nonprofits/download-xml?object_id=201911349349307891
# 282 https://projects.propublica.org/nonprofits/download-xml?object_id=201812999349301026
# 283 https://projects.propublica.org/nonprofits/download-xml?object_id=201722989349301462
# 284 https://projects.propublica.org/nonprofits/download-xml?object_id=201622259349303997
# 285 https://projects.propublica.org/nonprofits/download-xml?object_id=201503169349303225
# 33 / 83
# 286 https://projects.propublica.org/nonprofits/download-xml?object_id=202331189349300303
# 287 https://projects.propublica.org/nonprofits/download-xml?object_id=202221319349303917
# 288 https://projects.propublica.org/nonprofits/download-xml?object_id=202101189349301515
# 289 https://projects.propublica.org/nonprofits/download-xml?object_id=202010589349300236
# 290 https://projects.propublica.org/nonprofits/download-xml?object_id=201940249349301019
# 291 https://projects.propublica.org/nonprofits/download-xml?object_id=201800269349301550
# 292 https://projects.propublica.org/nonprofits/download-xml?object_id=201710269349300021
# 293 https://projects.propublica.org/nonprofits/download-xml?object_id=201640329349300984
# 294 https://projects.propublica.org/nonprofits/download-xml?object_id=201520289349301172
# 295 https://projects.propublica.org/nonprofits/download-xml?object_id=201400239349301215
# 296 https://projects.propublica.org/nonprofits/download-xml?object_id=201320329349300962
# 297 https://projects.propublica.org/nonprofits/download-xml?object_id=201230909349300238
# 298 https://projects.propublica.org/nonprofits/download-xml?object_id=201120329349300712
# 34 / 83
# 299 https://projects.propublica.org/nonprofits/download-xml?object_id=202203479349301405
# 300 https://projects.propublica.org/nonprofits/download-xml?object_id=202221349349302487
# 301 https://projects.propublica.org/nonprofits/download-xml?object_id=202141349349306089
# 302 https://projects.propublica.org/nonprofits/download-xml?object_id=202000379349301255
# 303 https://projects.propublica.org/nonprofits/download-xml?object_id=201930119349300938
# 35 / 83
# 304 https://projects.propublica.org/nonprofits/download-xml?object_id=202331309349300848
# 305 https://projects.propublica.org/nonprofits/download-xml?object_id=202201319349305930
# 306 https://projects.propublica.org/nonprofits/download-xml?object_id=202140469349300149
# 307 https://projects.propublica.org/nonprofits/download-xml?object_id=202010309349300711
# 308 https://projects.propublica.org/nonprofits/download-xml?object_id=201910439349301061
# 309 https://projects.propublica.org/nonprofits/download-xml?object_id=201831109349300928
# 310 https://projects.propublica.org/nonprofits/download-xml?object_id=201700329349301070
# 311 https://projects.propublica.org/nonprofits/download-xml?object_id=201610409349300246
# 312 https://projects.propublica.org/nonprofits/download-xml?object_id=201531289349300418
# 313 https://projects.propublica.org/nonprofits/download-xml?object_id=201430439349301253
# 36 / 83
# 314 https://projects.propublica.org/nonprofits/download-xml?object_id=202301359349316195
# 315 https://projects.propublica.org/nonprofits/download-xml?object_id=202232109349301663
# 316 https://projects.propublica.org/nonprofits/download-xml?object_id=202140429349300029
# 317 https://projects.propublica.org/nonprofits/download-xml?object_id=202001339349300630
# 318 https://projects.propublica.org/nonprofits/download-xml?object_id=201941069349300329
# 319 https://projects.propublica.org/nonprofits/download-xml?object_id=201800449349301180
# 320 https://projects.propublica.org/nonprofits/download-xml?object_id=201700419349301365
# 321 https://projects.propublica.org/nonprofits/download-xml?object_id=201621239349300442
# 322 https://projects.propublica.org/nonprofits/download-xml?object_id=201530339349301108
# 323 https://projects.propublica.org/nonprofits/download-xml?object_id=201341649349300314
# 324 https://projects.propublica.org/nonprofits/download-xml?object_id=201231679349300823
# 325 https://projects.propublica.org/nonprofits/download-xml?object_id=201110749349300331
# 37 / 83
# 326 https://projects.propublica.org/nonprofits/download-xml?object_id=202213209349301346
# 327 https://projects.propublica.org/nonprofits/download-xml?object_id=202123199349326622
# 328 https://projects.propublica.org/nonprofits/download-xml?object_id=202043219349322239
# 329 https://projects.propublica.org/nonprofits/download-xml?object_id=201942969349301614
# 330 https://projects.propublica.org/nonprofits/download-xml?object_id=201843189349312029
# 331 https://projects.propublica.org/nonprofits/download-xml?object_id=201713129349301956
# 332 https://projects.propublica.org/nonprofits/download-xml?object_id=201623199349306427
# 333 https://projects.propublica.org/nonprofits/download-xml?object_id=201532249349301358
# 334 https://projects.propublica.org/nonprofits/download-xml?object_id=201422279349302317
# 335 https://projects.propublica.org/nonprofits/download-xml?object_id=201332199349301133
# 336 https://projects.propublica.org/nonprofits/download-xml?object_id=201243189349300544
# 337 https://projects.propublica.org/nonprofits/download-xml?object_id=201123199349302942
# 38 / 83
# 338 https://projects.propublica.org/nonprofits/download-xml?object_id=202320869349301242
# 339 https://projects.propublica.org/nonprofits/download-xml?object_id=202210739349301791
# 340 https://projects.propublica.org/nonprofits/download-xml?object_id=202121209349301792
# 341 https://projects.propublica.org/nonprofits/download-xml?object_id=202001979349305615
# 342 https://projects.propublica.org/nonprofits/download-xml?object_id=201910809349300901
# 343 https://projects.propublica.org/nonprofits/download-xml?object_id=201820319349301007
# 344 https://projects.propublica.org/nonprofits/download-xml?object_id=201701359349311135
# 345 https://projects.propublica.org/nonprofits/download-xml?object_id=201601379349308575
# 346 https://projects.propublica.org/nonprofits/download-xml?object_id=201413109349301216
# 347 https://projects.propublica.org/nonprofits/download-xml?object_id=201420389349301447
# 348 https://projects.propublica.org/nonprofits/download-xml?object_id=201223049349300807
# 349 https://projects.propublica.org/nonprofits/download-xml?object_id=201132979349300653
# 350 https://projects.propublica.org/nonprofits/download-xml?object_id=201143219349300424
# 39 / 83
# 351 https://projects.propublica.org/nonprofits/download-xml?object_id=202222219349301007
# 352 https://projects.propublica.org/nonprofits/download-xml?object_id=202132299349300028
# 353 https://projects.propublica.org/nonprofits/download-xml?object_id=202001619349301320
# 354 https://projects.propublica.org/nonprofits/download-xml?object_id=201901339349305605
# 355 https://projects.propublica.org/nonprofits/download-xml?object_id=201822999349300922
# 356 https://projects.propublica.org/nonprofits/download-xml?object_id=201742439349300314
# 357 https://projects.propublica.org/nonprofits/download-xml?object_id=201642079349300999
# 358 https://projects.propublica.org/nonprofits/download-xml?object_id=201121449349300012
# 40 / 83
# 359 https://projects.propublica.org/nonprofits/download-xml?object_id=202340129349303669
# 360 https://projects.propublica.org/nonprofits/download-xml?object_id=202103409349300930
# 361 https://projects.propublica.org/nonprofits/download-xml?object_id=202043179349308559
# 362 https://projects.propublica.org/nonprofits/download-xml?object_id=201913199349310236
# 363 https://projects.propublica.org/nonprofits/download-xml?object_id=201940219349300434
# 364 https://projects.propublica.org/nonprofits/download-xml?object_id=201600269349300760
# 41 / 83
# 365 https://projects.propublica.org/nonprofits/download-xml?object_id=202310489349300246
# 366 https://projects.propublica.org/nonprofits/download-xml?object_id=202211369349314141
# 367 https://projects.propublica.org/nonprofits/download-xml?object_id=202140129349300914
# 368 https://projects.propublica.org/nonprofits/download-xml?object_id=202040419349300829
# 369 https://projects.propublica.org/nonprofits/download-xml?object_id=201910689349300231
# 370 https://projects.propublica.org/nonprofits/download-xml?object_id=201831209349301578
# 371 https://projects.propublica.org/nonprofits/download-xml?object_id=201701329349306405
# 372 https://projects.propublica.org/nonprofits/download-xml?object_id=201741329349306329
# 373 https://projects.propublica.org/nonprofits/download-xml?object_id=201510459349300616
# 374 https://projects.propublica.org/nonprofits/download-xml?object_id=201410439349301271
# 375 https://projects.propublica.org/nonprofits/download-xml?object_id=201331979349300833
# 376 https://projects.propublica.org/nonprofits/download-xml?object_id=201103559349300330
# 377 https://projects.propublica.org/nonprofits/download-xml?object_id=201110189349300306
# 42 / 83
# 378 https://projects.propublica.org/nonprofits/download-xml?object_id=202103419349300605
# 379 https://projects.propublica.org/nonprofits/download-xml?object_id=202003439349300105
# 380 https://projects.propublica.org/nonprofits/download-xml?object_id=201913019349300401
# 381 https://projects.propublica.org/nonprofits/download-xml?object_id=201920309349300507
# 382 https://projects.propublica.org/nonprofits/download-xml?object_id=201703189349308270
# 383 https://projects.propublica.org/nonprofits/download-xml?object_id=201741949349300114
# 384 https://projects.propublica.org/nonprofits/download-xml?object_id=201533489349300703
# 385 https://projects.propublica.org/nonprofits/download-xml?object_id=201412759349300706
# 386 https://projects.propublica.org/nonprofits/download-xml?object_id=201323189349306982
# 43 / 83
# 44 / 83
# 387 https://projects.propublica.org/nonprofits/download-xml?object_id=202231749349301418
# 388 https://projects.propublica.org/nonprofits/download-xml?object_id=202131959349300828
# 389 https://projects.propublica.org/nonprofits/download-xml?object_id=202041959349302419
# 390 https://projects.propublica.org/nonprofits/download-xml?object_id=201901969349302410
# 391 https://projects.propublica.org/nonprofits/download-xml?object_id=201831789349300143
# 392 https://projects.propublica.org/nonprofits/download-xml?object_id=201601979349301000
# 393 https://projects.propublica.org/nonprofits/download-xml?object_id=201531969349302018
# 394 https://projects.propublica.org/nonprofits/download-xml?object_id=201421889349300487
# 395 https://projects.propublica.org/nonprofits/download-xml?object_id=201311969349301051
# 396 https://projects.propublica.org/nonprofits/download-xml?object_id=201231929349300248
# 397 https://projects.propublica.org/nonprofits/download-xml?object_id=201121899349300422
# 45 / 83
# 398 https://projects.propublica.org/nonprofits/download-xml?object_id=202331379349301638
# 399 https://projects.propublica.org/nonprofits/download-xml?object_id=202220949349300532
# 400 https://projects.propublica.org/nonprofits/download-xml?object_id=202111369349300141
# 401 https://projects.propublica.org/nonprofits/download-xml?object_id=201900809349300545
# 402 https://projects.propublica.org/nonprofits/download-xml?object_id=201821359349312922
# 46 / 83
# 403 https://projects.propublica.org/nonprofits/download-xml?object_id=202341359349319869
# 404 https://projects.propublica.org/nonprofits/download-xml?object_id=202211369349315946
# 405 https://projects.propublica.org/nonprofits/download-xml?object_id=202121319349302087
# 406 https://projects.propublica.org/nonprofits/download-xml?object_id=202041279349301244
# 407 https://projects.propublica.org/nonprofits/download-xml?object_id=201843489349300439
# 408 https://projects.propublica.org/nonprofits/download-xml?object_id=201800389349300625
# 409 https://projects.propublica.org/nonprofits/download-xml?object_id=201603199349306620
# 410 https://projects.propublica.org/nonprofits/download-xml?object_id=201523019349301012
# 411 https://projects.propublica.org/nonprofits/download-xml?object_id=201432899349300323
# 412 https://projects.propublica.org/nonprofits/download-xml?object_id=201342739349300369
# 47 / 83
# 413 https://projects.propublica.org/nonprofits/download-xml?object_id=202213569349301336
# 414 https://projects.propublica.org/nonprofits/download-xml?object_id=202200619349301205
# 415 https://projects.propublica.org/nonprofits/download-xml?object_id=202013159349303941
# 416 https://projects.propublica.org/nonprofits/download-xml?object_id=202030419349301403
# 417 https://projects.propublica.org/nonprofits/download-xml?object_id=201900269349300605
# 418 https://projects.propublica.org/nonprofits/download-xml?object_id=201723179349307002
# 419 https://projects.propublica.org/nonprofits/download-xml?object_id=201741379349300649
# 420 https://projects.propublica.org/nonprofits/download-xml?object_id=201643209349307094
# 48 / 83
# 421 https://projects.propublica.org/nonprofits/download-xml?object_id=202311229349300836
# 422 https://projects.propublica.org/nonprofits/download-xml?object_id=202220339349301462
# 423 https://projects.propublica.org/nonprofits/download-xml?object_id=202110409349301611
# 424 https://projects.propublica.org/nonprofits/download-xml?object_id=202020349349301257
# 425 https://projects.propublica.org/nonprofits/download-xml?object_id=201713129349303671
# 426 https://projects.propublica.org/nonprofits/download-xml?object_id=201613159349304601
# 427 https://projects.propublica.org/nonprofits/download-xml?object_id=201523209349303842
# 428 https://projects.propublica.org/nonprofits/download-xml?object_id=201520439349301752
# 429 https://projects.propublica.org/nonprofits/download-xml?object_id=201410179349300521
# 430 https://projects.propublica.org/nonprofits/download-xml?object_id=201330669349300723
# 49 / 83
# 431 https://projects.propublica.org/nonprofits/download-xml?object_id=202330189349300903
# 432 https://projects.propublica.org/nonprofits/download-xml?object_id=202122959349300117
# 433 https://projects.propublica.org/nonprofits/download-xml?object_id=202023589349301207
# 434 https://projects.propublica.org/nonprofits/download-xml?object_id=202000219349300545
# 435 https://projects.propublica.org/nonprofits/download-xml?object_id=201842889349301594
# 436 https://projects.propublica.org/nonprofits/download-xml?object_id=201743219349300954
# 437 https://projects.propublica.org/nonprofits/download-xml?object_id=201603149349301360
# 438 https://projects.propublica.org/nonprofits/download-xml?object_id=201503179349306595
# 439 https://projects.propublica.org/nonprofits/download-xml?object_id=201443189349305099
# 50 / 83
# 440 https://projects.propublica.org/nonprofits/download-xml?object_id=202301199349300100
# 441 https://projects.propublica.org/nonprofits/download-xml?object_id=202212309349301596
# 442 https://projects.propublica.org/nonprofits/download-xml?object_id=202142319349301129
# 443 https://projects.propublica.org/nonprofits/download-xml?object_id=202032629349301423
# 444 https://projects.propublica.org/nonprofits/download-xml?object_id=201902919349300140
# 445 https://projects.propublica.org/nonprofits/download-xml?object_id=201812209349300731
# 446 https://projects.propublica.org/nonprofits/download-xml?object_id=201741529349300049
# 447 https://projects.propublica.org/nonprofits/download-xml?object_id=201543209349314609
# 51 / 83
# 448 https://projects.propublica.org/nonprofits/download-xml?object_id=202213199349322091
# 449 https://projects.propublica.org/nonprofits/download-xml?object_id=202143199349308009
# 450 https://projects.propublica.org/nonprofits/download-xml?object_id=202011839349301616
# 52 / 83
# 451 https://projects.propublica.org/nonprofits/download-xml?object_id=202243329349300104
# 452 https://projects.propublica.org/nonprofits/download-xml?object_id=202142319349300329
# 453 https://projects.propublica.org/nonprofits/download-xml?object_id=202001769349301120
# 454 https://projects.propublica.org/nonprofits/download-xml?object_id=201922769349301127
# 455 https://projects.propublica.org/nonprofits/download-xml?object_id=201822889349300407
# 456 https://projects.propublica.org/nonprofits/download-xml?object_id=201731289349300318
# 457 https://projects.propublica.org/nonprofits/download-xml?object_id=201601349349302565
# 458 https://projects.propublica.org/nonprofits/download-xml?object_id=201542299349303234
# 459 https://projects.propublica.org/nonprofits/download-xml?object_id=201422239349302152
# 460 https://projects.propublica.org/nonprofits/download-xml?object_id=201312279349303046
# 53 / 83
# 461 https://projects.propublica.org/nonprofits/download-xml?object_id=202222719349301757
# 462 https://projects.propublica.org/nonprofits/download-xml?object_id=202201369349316620
# 463 https://projects.propublica.org/nonprofits/download-xml?object_id=202131319349302313
# 54 / 83
# 464 https://projects.propublica.org/nonprofits/download-xml?object_id=202201309349304960
# 465 https://projects.propublica.org/nonprofits/download-xml?object_id=202121349349305352
# 466 https://projects.propublica.org/nonprofits/download-xml?object_id=202001399349300845
# 467 https://projects.propublica.org/nonprofits/download-xml?object_id=201932949349300228
# 468 https://projects.propublica.org/nonprofits/download-xml?object_id=201821309349303792
# 469 https://projects.propublica.org/nonprofits/download-xml?object_id=201643549349300649
# 470 https://projects.propublica.org/nonprofits/download-xml?object_id=201523579349300322
# 471 https://projects.propublica.org/nonprofits/download-xml?object_id=201511149349300116
# 472 https://projects.propublica.org/nonprofits/download-xml?object_id=201400309349300120
# 473 https://projects.propublica.org/nonprofits/download-xml?object_id=201213199349304261
# 474 https://projects.propublica.org/nonprofits/download-xml?object_id=201201249349300815
# 475 https://projects.propublica.org/nonprofits/download-xml?object_id=201100839349300115
# 55 / 83
# 476 https://projects.propublica.org/nonprofits/download-xml?object_id=202230679349301013
# 477 https://projects.propublica.org/nonprofits/download-xml?object_id=202130089349301988
# 478 https://projects.propublica.org/nonprofits/download-xml?object_id=202010649349301616
# 479 https://projects.propublica.org/nonprofits/download-xml?object_id=201930879349301213
# 480 https://projects.propublica.org/nonprofits/download-xml?object_id=201821359349305092
# 481 https://projects.propublica.org/nonprofits/download-xml?object_id=201731359349312298
# 482 https://projects.propublica.org/nonprofits/download-xml?object_id=201631259349301103
# 483 https://projects.propublica.org/nonprofits/download-xml?object_id=201530649349300723
# 484 https://projects.propublica.org/nonprofits/download-xml?object_id=201440499349300234
# 485 https://projects.propublica.org/nonprofits/download-xml?object_id=201330459349302603
# 486 https://projects.propublica.org/nonprofits/download-xml?object_id=201211989349300541
# 56 / 83
# 487 https://projects.propublica.org/nonprofits/download-xml?object_id=202321319349306632
# 488 https://projects.propublica.org/nonprofits/download-xml?object_id=202222089349300212
# 489 https://projects.propublica.org/nonprofits/download-xml?object_id=202111469349300911
# 490 https://projects.propublica.org/nonprofits/download-xml?object_id=202042549349301854
# 491 https://projects.propublica.org/nonprofits/download-xml?object_id=201911349349308321
# 492 https://projects.propublica.org/nonprofits/download-xml?object_id=201842269349302384
# 493 https://projects.propublica.org/nonprofits/download-xml?object_id=201712059349300346
# 494 https://projects.propublica.org/nonprofits/download-xml?object_id=201602289349305545
# 495 https://projects.propublica.org/nonprofits/download-xml?object_id=201502339349300520
# 496 https://projects.propublica.org/nonprofits/download-xml?object_id=201431359349305868
# 497 https://projects.propublica.org/nonprofits/download-xml?object_id=201333179349304958
# 57 / 83
# 498 https://projects.propublica.org/nonprofits/download-xml?object_id=202321319349306387
# 499 https://projects.propublica.org/nonprofits/download-xml?object_id=202231319349303538
# 500 https://projects.propublica.org/nonprofits/download-xml?object_id=202130969349300643
# 501 https://projects.propublica.org/nonprofits/download-xml?object_id=202041299349300934
# 502 https://projects.propublica.org/nonprofits/download-xml?object_id=201900729349300635
# 503 https://projects.propublica.org/nonprofits/download-xml?object_id=201300979349300400
# 58 / 83
# 504 https://projects.propublica.org/nonprofits/download-xml?object_id=202223189349312322
# 505 https://projects.propublica.org/nonprofits/download-xml?object_id=202133169349305108
# 506 https://projects.propublica.org/nonprofits/download-xml?object_id=202043109349302219
# 507 https://projects.propublica.org/nonprofits/download-xml?object_id=201943179349306554
# 508 https://projects.propublica.org/nonprofits/download-xml?object_id=201842989349301039
# 509 https://projects.propublica.org/nonprofits/download-xml?object_id=201702939349300815
# 510 https://projects.propublica.org/nonprofits/download-xml?object_id=201643089349302559
# 511 https://projects.propublica.org/nonprofits/download-xml?object_id=201513149349300806
# 512 https://projects.propublica.org/nonprofits/download-xml?object_id=201301989349301070
# 513 https://projects.propublica.org/nonprofits/download-xml?object_id=201232139349301108
# 514 https://projects.propublica.org/nonprofits/download-xml?object_id=201141229349300679
# 59 / 83
# 60 / 83
# 515 https://projects.propublica.org/nonprofits/download-xml?object_id=202340819349301804
# 516 https://projects.propublica.org/nonprofits/download-xml?object_id=202230909349300113
# 517 https://projects.propublica.org/nonprofits/download-xml?object_id=202131129349301588
# 518 https://projects.propublica.org/nonprofits/download-xml?object_id=202011399349301901
# 519 https://projects.propublica.org/nonprofits/download-xml?object_id=201940919349300829
# 520 https://projects.propublica.org/nonprofits/download-xml?object_id=201811319349303161
# 521 https://projects.propublica.org/nonprofits/download-xml?object_id=201731359349311873
# 522 https://projects.propublica.org/nonprofits/download-xml?object_id=201601379349310830
# 523 https://projects.propublica.org/nonprofits/download-xml?object_id=201531349349308828
# 524 https://projects.propublica.org/nonprofits/download-xml?object_id=201441339349305869
# 525 https://projects.propublica.org/nonprofits/download-xml?object_id=201311359349308641
# 526 https://projects.propublica.org/nonprofits/download-xml?object_id=201231299349301928
# 527 https://projects.propublica.org/nonprofits/download-xml?object_id=201121369349306422
# 61 / 83
# 528 https://projects.propublica.org/nonprofits/download-xml?object_id=202223189349312202
# 529 https://projects.propublica.org/nonprofits/download-xml?object_id=202102089349301400
# 530 https://projects.propublica.org/nonprofits/download-xml?object_id=202041859349300324
# 531 https://projects.propublica.org/nonprofits/download-xml?object_id=201933189349304303
# 532 https://projects.propublica.org/nonprofits/download-xml?object_id=201801649349300520
# 533 https://projects.propublica.org/nonprofits/download-xml?object_id=201811649349300521
# 534 https://projects.propublica.org/nonprofits/download-xml?object_id=201631379349308783
# ...
# 583 https://projects.propublica.org/nonprofits/download-xml?object_id=202001979349307700
# 584 https://projects.propublica.org/nonprofits/download-xml?object_id=201931359349311243
# 585 https://projects.propublica.org/nonprofits/download-xml?object_id=201811239349300226
# 586 https://projects.propublica.org/nonprofits/download-xml?object_id=201720469349302112
# 587 https://projects.propublica.org/nonprofits/download-xml?object_id=201600419349301930
# 588 https://projects.propublica.org/nonprofits/download-xml?object_id=201540439349301724
# 589 https://projects.propublica.org/nonprofits/download-xml?object_id=201440459349301699
# 590 https://projects.propublica.org/nonprofits/download-xml?object_id=201320449349301807
# 591 https://projects.propublica.org/nonprofits/download-xml?object_id=201220699349301112
# 592 https://projects.propublica.org/nonprofits/download-xml?object_id=201100429349301240
# 67 / 83
# 593 https://projects.propublica.org/nonprofits/download-xml?object_id=202241319349303914
# 594 https://projects.propublica.org/nonprofits/download-xml?object_id=202111319349302666
# 595 https://projects.propublica.org/nonprofits/download-xml?object_id=202010579349301766
# 596 https://projects.propublica.org/nonprofits/download-xml?object_id=201910379349301136
# 597 https://projects.propublica.org/nonprofits/download-xml?object_id=201801289349302885
# 598 https://projects.propublica.org/nonprofits/download-xml?object_id=201720479349300032
# 599 https://projects.propublica.org/nonprofits/download-xml?object_id=201610909349301051
# 600 https://projects.propublica.org/nonprofits/download-xml?object_id=201501209349301140
# 68 / 83
# 601 https://projects.propublica.org/nonprofits/download-xml?object_id=202232459349300923
# 602 https://projects.propublica.org/nonprofits/download-xml?object_id=202132379349300918
# 603 https://projects.propublica.org/nonprofits/download-xml?object_id=202043159349304559
# 604 https://projects.propublica.org/nonprofits/download-xml?object_id=201903169349306315
# 605 https://projects.propublica.org/nonprofits/download-xml?object_id=201812719349300441
# 606 https://projects.propublica.org/nonprofits/download-xml?object_id=201702969349301395
# 607 https://projects.propublica.org/nonprofits/download-xml?object_id=201622249349301597
# 608 https://projects.propublica.org/nonprofits/download-xml?object_id=201522409349300627
# 609 https://projects.propublica.org/nonprofits/download-xml?object_id=201442939349300324
# 610 https://projects.propublica.org/nonprofits/download-xml?object_id=201313169349303846
# 611 https://projects.propublica.org/nonprofits/download-xml?object_id=201203199349306350
# 612 https://projects.propublica.org/nonprofits/download-xml?object_id=201123199349310862
# 69 / 83
# 613 https://projects.propublica.org/nonprofits/download-xml?object_id=202311359349316171
# 614 https://projects.propublica.org/nonprofits/download-xml?object_id=202211229349302251
# 615 https://projects.propublica.org/nonprofits/download-xml?object_id=202120859349301007
# 616 https://projects.propublica.org/nonprofits/download-xml?object_id=202031909349302653
# 617 https://projects.propublica.org/nonprofits/download-xml?object_id=201921349349310562
# 618 https://projects.propublica.org/nonprofits/download-xml?object_id=201811359349309706
# 619 https://projects.propublica.org/nonprofits/download-xml?object_id=201720389349301502
# 620 https://projects.propublica.org/nonprofits/download-xml?object_id=201513509349300146
# 70 / 83
# 621 https://projects.propublica.org/nonprofits/download-xml?object_id=202321329349306227
# 622 https://projects.propublica.org/nonprofits/download-xml?object_id=202241369349317829
# 623 https://projects.propublica.org/nonprofits/download-xml?object_id=202140639349301819
# 624 https://projects.propublica.org/nonprofits/download-xml?object_id=202041339349303214
# 625 https://projects.propublica.org/nonprofits/download-xml?object_id=201921359349305402
# 626 https://projects.propublica.org/nonprofits/download-xml?object_id=201821349349310442
# 627 https://projects.propublica.org/nonprofits/download-xml?object_id=201741149349300624
# 628 https://projects.propublica.org/nonprofits/download-xml?object_id=201601349349301395
# 629 https://projects.propublica.org/nonprofits/download-xml?object_id=201511289349301396
# 630 https://projects.propublica.org/nonprofits/download-xml?object_id=201441359349305494
# 631 https://projects.propublica.org/nonprofits/download-xml?object_id=201222059349300532
# 632 https://projects.propublica.org/nonprofits/download-xml?object_id=201132989349300713
# 71 / 83
# 633 https://projects.propublica.org/nonprofits/download-xml?object_id=202301219349302955
# 634 https://projects.propublica.org/nonprofits/download-xml?object_id=202221249349302107
# 635 https://projects.propublica.org/nonprofits/download-xml?object_id=202111379349307321
# 636 https://projects.propublica.org/nonprofits/download-xml?object_id=202041969349304414
# 637 https://projects.propublica.org/nonprofits/download-xml?object_id=201901349349309765
# 638 https://projects.propublica.org/nonprofits/download-xml?object_id=201831299349302193
# 639 https://projects.propublica.org/nonprofits/download-xml?object_id=201740659349300024
# 640 https://projects.propublica.org/nonprofits/download-xml?object_id=201630359349301678
# 641 https://projects.propublica.org/nonprofits/download-xml?object_id=201540619349300924
# 642 https://projects.propublica.org/nonprofits/download-xml?object_id=201400929349300015
# 643 https://projects.propublica.org/nonprofits/download-xml?object_id=201341199349300869
# 72 / 83
# 644 https://projects.propublica.org/nonprofits/download-xml?object_id=202232169349301903
# 645 https://projects.propublica.org/nonprofits/download-xml?object_id=202141759349300919
# 646 https://projects.propublica.org/nonprofits/download-xml?object_id=202012209349300431
# 647 https://projects.propublica.org/nonprofits/download-xml?object_id=201912209349300341
# 648 https://projects.propublica.org/nonprofits/download-xml?object_id=201842199349301264
# 649 https://projects.propublica.org/nonprofits/download-xml?object_id=201702269349301270
# 650 https://projects.propublica.org/nonprofits/download-xml?object_id=201622239349302537
# 651 https://projects.propublica.org/nonprofits/download-xml?object_id=201512259349303656
# 652 https://projects.propublica.org/nonprofits/download-xml?object_id=201432259349300643
# 653 https://projects.propublica.org/nonprofits/download-xml?object_id=201312269349303311
# 654 https://projects.propublica.org/nonprofits/download-xml?object_id=201222279349304012
# 655 https://projects.propublica.org/nonprofits/download-xml?object_id=201112289349300891
# 73 / 83
# 656 https://projects.propublica.org/nonprofits/download-xml?object_id=202301309349302465
# 657 https://projects.propublica.org/nonprofits/download-xml?object_id=202230769349301413
# 658 https://projects.propublica.org/nonprofits/download-xml?object_id=202140639349300834
# 659 https://projects.propublica.org/nonprofits/download-xml?object_id=202030099349300143
# 660 https://projects.propublica.org/nonprofits/download-xml?object_id=201900289349301270
# 661 https://projects.propublica.org/nonprofits/download-xml?object_id=201830409349301138
# 662 https://projects.propublica.org/nonprofits/download-xml?object_id=201740449349302579
# 663 https://projects.propublica.org/nonprofits/download-xml?object_id=201600439349303235
# 664 https://projects.propublica.org/nonprofits/download-xml?object_id=201500659349300210
# 665 https://projects.propublica.org/nonprofits/download-xml?object_id=201400349349300740
# 666 https://projects.propublica.org/nonprofits/download-xml?object_id=201340329349301009
# 667 https://projects.propublica.org/nonprofits/download-xml?object_id=201140189349300219
# 74 / 83
# 668 https://projects.propublica.org/nonprofits/download-xml?object_id=202311159349300301
# 669 https://projects.propublica.org/nonprofits/download-xml?object_id=202241089349300824
# 670 https://projects.propublica.org/nonprofits/download-xml?object_id=202101109349300840
# 671 https://projects.propublica.org/nonprofits/download-xml?object_id=202020739349300702
# 672 https://projects.propublica.org/nonprofits/download-xml?object_id=201941309349301444
# 673 https://projects.propublica.org/nonprofits/download-xml?object_id=201830649349300853
# 674 https://projects.propublica.org/nonprofits/download-xml?object_id=201740459349301999
# 675 https://projects.propublica.org/nonprofits/download-xml?object_id=201640469349302904
# 676 https://projects.propublica.org/nonprofits/download-xml?object_id=201520489349301277
# 677 https://projects.propublica.org/nonprofits/download-xml?object_id=201420499349301722
# 678 https://projects.propublica.org/nonprofits/download-xml?object_id=201300389349300005
# 679 https://projects.propublica.org/nonprofits/download-xml?object_id=201200819349300610
# 680 https://projects.propublica.org/nonprofits/download-xml?object_id=201100459349301135
# 75 / 83
# 681 https://projects.propublica.org/nonprofits/download-xml?object_id=202301309349305605
# 682 https://projects.propublica.org/nonprofits/download-xml?object_id=202230749349301558
# 683 https://projects.propublica.org/nonprofits/download-xml?object_id=202101059349301630
# 684 https://projects.propublica.org/nonprofits/download-xml?object_id=202010349349300126
# 685 https://projects.propublica.org/nonprofits/download-xml?object_id=201901149349301370
# 686 https://projects.propublica.org/nonprofits/download-xml?object_id=201820329349302062
# 687 https://projects.propublica.org/nonprofits/download-xml?object_id=201730459349302858
# 688 https://projects.propublica.org/nonprofits/download-xml?object_id=201641179349300044
# 689 https://projects.propublica.org/nonprofits/download-xml?object_id=201541339349305214
# 690 https://projects.propublica.org/nonprofits/download-xml?object_id=201441339349304659
# 691 https://projects.propublica.org/nonprofits/download-xml?object_id=201320459349302322
# 76 / 83
# 692 https://projects.propublica.org/nonprofits/download-xml?object_id=202311289349304461
# 693 https://projects.propublica.org/nonprofits/download-xml?object_id=202200249349300655
# 694 https://projects.propublica.org/nonprofits/download-xml?object_id=202043509349301814
# 695 https://projects.propublica.org/nonprofits/download-xml?object_id=202010309349300426
# 696 https://projects.propublica.org/nonprofits/download-xml?object_id=201910119349301201
# 697 https://projects.propublica.org/nonprofits/download-xml?object_id=201713139349302751
# 698 https://projects.propublica.org/nonprofits/download-xml?object_id=201720409349301452
# 699 https://projects.propublica.org/nonprofits/download-xml?object_id=201533139349303293
# 700 https://projects.propublica.org/nonprofits/download-xml?object_id=201510629349300041
# 701 https://projects.propublica.org/nonprofits/download-xml?object_id=201313229349300836
# 702 https://projects.propublica.org/nonprofits/download-xml?object_id=201243549349300119
# 77 / 83
# 703 https://projects.propublica.org/nonprofits/download-xml?object_id=202320899349301857
# 704 https://projects.propublica.org/nonprofits/download-xml?object_id=202221389349301022
# 705 https://projects.propublica.org/nonprofits/download-xml?object_id=202110749349300046
# 706 https://projects.propublica.org/nonprofits/download-xml?object_id=202022669349300022
# 707 https://projects.propublica.org/nonprofits/download-xml?object_id=201932909349301313
# 708 https://projects.propublica.org/nonprofits/download-xml?object_id=201833199349312273
# 709 https://projects.propublica.org/nonprofits/download-xml?object_id=201733569349300623
# 710 https://projects.propublica.org/nonprofits/download-xml?object_id=201633159349303143
# 78 / 83
# 711 https://projects.propublica.org/nonprofits/download-xml?object_id=202233069349302923
# 712 https://projects.propublica.org/nonprofits/download-xml?object_id=202112779349301261
# 713 https://projects.propublica.org/nonprofits/download-xml?object_id=202022379349300717
# 714 https://projects.propublica.org/nonprofits/download-xml?object_id=201902279349302655
# 715 https://projects.propublica.org/nonprofits/download-xml?object_id=201832619349300903
# 716 https://projects.propublica.org/nonprofits/download-xml?object_id=201712499349300236
# 717 https://projects.propublica.org/nonprofits/download-xml?object_id=201602949349300720
# 718 https://projects.propublica.org/nonprofits/download-xml?object_id=201512959349301286
# 719 https://projects.propublica.org/nonprofits/download-xml?object_id=201441899349301019
# 720 https://projects.propublica.org/nonprofits/download-xml?object_id=201302909349300610
# 721 https://projects.propublica.org/nonprofits/download-xml?object_id=201202799349300630
# 722 https://projects.propublica.org/nonprofits/download-xml?object_id=201111949349300421
# 79 / 83
# 723 https://projects.propublica.org/nonprofits/download-xml?object_id=202340839349301104
# 724 https://projects.propublica.org/nonprofits/download-xml?object_id=202213199349329616
# 725 https://projects.propublica.org/nonprofits/download-xml?object_id=202033219349300928
# 726 https://projects.propublica.org/nonprofits/download-xml?object_id=201923199349318877
# 727 https://projects.propublica.org/nonprofits/download-xml?object_id=201823199349320347
# 728 https://projects.propublica.org/nonprofits/download-xml?object_id=201723199349317287
# 729 https://projects.propublica.org/nonprofits/download-xml?object_id=201613209349309136
# 730 https://projects.propublica.org/nonprofits/download-xml?object_id=201502339349300610
# 731 https://projects.propublica.org/nonprofits/download-xml?object_id=201442269349303949
# 732 https://projects.propublica.org/nonprofits/download-xml?object_id=201302269349301925
# 80 / 83
# 733 https://projects.propublica.org/nonprofits/download-xml?object_id=202300769349300130
# 734 https://projects.propublica.org/nonprofits/download-xml?object_id=202221329349304867
# 735 https://projects.propublica.org/nonprofits/download-xml?object_id=202100649349300545
# 736 https://projects.propublica.org/nonprofits/download-xml?object_id=202000709349300040
# 737 https://projects.propublica.org/nonprofits/download-xml?object_id=201920809349300542
# 738 https://projects.propublica.org/nonprofits/download-xml?object_id=201810689349300446
# 739 https://projects.propublica.org/nonprofits/download-xml?object_id=201701329349302285
# 740 https://projects.propublica.org/nonprofits/download-xml?object_id=201631339349302733
# 741 https://projects.propublica.org/nonprofits/download-xml?object_id=201500759349301170
# 742 https://projects.propublica.org/nonprofits/download-xml?object_id=201431139349300913
# 743 https://projects.propublica.org/nonprofits/download-xml?object_id=201320739349301012
# 744 https://projects.propublica.org/nonprofits/download-xml?object_id=201201179349300315
# 745 https://projects.propublica.org/nonprofits/download-xml?object_id=201131329349301888
# 81 / 83
# 746 https://projects.propublica.org/nonprofits/download-xml?object_id=202300989349300325
# 747 https://projects.propublica.org/nonprofits/download-xml?object_id=202240419349300834
# 748 https://projects.propublica.org/nonprofits/download-xml?object_id=202120489349300302
# 749 https://projects.propublica.org/nonprofits/download-xml?object_id=202000379349301270
# 750 https://projects.propublica.org/nonprofits/download-xml?object_id=201910439349300101
# 751 https://projects.propublica.org/nonprofits/download-xml?object_id=201831329349301038
# 752 https://projects.propublica.org/nonprofits/download-xml?object_id=201710409349300001
# 82 / 83
# 753 https://projects.propublica.org/nonprofits/download-xml?object_id=202231369349309063
# 754 https://projects.propublica.org/nonprofits/download-xml?object_id=202131379349304413
# 755 https://projects.propublica.org/nonprofits/download-xml?object_id=201943189349315769
# 756 https://projects.propublica.org/nonprofits/download-xml?object_id=201803179349308550
# 757 https://projects.propublica.org/nonprofits/download-xml?object_id=201743179349307554
# 758 https://projects.propublica.org/nonprofits/download-xml?object_id=201643159349304604
# 759 https://projects.propublica.org/nonprofits/download-xml?object_id=201533499349300823
# 760 https://projects.propublica.org/nonprofits/download-xml?object_id=201133359349300518
# 83 / 83

# %%
info990
# Out:
#                                                     ba        EIN  Tax Year  \
# 0    North County Lifeline Inc\ndba Lifeline Commun...  952794253    2021.0
# 1    North County Lifeline Inc\ndba Lifeline Commun...  952794253    2020.0
# 2                            North County Lifeline Inc  952794253    2019.0
# 3                            North County Lifeline Inc  952794253    2018.0
# 4                            North County Lifeline Inc  952794253    2017.0
# ..                                                 ...        ...       ...
# 756  THE SAN DIEGO LESBIANGAY BISEXUAL\nTRANSGENDER...  237332048    2017.0
# 757  THE SAN DIEGO LESBIANGAY BISEXUAL\nTRANSGENDER...  237332048    2016.0
# 758  THE SAN DIEGO LESBIANGAY BISEXUAL\nTRANSGENDER...  237332048    2015.0
# 759  THE SAN DIEGO LESBIANGAY BISEXUAL\nTRANSGENDER...  237332048    2014.0
# 760                                          Not found  237332048       NaN
#
#     Tax End Date Location (Zipcode) Federate Campaigns Membership Dues  \
# 0     06-30-2022              92084                  0               0
# 1     06-30-2021              92056                  0               0
# 2     06-30-2020              92056                  0               0
# 3     06-30-2019              92056                  0               0
# 4     06-30-2018              92056                  0               0
# ..           ...                ...                ...             ...
# 756   06-30-2018              92163                  0               0
# 757   06-30-2017              92163                  0               0
# 758   06-30-2016              92163                  0               0
# 759   06-30-2015              92163                  0               0
# 760          NaN                  0                  0               0
#
#     Fundraising Events Related Organizations Government Grants  \
# 0                    0                     0          13405575
# 1                    0                     0          13098737
# 2                    0                     0          12446965
# 3                    0                     0          10496439
# 4                    0                     0           9738384
# ..                 ...                   ...               ...
# 756                  0                     0           2618909
# 757                  0                     0           2674347
# 758                  0                     0           2265389
# 759                  0                     0           1807212
# 760                  0                     0                 0
#
#     All Other Contributions Noncash Contributions     Total
# 0                    451714                223226  13857289
# 1                    679469                189639  13778206
# 2                    392396                251569  12839361
# 3                    353245                235480  10849684
# 4                    287018                207107  10025402
# ..                      ...                   ...       ...
# 756                 4786412                     0   7405321
# 757                 4105894                     0   6780241
# 758                 2588997                     0   4854386
# 759                 2867228                     0   4674440
# 760                       0                     0         0
#
# [761 rows x 13 columns]

# %% [markdown]
# ### Checking the missing cells

# %% [markdown]
# The following two cells should both be 1.0.
#
# The first checks the conditional probability that if the name is not found in a row, the tax year wasn't found.
#
# The second checks the inverse conditional probability. Sometimes, if the request attempt tried and failed three times, the row will be entirely empty, where the name is `''` and not `'Not Found'`

# %%
# Every time the name isn't found, nothing is found
info990.loc[info990['ba'] == 'Not found']['Tax Year'].isna().mean()
# Out:
# 1.0

# %%
# And every time the tax year isn't found the name isn't found
(info990[['ba', 'Tax Year']].loc[info990['Tax Year'].isna()]['ba'] == 'Not found').mean()
# Out:
# 1.0

# %% [markdown]
# This cell indicates how many XML files failed to be accessed

# %%
info990['ba'].isna().sum()
# Out:
# 0

# %% [markdown]
# If the following cell returns 0.0, that indicates that every time the tax year is missing, every single financial cell is zero. All of these rows can be dropped and no information is lost.

# %%
info990.loc[info990['Tax Year'].isna(), 'Federate Campaigns':].sum(axis=1).sum()
# Out:
# 0

# %% [markdown]
# ### Cleaning the raw information

# %% [markdown]
# Assuming the prior three checks are all adequate, we can drop rows with any nan values.

# %%
no_error = info990.dropna().reset_index(drop=True)
int_columns = no_error.columns.difference(['ba','Tax End Date'])  # Skip the 'Tax End Date' column
no_error[int_columns] = no_error[int_columns].astype(int)
# create EIN_YEAR column and set it as index
no_error['EIN_YEAR'] = no_error['EIN'].astype(str) + '_' + no_error['Tax Year'].astype(str)
no_error = no_error.set_index('EIN_YEAR')

# %% [markdown]
# ### Export here!

# %% [markdown]
# <b>REMEMBER TO EXPORT</b>
#
# `no_error` is the cleaned dataframe
#
# `info990` is the raw dataframe with missing rows

# %%
no_error.to_csv('no_errors.csv')

# %%
info990.to_csv('full_table.csv')

# %% [markdown]
# The following line appends the rows to the bottom of the existing dataframe titled `'no_errors.csv'` instead.
#
# It creates a new CSV and it is recommended to rename it back to `no_errors.csv` in the case it is exported successfully

# %%
extended = pd.concat([pd.read_csv('no_errors.csv'), no_error]).reset_index(drop=True).drop_duplicates()
extended.to_csv('no_errors_appended.csv')

# %% [markdown]
# ## Testing Zone

# %%
"""
url = 'https://projects.propublica.org/nonprofits/organizations/263405689'
html = scrape_website(url)
soup = BeautifulSoup(html.text)
links = soup.find_all('a', class_='action xml')
base_url = 'https://projects.propublica.org'
urls = [base_url + x.get('href') for x in links if x.text == '990']
"""

# %%
"""
test = [x for x in soup.find_all(class_='action xml') if re.search(r'990\b', x.text)]
test2 = [base_url + x.get('href') if x.name == 'a' else base_url + x.select_one('select.action.xml option[data-href]').get('data-href') for x in test]
"""

# %% [markdown]
# ## Working with our 990 information

# %%
info990
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 info990
#
# NameError: name 'info990' is not defined

# %%
# clean up data
extended = pd.concat([pd.read_csv('no_errors.csv'), no_error]).reset_index(drop=True).drop_duplicates()

# %%
info = pd.read_csv('no_errors.csv')

# %%
info = info.set_index('EIN_YEAR')

# %%
info
# Out:
#                                                                ba        EIN  \
# EIN_YEAR
# 952794253_2021  North County Lifeline Inc\ndba Lifeline Commun...  952794253
# 952794253_2020  North County Lifeline Inc\ndba Lifeline Commun...  952794253
# 952794253_2019                          North County Lifeline Inc  952794253
# 952794253_2018                          North County Lifeline Inc  952794253
# 952794253_2017                          North County Lifeline Inc  952794253
# ...                                                           ...        ...
# 237332048_2018  THE SAN DIEGO LESBIANGAY BISEXUAL\nTRANSGENDER...  237332048
# 237332048_2017  THE SAN DIEGO LESBIANGAY BISEXUAL\nTRANSGENDER...  237332048
# 237332048_2016  THE SAN DIEGO LESBIANGAY BISEXUAL\nTRANSGENDER...  237332048
# 237332048_2015  THE SAN DIEGO LESBIANGAY BISEXUAL\nTRANSGENDER...  237332048
# 237332048_2014  THE SAN DIEGO LESBIANGAY BISEXUAL\nTRANSGENDER...  237332048
#
#                 Tax Year Tax End Date  Location (Zipcode)  Federate Campaigns  \
# EIN_YEAR
# 952794253_2021      2021   06-30-2022               92084                   0
# 952794253_2020      2020   06-30-2021               92056                   0
# 952794253_2019      2019   06-30-2020               92056                   0
# 952794253_2018      2018   06-30-2019               92056                   0
# 952794253_2017      2017   06-30-2018               92056                   0
# ...                  ...          ...                 ...                 ...
# 237332048_2018      2018   06-30-2019               92163                   0
# 237332048_2017      2017   06-30-2018               92163                   0
# 237332048_2016      2016   06-30-2017               92163                   0
# 237332048_2015      2015   06-30-2016               92163                   0
# 237332048_2014      2014   06-30-2015               92163                   0
#
#                 Membership Dues  Fundraising Events  Related Organizations  \
# EIN_YEAR
# 952794253_2021                0                   0                      0
# 952794253_2020                0                   0                      0
# 952794253_2019                0                   0                      0
# 952794253_2018                0                   0                      0
# 952794253_2017                0                   0                      0
# ...                         ...                 ...                    ...
# 237332048_2018                0                   0                      0
# 237332048_2017                0                   0                      0
# 237332048_2016                0                   0                      0
# 237332048_2015                0                   0                      0
# 237332048_2014                0                   0                      0
#
#                 Government Grants  All Other Contributions  \
# EIN_YEAR
# 952794253_2021           13405575                   451714
# 952794253_2020           13098737                   679469
# 952794253_2019           12446965                   392396
# 952794253_2018           10496439                   353245
# 952794253_2017            9738384                   287018
# ...                           ...                      ...
# 237332048_2018            2417854                  4898662
# 237332048_2017            2618909                  4786412
# 237332048_2016            2674347                  4105894
# 237332048_2015            2265389                  2588997
# 237332048_2014            1807212                  2867228
#
#                 Noncash Contributions     Total
# EIN_YEAR
# 952794253_2021                 223226  13857289
# 952794253_2020                 189639  13778206
# 952794253_2019                 251569  12839361
# 952794253_2018                 235480  10849684
# 952794253_2017                 207107  10025402
# ...                               ...       ...
# 237332048_2018                      0   7316516
# 237332048_2017                      0   7405321
# 237332048_2016                      0   6780241
# 237332048_2015                      0   4854386
# 237332048_2014                      0   4674440
#
# [621 rows x 13 columns]

# %% [markdown]
# Find errors in outputted dataset, this will output the ***EIN_YEAR*** values that are outputted incorrectly. The error seems to always be in the ***Fundraising Events*** column

# %%
info_EINerrs = find_errors(no_error)
info_EINerrs

# %%
# EIN_YEARs with errors
info_errs = info[info.index.isin(info_EINerrs)]

# %%
# grabbing EINs that had an error in an EIN_YEAR
EINerrs = [int(err[:-5]) for (err) in info_EINerrs]
EINerrs
# Out:
# [951874073,
#  272917644,
#  952039198,
#  952039198,
#  953302967,
#  571214920,
#  953368020,
#  331146733,
#  263405689,
#  953497926,
#  550806460]

# %% [markdown]
# Correct errors for the ***Fundraising Events*** by using `grabber(errors = True)`

# %%
filtered_info_errs = grabber(EINerrs, verbose=True, errors=True)
# Out:
# 0 / 11
# 0 https://projects.propublica.org/nonprofits/download-xml?object_id=202310589349301711
# 1 https://projects.propublica.org/nonprofits/download-xml?object_id=202240459349300229
# 2 https://projects.propublica.org/nonprofits/download-xml?object_id=202100349349301560
# 3 https://projects.propublica.org/nonprofits/download-xml?object_id=202010449349300941
# 4 https://projects.propublica.org/nonprofits/download-xml?object_id=201920429349301232
# 5 https://projects.propublica.org/nonprofits/download-xml?object_id=201840519349301264
# 6 https://projects.propublica.org/nonprofits/download-xml?object_id=201700879349300610
# 7 https://projects.propublica.org/nonprofits/download-xml?object_id=201612219349301556
# 8 https://projects.propublica.org/nonprofits/download-xml?object_id=201531339349305568
# 9 https://projects.propublica.org/nonprofits/download-xml?object_id=201421219349301317
# 10 https://projects.propublica.org/nonprofits/download-xml?object_id=201310469349302701
# 11 https://projects.propublica.org/nonprofits/download-xml?object_id=201202089349301000
# 12 https://projects.propublica.org/nonprofits/download-xml?object_id=201122109349300347
# 1 / 11
# 13 https://projects.propublica.org/nonprofits/download-xml?object_id=202232909349300938
# 14 https://projects.propublica.org/nonprofits/download-xml?object_id=202142499349300204
# 15 https://projects.propublica.org/nonprofits/download-xml?object_id=202012689349300236
# 16 https://projects.propublica.org/nonprofits/download-xml?object_id=201931639349300028
# 17 https://projects.propublica.org/nonprofits/download-xml?object_id=201801919349300140
# 18 https://projects.propublica.org/nonprofits/download-xml?object_id=201710939349301226
# 19 https://projects.propublica.org/nonprofits/download-xml?object_id=201621329349303557
# 2 / 11
# 20 https://projects.propublica.org/nonprofits/download-xml?object_id=202331189349300303
# 21 https://projects.propublica.org/nonprofits/download-xml?object_id=202221319349303917
# 22 https://projects.propublica.org/nonprofits/download-xml?object_id=202101189349301515
# 23 https://projects.propublica.org/nonprofits/download-xml?object_id=202010589349300236
# 24 https://projects.propublica.org/nonprofits/download-xml?object_id=201940249349301019
# 25 https://projects.propublica.org/nonprofits/download-xml?object_id=201800269349301550
# 26 https://projects.propublica.org/nonprofits/download-xml?object_id=201710269349300021
# 27 https://projects.propublica.org/nonprofits/download-xml?object_id=201640329349300984
# 28 https://projects.propublica.org/nonprofits/download-xml?object_id=201520289349301172
# 29 https://projects.propublica.org/nonprofits/download-xml?object_id=201400239349301215
# 30 https://projects.propublica.org/nonprofits/download-xml?object_id=201320329349300962
# 31 https://projects.propublica.org/nonprofits/download-xml?object_id=201230909349300238
# 32 https://projects.propublica.org/nonprofits/download-xml?object_id=201120329349300712
# 3 / 11
# 33 https://projects.propublica.org/nonprofits/download-xml?object_id=202331189349300303
# 34 https://projects.propublica.org/nonprofits/download-xml?object_id=202221319349303917
# 35 https://projects.propublica.org/nonprofits/download-xml?object_id=202101189349301515
# 36 https://projects.propublica.org/nonprofits/download-xml?object_id=202010589349300236
# 37 https://projects.propublica.org/nonprofits/download-xml?object_id=201940249349301019
# 38 https://projects.propublica.org/nonprofits/download-xml?object_id=201800269349301550
# 39 https://projects.propublica.org/nonprofits/download-xml?object_id=201710269349300021
# 40 https://projects.propublica.org/nonprofits/download-xml?object_id=201640329349300984
# 41 https://projects.propublica.org/nonprofits/download-xml?object_id=201520289349301172
# 42 https://projects.propublica.org/nonprofits/download-xml?object_id=201400239349301215
# 43 https://projects.propublica.org/nonprofits/download-xml?object_id=201320329349300962
# 44 https://projects.propublica.org/nonprofits/download-xml?object_id=201230909349300238
# 45 https://projects.propublica.org/nonprofits/download-xml?object_id=201120329349300712
# 4 / 11
# 46 https://projects.propublica.org/nonprofits/download-xml?object_id=202310489349300246
# 47 https://projects.propublica.org/nonprofits/download-xml?object_id=202211369349314141
# 48 https://projects.propublica.org/nonprofits/download-xml?object_id=202140129349300914
# 49 https://projects.propublica.org/nonprofits/download-xml?object_id=202040419349300829
# 50 https://projects.propublica.org/nonprofits/download-xml?object_id=201910689349300231
# 51 https://projects.propublica.org/nonprofits/download-xml?object_id=201831209349301578
# 52 https://projects.propublica.org/nonprofits/download-xml?object_id=201701329349306405
# 53 https://projects.propublica.org/nonprofits/download-xml?object_id=201741329349306329
# 54 https://projects.propublica.org/nonprofits/download-xml?object_id=201510459349300616
# 55 https://projects.propublica.org/nonprofits/download-xml?object_id=201410439349301271
# 56 https://projects.propublica.org/nonprofits/download-xml?object_id=201331979349300833
# 57 https://projects.propublica.org/nonprofits/download-xml?object_id=201103559349300330
# 58 https://projects.propublica.org/nonprofits/download-xml?object_id=201110189349300306
# 5 / 11
# 59 https://projects.propublica.org/nonprofits/download-xml?object_id=202331379349301638
# 60 https://projects.propublica.org/nonprofits/download-xml?object_id=202220949349300532
# 61 https://projects.propublica.org/nonprofits/download-xml?object_id=202111369349300141
# 62 https://projects.propublica.org/nonprofits/download-xml?object_id=201900809349300545
# 63 https://projects.propublica.org/nonprofits/download-xml?object_id=201821359349312922
# 6 / 11
# 64 https://projects.propublica.org/nonprofits/download-xml?object_id=202213569349301336
# 65 https://projects.propublica.org/nonprofits/download-xml?object_id=202200619349301205
# 66 https://projects.propublica.org/nonprofits/download-xml?object_id=202013159349303941
# 67 https://projects.propublica.org/nonprofits/download-xml?object_id=202030419349301403
# 68 https://projects.propublica.org/nonprofits/download-xml?object_id=201900269349300605
# 69 https://projects.propublica.org/nonprofits/download-xml?object_id=201723179349307002
# 70 https://projects.propublica.org/nonprofits/download-xml?object_id=201741379349300649
# 71 https://projects.propublica.org/nonprofits/download-xml?object_id=201643209349307094
# 7 / 11
# 72 https://projects.propublica.org/nonprofits/download-xml?object_id=202301199349300100
# 73 https://projects.propublica.org/nonprofits/download-xml?object_id=202212309349301596
# 74 https://projects.propublica.org/nonprofits/download-xml?object_id=202142319349301129
# 75 https://projects.propublica.org/nonprofits/download-xml?object_id=202032629349301423
# 76 https://projects.propublica.org/nonprofits/download-xml?object_id=201902919349300140
# 77 https://projects.propublica.org/nonprofits/download-xml?object_id=201812209349300731
# 78 https://projects.propublica.org/nonprofits/download-xml?object_id=201741529349300049
# 79 https://projects.propublica.org/nonprofits/download-xml?object_id=201543209349314609
# 8 / 11
# 80 https://projects.propublica.org/nonprofits/download-xml?object_id=202223189349312202
# 81 https://projects.propublica.org/nonprofits/download-xml?object_id=202102089349301400
# 82 https://projects.propublica.org/nonprofits/download-xml?object_id=202041859349300324
# 83 https://projects.propublica.org/nonprofits/download-xml?object_id=201933189349304303
# 84 https://projects.propublica.org/nonprofits/download-xml?object_id=201801649349300520
# 85 https://projects.propublica.org/nonprofits/download-xml?object_id=201811649349300521
# 86 https://projects.propublica.org/nonprofits/download-xml?object_id=201631379349308783
# 87 https://projects.propublica.org/nonprofits/download-xml?object_id=201511349349308006
# 88 https://projects.propublica.org/nonprofits/download-xml?object_id=201431979349300048
# 9 / 11
# 89 https://projects.propublica.org/nonprofits/download-xml?object_id=202321329349306227
# 90 https://projects.propublica.org/nonprofits/download-xml?object_id=202241369349317829
# 91 https://projects.propublica.org/nonprofits/download-xml?object_id=202140639349301819
# 92 https://projects.propublica.org/nonprofits/download-xml?object_id=202041339349303214
# 93 https://projects.propublica.org/nonprofits/download-xml?object_id=201921359349305402
# 94 https://projects.propublica.org/nonprofits/download-xml?object_id=201821349349310442
# 95 https://projects.propublica.org/nonprofits/download-xml?object_id=201741149349300624
# 96 https://projects.propublica.org/nonprofits/download-xml?object_id=201601349349301395
# 97 https://projects.propublica.org/nonprofits/download-xml?object_id=201511289349301396
# 98 https://projects.propublica.org/nonprofits/download-xml?object_id=201441359349305494
# 99 https://projects.propublica.org/nonprofits/download-xml?object_id=201222059349300532
# 100 https://projects.propublica.org/nonprofits/download-xml?object_id=201132989349300713
# 10 / 11
# 101 https://projects.propublica.org/nonprofits/download-xml?object_id=202320899349301857
# 102 https://projects.propublica.org/nonprofits/download-xml?object_id=202221389349301022
# 103 https://projects.propublica.org/nonprofits/download-xml?object_id=202110749349300046
# 104 https://projects.propublica.org/nonprofits/download-xml?object_id=202022669349300022
# 105 https://projects.propublica.org/nonprofits/download-xml?object_id=201932909349301313
# 106 https://projects.propublica.org/nonprofits/download-xml?object_id=201833199349312273
# 107 https://projects.propublica.org/nonprofits/download-xml?object_id=201733569349300623
# 108 https://projects.propublica.org/nonprofits/download-xml?object_id=201633159349303143
# 11 / 11

# %%
filtered_info_errs
# Out:
#                                       ba        EIN  Tax Year Tax End Date  \
# 0           SAN DIEGO RESCUE MISSION INC  951874073    2021.0   09-30-2022
# 1           SAN DIEGO RESCUE MISSION INC  951874073    2020.0   09-30-2021
# 2           SAN DIEGO RESCUE MISSION INC  951874073    2019.0   09-30-2020
# 3           SAN DIEGO RESCUE MISSION INC  951874073    2018.0   09-30-2019
# 4           SAN DIEGO RESCUE MISSION INC  951874073    2017.0   09-30-2018
# ..                                   ...        ...       ...          ...
# 104  Bilateral Safety Corridor Coalition  550806460    2019.0   12-31-2019
# 105  BILATERAL SAFETY CORRIDOR COALITION  550806460    2018.0   12-31-2018
# 106  Bilateral Safety Corridor Coalition  550806460    2017.0   12-31-2017
# 107  Bilateral Safety Corridor Coalition  550806460    2016.0   12-31-2016
# 108  Bilateral Safety Corridor Coalition  550806460    2015.0   12-31-2015
#
#     Location (Zipcode) Federate Campaigns Membership Dues Fundraising Events  \
# 0                92138                  0               0             155764
# 1                92138                  0               0             142855
# 2                92138                  0               0              50825
# 3                92138                  0               0             297819
# 4                92138                  0               0                  0
# ..                 ...                ...             ...                ...
# 104              91950                  0               0                  0
# 105              91950                  0               0                  0
# 106              91950                  0               0                  0
# 107              91950                  0               0                  0
# 108              91950                  0               0                  0
#
#     Related Organizations Government Grants All Other Contributions  \
# 0                       0                 0                26121296
# 1                       0                 0                21978558
# 2                       0                 0                16540608
# 3                       0                 0                16921789
# 4                       0                 0                17095088
# ..                    ...               ...                     ...
# 104                     0                 0                  269047
# 105                     0                 0                  297479
# 106                     0            171066                  159109
# 107                     0            188786                  236171
# 108                     0            159442                  117018
#
#     Noncash Contributions     Total
# 0                 8271604  26277060
# 1                10039786  22121413
# 2                 7454894  16591433
# 3                 8637829  17219608
# 4                 9929227  17095088
# ..                    ...       ...
# 104                     0    269047
# 105                     0    297479
# 106                     0    330175
# 107                     0    424957
# 108                     0    276460
#
# [109 rows x 13 columns]

# %% [markdown]
# Drop NaN values, create an *EIN_YEAR* column, and set it as index

# %%
info_no_errors = filtered_info_errs.dropna().reset_index(drop=True)
int_columns = info_no_errors.columns.difference(['ba','Tax End Date'])  # Skip the 'Tax End Date' column
info_no_errors[int_columns] = info_no_errors[int_columns].astype(int)
info_no_errors['EIN_YEAR'] = info_no_errors['EIN'].astype(str) + '_' + info_no_errors['Tax Year'].astype(str)
info_no_errors = info_no_errors.set_index('EIN_YEAR')
info_no_errors
# Out:
#                                                  ba        EIN  Tax Year  \
# EIN_YEAR
# 951874073_2021         SAN DIEGO RESCUE MISSION INC  951874073      2021
# 951874073_2020         SAN DIEGO RESCUE MISSION INC  951874073      2020
# 951874073_2019         SAN DIEGO RESCUE MISSION INC  951874073      2019
# 951874073_2018         SAN DIEGO RESCUE MISSION INC  951874073      2018
# 951874073_2017         SAN DIEGO RESCUE MISSION INC  951874073      2017
# ...                                             ...        ...       ...
# 550806460_2019  Bilateral Safety Corridor Coalition  550806460      2019
# 550806460_2018  BILATERAL SAFETY CORRIDOR COALITION  550806460      2018
# 550806460_2017  Bilateral Safety Corridor Coalition  550806460      2017
# 550806460_2016  Bilateral Safety Corridor Coalition  550806460      2016
# 550806460_2015  Bilateral Safety Corridor Coalition  550806460      2015
#
#                Tax End Date  Location (Zipcode)  Federate Campaigns  \
# EIN_YEAR
# 951874073_2021   09-30-2022               92138                   0
# 951874073_2020   09-30-2021               92138                   0
# 951874073_2019   09-30-2020               92138                   0
# 951874073_2018   09-30-2019               92138                   0
# 951874073_2017   09-30-2018               92138                   0
# ...                     ...                 ...                 ...
# 550806460_2019   12-31-2019               91950                   0
# 550806460_2018   12-31-2018               91950                   0
# 550806460_2017   12-31-2017               91950                   0
# 550806460_2016   12-31-2016               91950                   0
# 550806460_2015   12-31-2015               91950                   0
#
#                 Membership Dues  Fundraising Events  Related Organizations  \
# EIN_YEAR
# 951874073_2021                0              155764                      0
# 951874073_2020                0              142855                      0
# 951874073_2019                0               50825                      0
# 951874073_2018                0              297819                      0
# 951874073_2017                0                   0                      0
# ...                         ...                 ...                    ...
# 550806460_2019                0                   0                      0
# 550806460_2018                0                   0                      0
# 550806460_2017                0                   0                      0
# 550806460_2016                0                   0                      0
# 550806460_2015                0                   0                      0
#
#                 Government Grants  All Other Contributions  \
# EIN_YEAR
# 951874073_2021                  0                 26121296
# 951874073_2020                  0                 21978558
# 951874073_2019                  0                 16540608
# 951874073_2018                  0                 16921789
# 951874073_2017                  0                 17095088
# ...                           ...                      ...
# 550806460_2019                  0                   269047
# 550806460_2018                  0                   297479
# 550806460_2017             171066                   159109
# 550806460_2016             188786                   236171
# 550806460_2015             159442                   117018
#
#                 Noncash Contributions     Total
# EIN_YEAR
# 951874073_2021                8271604  26277060
# 951874073_2020               10039786  22121413
# 951874073_2019                7454894  16591433
# 951874073_2018                8637829  17219608
# 951874073_2017                9929227  17095088
# ...                               ...       ...
# 550806460_2019                      0    269047
# 550806460_2018                      0    297479
# 550806460_2017                      0    330175
# 550806460_2016                      0    424957
# 550806460_2015                      0    276460
#
# [90 rows x 13 columns]

# %%
find_errors(info_no_errors)
# Out:
# ('951874073_2015',)

# %% [markdown]
# The EIN_YEAR '951874073_2015' has an error we found manually so we're just going to set the 'Fundraising Events' value to 0

# %%
info_no_errors.loc['951874073_2015', 'Fundraising Events'] = 0
find_errors(info_no_errors)
# Out:
# ()

# %%
info_no_errors.to_csv('info_no_errors.csv')

# %% [markdown]
# ## EIN Dataset

# %%
info = pd.read_csv('no_errors.csv')
info_no_errors = pd.read_csv('info_no_errors.csv')

# %% [markdown]
# Replace errors with corrected data in    *info_no_errors*    by using `replace_corrected_data_and_standardize`

# %%
info_copy = info.copy()
info_no_errors_copy = info_no_errors.copy()

info_copy.rename(columns={'ba': 'Organization Name'}, inplace=True)
info_no_errors_copy.rename(columns={'ba': 'Organization Name'}, inplace=True)

EIN_dataset_df = replace_corrected_data_and_standardize(info_copy, info_no_errors_copy)

EIN_dataset_df.set_index('EIN_YEAR', inplace=True)
EIN_dataset_df = EIN_dataset_df.drop('index',axis=1)
EIN_dataset_df
# Out:
#                                                 Organization Name        EIN  \
# EIN_YEAR
# 952794253_2021  NORTH COUNTY LIFELINE INC DBA LIFELINE COMMUNI...  952794253
# 952794253_2020  NORTH COUNTY LIFELINE INC DBA LIFELINE COMMUNI...  952794253
# 952794253_2019                          NORTH COUNTY LIFELINE INC  952794253
# 952794253_2018                          NORTH COUNTY LIFELINE INC  952794253
# 952794253_2017                          NORTH COUNTY LIFELINE INC  952794253
# ...                                                           ...        ...
# 237332048_2018  THE SAN DIEGO LESBIANGAY BISEXUAL TRANSGENDER ...  237332048
# 237332048_2017  THE SAN DIEGO LESBIANGAY BISEXUAL TRANSGENDER ...  237332048
# 237332048_2016  THE SAN DIEGO LESBIANGAY BISEXUAL TRANSGENDER ...  237332048
# 237332048_2015  THE SAN DIEGO LESBIANGAY BISEXUAL TRANSGENDER ...  237332048
# 237332048_2014  THE SAN DIEGO LESBIANGAY BISEXUAL TRANSGENDER ...  237332048
#
#                 Tax Year Tax End Date  Location (Zipcode)  Federate Campaigns  \
# EIN_YEAR
# 952794253_2021      2021   06-30-2022               92084                   0
# 952794253_2020      2020   06-30-2021               92056                   0
# 952794253_2019      2019   06-30-2020               92056                   0
# 952794253_2018      2018   06-30-2019               92056                   0
# 952794253_2017      2017   06-30-2018               92056                   0
# ...                  ...          ...                 ...                 ...
# 237332048_2018      2018   06-30-2019               92163                   0
# 237332048_2017      2017   06-30-2018               92163                   0
# 237332048_2016      2016   06-30-2017               92163                   0
# 237332048_2015      2015   06-30-2016               92163                   0
# 237332048_2014      2014   06-30-2015               92163                   0
#
#                 Membership Dues  Fundraising Events  Related Organizations  \
# EIN_YEAR
# 952794253_2021                0                   0                      0
# 952794253_2020                0                   0                      0
# 952794253_2019                0                   0                      0
# 952794253_2018                0                   0                      0
# 952794253_2017                0                   0                      0
# ...                         ...                 ...                    ...
# 237332048_2018                0                   0                      0
# 237332048_2017                0                   0                      0
# 237332048_2016                0                   0                      0
# 237332048_2015                0                   0                      0
# 237332048_2014                0                   0                      0
#
#                 Government Grants  All Other Contributions  \
# EIN_YEAR
# 952794253_2021           13405575                   451714
# 952794253_2020           13098737                   679469
# 952794253_2019           12446965                   392396
# 952794253_2018           10496439                   353245
# 952794253_2017            9738384                   287018
# ...                           ...                      ...
# 237332048_2018            2417854                  4898662
# 237332048_2017            2618909                  4786412
# 237332048_2016            2674347                  4105894
# 237332048_2015            2265389                  2588997
# 237332048_2014            1807212                  2867228
#
#                 Noncash Contributions     Total  Philanthropic_Total
# EIN_YEAR
# 952794253_2021                 223226  13857289               451714
# 952794253_2020                 189639  13778206               679469
# 952794253_2019                 251569  12839361               392396
# 952794253_2018                 235480  10849684               353245
# 952794253_2017                 207107  10025402               287018
# ...                               ...       ...                  ...
# 237332048_2018                      0   7316516              4898662
# 237332048_2017                      0   7405321              4786412
# 237332048_2016                      0   6780241              4105894
# 237332048_2015                      0   4854386              2588997
# 237332048_2014                      0   4674440              2867228
#
# [621 rows x 14 columns]

# %%
EIN_dataset_df.to_csv('EIN_dataset.csv')

# %% [markdown]
# ## Getting Manual Pull Rows that aren't included in the Scraped Data

# %% [markdown]
# Not all 990 years have an XML file attached for the earlier years, but they were recorded in the manual pull so we can access those years from the manual pull and merge that data into our current dataset

# %%
# Manually inputted Tax End Year for the eins in 'pull_these' into the downloaded csv
raw_manual_pull = pd.read_csv('990 Manual Pull - Tax End Date.csv')
raw_manual_pull.set_index('EIN_YEAR',inplace=True)
raw_manual_pull
# Out:
#                                                  ba          EIN  Tax Year  \
# EIN_YEAR
# 113723093_2015  Regional Task Force on the Homeless  113723093.0    2015.0
# 113723093_2016  Regional Task Force on the Homeless  113723093.0    2016.0
# 113723093_2018  Regional Task Force on the Homeless  113723093.0    2018.0
# 113723093_2019  Regional Task Force on the Homeless  113723093.0    2019.0
# 113723093_2020  Regional Task Force on the Homeless  113723093.0    2020.0
# ...                                             ...          ...       ...
# 571214920_2020         Operation Hope North County   571214920.0    2020.0
# 571162424_2021          Kingdom Causes dba City Net  571162424.0    2021.0
# NaN                                             NaN          NaN       NaN
# NaN                                             NaN          NaN       NaN
# NaN                                             NaN          NaN       NaN
#
#                Tax End Date  Location (Zipcode) Federate Campaigns  \
# EIN_YEAR
# 113723093_2015          NaN             92123.0                  0
# 113723093_2016          NaN             92123.0                  0
# 113723093_2018          NaN             92123.0                  0
# 113723093_2019          NaN             92123.0                  0
# 113723093_2020          NaN             92123.0                  0
# ...                     ...                 ...                ...
# 571214920_2020          NaN             92084.0                  0
# 571162424_2021          NaN             90807.0              89250
# NaN                     NaN                 NaN     $35,571,906.00
# NaN                     NaN                 NaN                NaN
# NaN                     NaN                 NaN                NaN
#
#                Membership Dues Fundraising Events Related Organizations  \
# EIN_YEAR
# 113723093_2015               0                  0                     0
# 113723093_2016            6677                  0                     0
# 113723093_2018               0                  0                     0
# 113723093_2019               0                  0                     0
# 113723093_2020               0                  0                     0
# ...                        ...                ...                   ...
# 571214920_2020               0                  0                     0
# 571162424_2021               0                  0                     0
# NaN                 $47,967.00     $19,229,327.00        $23,349,134.00
# NaN                        NaN                NaN                   NaN
# NaN                        NaN                NaN                   NaN
#
#                 Government Grants  \
# EIN_YEAR
# 113723093_2015            1110060
# 113723093_2016            1922156
# 113723093_2018            2505451
# 113723093_2019            9344677
# 113723093_2020           17841834
# ...                           ...
# 571214920_2020             422615
# 571162424_2021             429733
# NaN             $3,384,170,346.00
# NaN                           NaN
# NaN                           NaN
#
#                All Other Contributions gifts, grants and similar amounts not included above  \
# EIN_YEAR
# 113723093_2015                                              47330
# 113723093_2016                                              65214
# 113723093_2018                                             865020
# 113723093_2019                                             182239
# 113723093_2020                                             183535
# ...                                                           ...
# 571214920_2020                                             692114
# 571162424_2021                                             790394
# NaN                                               $759,399,657.00
# NaN                                                           NaN
# NaN                                                           NaN
#
#                Noncash constributions included in lines 1a - 1f  \
# EIN_YEAR
# 113723093_2015                                                0
# 113723093_2016                                                0
# 113723093_2018                                                0
# 113723093_2019                                                0
# 113723093_2020                                                0
# ...                                                         ...
# 571214920_2020                                                0
# 571162424_2021                                            27870
# NaN                                             $218,330,487.00
# NaN                                                         NaN
# NaN                                                         NaN
#
#                            Total  Type  Unnamed: 14 Unnamed: 15  Unnamed: 16
# EIN_YEAR
# 113723093_2015            1157390    A    1157390.0        True          0.0
# 113723093_2016            1994047    A    1994047.0        True          0.0
# 113723093_2018            3370471    A    3370471.0        True          0.0
# 113723093_2019            9526916    A    9526916.0        True          0.0
# 113723093_2020           18025369    A   18025369.0        True          0.0
# ...                           ...  ...          ...         ...          ...
# 571214920_2020            1114729  NaN    1114729.0        True          NaN
# 571162424_2021            1309377  NaN    1309377.0        True          NaN
# NaN             $4,230,190,126.00  NaN          NaN         NaN          NaN
# NaN               $846,019,780.00  NaN          NaN         NaN          NaN
# NaN               $120,859,968.57  NaN          NaN         NaN          NaN
#
# [351 rows x 17 columns]

# %%
# drop rows that have NaN EIN values
manual_pull = raw_manual_pull[raw_manual_pull.get('Type') == 'A'].dropna(thresh=1).dropna(subset=['EIN']).drop(['Type'], axis=1)
manual_pull
# Out:
#                                                  ba          EIN  Tax Year  \
# EIN_YEAR
# 113723093_2015  Regional Task Force on the Homeless  113723093.0    2015.0
# 113723093_2016  Regional Task Force on the Homeless  113723093.0    2016.0
# 113723093_2018  Regional Task Force on the Homeless  113723093.0    2018.0
# 113723093_2019  Regional Task Force on the Homeless  113723093.0    2019.0
# 113723093_2020  Regional Task Force on the Homeless  113723093.0    2020.0
# ...                                             ...          ...       ...
# 270447059_2018               Dreams for Change Inc.  270447059.0    2018.0
# 270447059_2019               Dreams for Change Inc.  270447059.0    2019.0
# 270447059_2020               Dreams for Change Inc.  270447059.0    2020.0
# 330210280_2019                               UPLIFT  330210280.0    2019.0
# 822363154_2019        Voices of Our City Choir Inc.  822363154.0    2019.0
#
#                Tax End Date  Location (Zipcode) Federate Campaigns  \
# EIN_YEAR
# 113723093_2015          NaN             92123.0                  0
# 113723093_2016          NaN             92123.0                  0
# 113723093_2018          NaN             92123.0                  0
# 113723093_2019          NaN             92123.0                  0
# 113723093_2020          NaN             92123.0                  0
# ...                     ...                 ...                ...
# 270447059_2018          NaN             92176.0                  0
# 270447059_2019          NaN             92176.0                  0
# 270447059_2020          NaN             92176.0                  0
# 330210280_2019          NaN             92102.0                  0
# 822363154_2019   12-31-2019             92112.0                  0
#
#                Membership Dues Fundraising Events Related Organizations  \
# EIN_YEAR
# 113723093_2015               0                  0                     0
# 113723093_2016            6677                  0                     0
# 113723093_2018               0                  0                     0
# 113723093_2019               0                  0                     0
# 113723093_2020               0                  0                     0
# ...                        ...                ...                   ...
# 270447059_2018               0                  0                     0
# 270447059_2019               0                  0                     0
# 270447059_2020               0                  0                     0
# 330210280_2019               0              36547                     0
# 822363154_2019               0                  0                     0
#
#                Government Grants  \
# EIN_YEAR
# 113723093_2015           1110060
# 113723093_2016           1922156
# 113723093_2018           2505451
# 113723093_2019           9344677
# 113723093_2020          17841834
# ...                          ...
# 270447059_2018            345041
# 270447059_2019            600504
# 270447059_2020            717584
# 330210280_2019                 0
# 822363154_2019                 0
#
#                All Other Contributions gifts, grants and similar amounts not included above  \
# EIN_YEAR
# 113723093_2015                                              47330
# 113723093_2016                                              65214
# 113723093_2018                                             865020
# 113723093_2019                                             182239
# 113723093_2020                                             183535
# ...                                                           ...
# 270447059_2018                                             492397
# 270447059_2019                                             421536
# 270447059_2020                                             434903
# 330210280_2019                                             192704
# 822363154_2019                                             237154
#
#                Noncash constributions included in lines 1a - 1f    Total   \
# EIN_YEAR
# 113723093_2015                                                0   1157390
# 113723093_2016                                                0   1994047
# 113723093_2018                                                0   3370471
# 113723093_2019                                                0   9526916
# 113723093_2020                                                0  18025369
# ...                                                         ...       ...
# 270447059_2018                                                0    837438
# 270447059_2019                                                0   1022040
# 270447059_2020                                                0   1152487
# 330210280_2019                                                0    229251
# 822363154_2019                                                0    237154
#
#                 Unnamed: 14 Unnamed: 15  Unnamed: 16
# EIN_YEAR
# 113723093_2015    1157390.0        True          0.0
# 113723093_2016    1994047.0        True          0.0
# 113723093_2018    3370471.0        True          0.0
# 113723093_2019    9526916.0        True          0.0
# 113723093_2020   18025369.0        True          0.0
# ...                     ...         ...          ...
# 270447059_2018     837438.0        True          NaN
# 270447059_2019    1022040.0        True          NaN
# 270447059_2020    1152487.0        True          NaN
# 330210280_2019     229251.0        True          NaN
# 822363154_2019     237154.0        True          NaN
#
# [320 rows x 16 columns]

# %% [markdown]
# *EIN_YEAR*s that are in the manual pull but weren't pulled by XML and need to be added to our dataset

# %%
pull_these = list(manual_pull.index.difference(EIN_dataset_df.index))
pull_these
# Out:
# ['330006089_2015',
#  '330433314_2015',
#  '330433314_2016',
#  '330433314_2017',
#  '330433314_2018',
#  '330602842_2015',
#  '330602842_2016',
#  '330602842_2017',
#  '330602842_2018',
#  '330602842_2019',
#  '465055513_2016',
#  '465055513_2017',
#  '562613191_2015',
#  '562613191_2016',
#  '941676390_2016',
#  '941676390_2017',
#  '941676390_2018',
#  '941676390_2019',
#  '952111196_2015',
#  '952850121_2015',
#  '952850121_2016']

# %%
to_pull = np.unique([ein[:-5] for ein in pull_these])
to_pull
# Out:
# array(['330006089', '330433314', '330602842', '465055513', '562613191',
#        '941676390', '952111196', '952850121'], dtype='<U9')

# %% [markdown]
# Fill ***not_scraped*** with the manual pull data for the ***pull_these*** EIN values

# %%
not_scraped = manual_pull.loc[pull_these]
not_scraped['EIN'] = [int(ein) for ein in not_scraped['EIN']]
not_scraped['Tax Year'] = [int(year) for year in not_scraped['Tax Year']]
not_scraped['Location (Zipcode)'] = [int(loc) for loc in not_scraped['Location (Zipcode)']]
not_scraped = not_scraped.drop(['Unnamed: 14','Unnamed: 15','Unnamed: 16'],axis=1).reset_index()
not_scraped
# Out:
#           EIN_YEAR                                                 ba  \
# 0   330006089_2015               Deaf Community Services of San Diego
# 1   330433314_2015                National Conflict Resolution Center
# 2   330433314_2016                National Conflict Resolution Center
# 3   330433314_2017                National Conflict Resolution Center
# 4   330433314_2018                National Conflict Resolution Center
# 5   330602842_2015        Association for Community Housing Solutions
# 6   330602842_2016        Association for Community Housing Solutions
# 7   330602842_2017        Association for Community Housing Solutions
# 8   330602842_2018        Association for Community Housing Solutions
# 9   330602842_2019        Association for Community Housing Solutions
# 10  465055513_2016                                Urban Street Angels
# 11  465055513_2017                                Urban Street Angels
# 12  562613191_2015  STRONG HEARTED NATIVE WOMEN'S COALITION, INCOR...
# 13  562613191_2016  STRONG HEARTED NATIVE WOMEN'S COALITION, INCOR...
# 14  941676390_2016              California Indian Legal Services Inc.
# 15  941676390_2017              California Indian Legal Services Inc.
# 16  941676390_2018              California Indian Legal Services Inc.
# 17  941676390_2019              California Indian Legal Services Inc.
# 18  952111196_2015                    ST. PAUL'S EPISCOPAL HOME, INC.
# 19  952850121_2015                                    Serving Seniors
# 20  952850121_2016                                    Serving Seniors
#
#           EIN  Tax Year Tax End Date  Location (Zipcode) Federate Campaigns  \
# 0   330006089      2015    6-30-2016               92108               3270
# 1   330433314      2015    6-30-2016               92101                  0
# 2   330433314      2016    6-30-2017               92101                  0
# 3   330433314      2017    6-30-2018               92101                  0
# 4   330433314      2018    6-30-2019               92101                  0
# 5   330602842      2015   12-31-2015               92123                  0
# 6   330602842      2016   12-31-2016               92123                  0
# 7   330602842      2017   12-31-2017               92123                  0
# 8   330602842      2018   12-31-2018               92123                  0
# 9   330602842      2019   12-31-2019               92123                  0
# 10  465055513      2016   12-31-2016               92101                  0
# 11  465055513      2017   12-31-2017               92101                  0
# 12  562613191      2015    6-30-2016               92082                  0
# 13  562613191      2016    6-30-2017               92082                  0
# 14  941676390      2016   12-31-2016               92025                  0
# 15  941676390      2017   12-31-2017               92025                  0
# 16  941676390      2018   12-31-2018               92025                  0
# 17  941676390      2019   12-31-2019               92025                  0
# 18  952111196      2015    8-31-2016               92013                  0
# 19  952850121      2015    6-30-2016               92101                  0
# 20  952850121      2016    6-30-2017               92101                  0
#
#    Membership Dues Fundraising Events Related Organizations Government Grants  \
# 0                0                  0                     0           1329774
# 1                0                  0                     0            851714
# 2                0                  0                     0            806892
# 3                0                  0                     0           1514007
# 4                0                  0                     0           1265617
# 5                0                  0                     0           1237593
# 6                0                  0                     0           1485908
# 7                0                  0                     0           1564629
# 8                0                  0                     0           1610341
# 9                0                  0                     0           1527348
# 10               0              41551                     0            155681
# 11               0              31109                     0             26250
# 12               0                  0                     0            727969
# 13               0                  0                     0            726300
# 14               0                  0                     0           1562588
# 15               0                  0                     0           2029571
# 16               0                  0                     0           1819928
# 17               0                  0                     0           1765110
# 18               0                  0               2297041            590897
# 19               0                  0                     0           3119195
# 20               0             325000                     0           3245708
#
#    All Other Contributions gifts, grants and similar amounts not included above  \
# 0                                               61532
# 1                                             1076360
# 2                                             1300903
# 3                                             1231820
# 4                                             1689439
# 5                                                 454
# 6                                                1212
# 7                                                1120
# 8                                                5416
# 9                                                8561
# 10                                             100940
# 11                                             349708
# 12                                               1957
# 13                                               2800
# 14                                             103148
# 15                                             126194
# 16                                              73318
# 17                                             174234
# 18                                             894547
# 19                                            1727053
# 20                                            1210887
#
#    Noncash constributions included in lines 1a - 1f   Total
# 0                                                 0  1394576
# 1                                                 0  1928074
# 2                                                 0  2107795
# 3                                                 0  2745827
# 4                                                 0  2955056
# 5                                                 0  1238047
# 6                                                 0  1487120
# 7                                                 0  1565749
# 8                                                 0  1615757
# 9                                                 0  1535909
# 10                                                0   298172
# 11                                                0   407067
# 12                                                0   729926
# 13                                                0   729100
# 14                                                0  1665736
# 15                                                0  2155765
# 16                                                0  1893246
# 17                                                0  1939344
# 18                                           884493  3782485
# 19                                            96540  4846248
# 20                                                0  4781595

# %% [markdown]
# Rename columns and export

# %%
not_scraped.columns = ['EIN_YEAR','Organization Name', 'EIN', 'Tax Year', 'Tax End Date','Location (Zipcode)', 'Federate Campaigns', 'Membership Dues', \
                       'Fundraising Events', 'Related Organizations', 'Government Grants', 'All Other Contributions', \
                       'Noncash Contributions', 'Total']

int_columns = not_scraped.columns.difference(['Organization Name','EIN_YEAR', 'Tax End Date'])  # Skip the 'Tax End Date' column
not_scraped[int_columns] = not_scraped[int_columns].apply(pd.to_numeric, errors='coerce')
not_scraped.set_index('EIN_YEAR', inplace = True)
not_scraped.to_csv('not_scraped.csv')

# %% [markdown]
# Add ***not_scraped*** to our ***EIN_dataset_df*** for our full dataset

# %%
phil_df = pd.concat([EIN_dataset_df, not_scraped])
phil_df.sort_values(by='EIN_YEAR', inplace=True)
phil_df
# Out:
#                                       Organization Name        EIN  Tax Year  \
# EIN_YEAR
# 113723093_2014  REGIONAL TASK FORCE ON THE HOMELESS INC  113723093      2014
# 113723093_2015      REGIONAL TASK FORCE ON THE HOMELESS  113723093      2015
# 113723093_2016      REGIONAL TASK FORCE ON THE HOMELESS  113723093      2016
# 113723093_2017      REGIONAL TASK FORCE ON THE HOMELESS  113723093      2017
# 113723093_2018      REGIONAL TASK FORCE ON THE HOMELESS  113723093      2018
# ...                                                 ...        ...       ...
# 956379598_2017           CENTER FOR COMMUNITY SOLUTIONS  956379598      2017
# 956379598_2018           CENTER FOR COMMUNITY SOLUTIONS  956379598      2018
# 956379598_2019           CENTER FOR COMMUNITY SOLUTIONS  956379598      2019
# 956379598_2020           CENTER FOR COMMUNITY SOLUTIONS  956379598      2020
# 956379598_2021           CENTER FOR COMMUNITY SOLUTIONS  956379598      2021
#
#                Tax End Date  Location (Zipcode)  Federate Campaigns  \
# EIN_YEAR
# 113723093_2014   06-30-2015               92123                   0
# 113723093_2015   06-30-2016               92123                   0
# 113723093_2016   06-30-2017               92123                   0
# 113723093_2017   06-30-2018               92123                   0
# 113723093_2018   06-30-2019               92123                   0
# ...                     ...                 ...                 ...
# 956379598_2017   06-30-2018               92109                   0
# 956379598_2018   06-30-2019               92109                   0
# 956379598_2019   06-30-2020               92109                   0
# 956379598_2020   06-30-2021               92109                   0
# 956379598_2021   06-30-2022               92109                   0
#
#                 Membership Dues  Fundraising Events  Related Organizations  \
# EIN_YEAR
# 113723093_2014                0                   0                      0
# 113723093_2015                0                   0                      0
# 113723093_2016             6677                   0                      0
# 113723093_2017                0                   0                      0
# 113723093_2018                0                   0                      0
# ...                         ...                 ...                    ...
# 956379598_2017                0              286098                      0
# 956379598_2018                0              431150                      0
# 956379598_2019                0              169778                      0
# 956379598_2020                0              493759                      0
# 956379598_2021                0              463831                      0
#
#                 Government Grants  All Other Contributions  \
# EIN_YEAR
# 113723093_2014             991765                    94796
# 113723093_2015            1110060                    47330
# 113723093_2016            1922156                    65214
# 113723093_2017            2021667                   738875
# 113723093_2018            2505451                   865020
# ...                           ...                      ...
# 956379598_2017            4101800                   719296
# 956379598_2018            4702859                   731655
# 956379598_2019            4963840                   943753
# 956379598_2020            4983768                  1295828
# 956379598_2021            5516946                   850877
#
#                 Noncash Contributions    Total  Philanthropic_Total
# EIN_YEAR
# 113723093_2014                      0  1086561              94796.0
# 113723093_2015                      0  1157390              47330.0
# 113723093_2016                      0  1994047              71891.0
# 113723093_2017                      0  2760542             738875.0
# 113723093_2018                      0  3370471             865020.0
# ...                               ...      ...                  ...
# 956379598_2017                  35080  5107194            1005394.0
# 956379598_2018                  33999  5865664            1162805.0
# 956379598_2019                  50456  6077371            1113531.0
# 956379598_2020                  21422  6773355            1789587.0
# 956379598_2021                  16256  6831654            1314708.0
#
# [642 rows x 14 columns]

# %%
phil_df.to_csv('Phil Dataset.csv')

# %% [markdown]
# ## Parsing dataset by month

# %%
data = pd.read_csv('Phil Dataset.csv')

# %% [markdown]
# Add rows for each month

# %%
# Convert 'Tax End Date' column to datetime format
data['Tax End Date'] = pd.to_datetime(data['Tax End Date'])

# Apply the function to each row and expand the DataFrame
expanded_data_fiscal_year = data.apply(distribute_values_fiscal_year, axis=1)
expanded_data_fiscal_year = pd.DataFrame([item for sublist in expanded_data_fiscal_year for item in sublist])

# Save the expanded data to a new CSV file
expanded_data_fiscal_year = expanded_data_fiscal_year.drop_duplicates()
expanded_data_fiscal_year.to_csv('Phil Dataset - Analysis.csv')
# Out:
#            EIN_YEAR                        Organization Name        EIN  \
# 0    113723093_2014  REGIONAL TASK FORCE ON THE HOMELESS INC  113723093
# 0    113723093_2014  REGIONAL TASK FORCE ON THE HOMELESS INC  113723093
# 0    113723093_2014  REGIONAL TASK FORCE ON THE HOMELESS INC  113723093
# 0    113723093_2014  REGIONAL TASK FORCE ON THE HOMELESS INC  113723093
# 0    113723093_2014  REGIONAL TASK FORCE ON THE HOMELESS INC  113723093
# ..              ...                                      ...        ...
# 641  956379598_2021           CENTER FOR COMMUNITY SOLUTIONS  956379598
# 641  956379598_2021           CENTER FOR COMMUNITY SOLUTIONS  956379598
# 641  956379598_2021           CENTER FOR COMMUNITY SOLUTIONS  956379598
# 641  956379598_2021           CENTER FOR COMMUNITY SOLUTIONS  956379598
# 641  956379598_2021           CENTER FOR COMMUNITY SOLUTIONS  956379598
#
#      Tax Year Tax End Date  Location (Zipcode)  Federate Campaigns  \
# 0        2014   07-31-2014               92123                   0
# 0        2014   08-31-2014               92123                   0
# 0        2014   09-30-2014               92123                   0
# 0        2014   10-31-2014               92123                   0
# 0        2014   11-30-2014               92123                   0
# ..        ...          ...                 ...                 ...
# 641      2021   02-28-2022               92109                   0
# 641      2021   03-31-2022               92109                   0
# 641      2021   04-30-2022               92109                   0
# 641      2021   05-31-2022               92109                   0
# 641      2021   06-30-2022               92109                   0
#
#      Membership Dues  Fundraising Events  Related Organizations  \
# 0                0.0            0.000000                    0.0
# 0                0.0            0.000000                    0.0
# 0                0.0            0.000000                    0.0
# 0                0.0            0.000000                    0.0
# 0                0.0            0.000000                    0.0
# ..               ...                 ...                    ...
# 641              0.0        38652.583333                    0.0
# 641              0.0        38652.583333                    0.0
# 641              0.0        38652.583333                    0.0
# 641              0.0        38652.583333                    0.0
# 641              0.0        38652.583333                    0.0
#
#      Government Grants  All Other Contributions  Noncash Contributions  \
# 0         82647.083333              7899.666667               0.000000
# 0         82647.083333              7899.666667               0.000000
# 0         82647.083333              7899.666667               0.000000
# 0         82647.083333              7899.666667               0.000000
# 0         82647.083333              7899.666667               0.000000
# ..                 ...                      ...                    ...
# 641      459745.500000             70906.416667            1354.666667
# 641      459745.500000             70906.416667            1354.666667
# 641      459745.500000             70906.416667            1354.666667
# 641      459745.500000             70906.416667            1354.666667
# 641      459745.500000             70906.416667            1354.666667
#
#          Total  Philanthropic_Total
# 0     90546.75          7899.666667
# 0     90546.75          7899.666667
# 0     90546.75          7899.666667
# 0     90546.75          7899.666667
# 0     90546.75          7899.666667
# ..         ...                  ...
# 641  569304.50        109559.000000
# 641  569304.50        109559.000000
# 641  569304.50        109559.000000
# 641  569304.50        109559.000000
# 641  569304.50        109559.000000
#
# [7704 rows x 15 columns]
