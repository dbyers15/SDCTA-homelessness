# %%
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET
import requests
from bs4 import BeautifulSoup
import time
import lxml
import re

# %% [markdown]
# # Parsing XML Files from ProPublica
#
# Last updated: 6/1/23 by Christopher Lum

# %% [markdown]
# ### Methods

# %% [markdown]
# `scrape_website(url, attempts=0)`
# - Takes a URL and returns the response object if successful. Retries three times on failure
#
# `info_grabber(fp, url=True)`
# - Takes the URL/filepath of an XML file. The `url` parameter indicates whether the given filepath is a URL or local
# - Returns a dictionary of the row information for section VIII (along with a couple other columns)
# - Older (prior to 2013) XML files have different tags and thus can't be read. Results in a row of all zeroes and `'Not Found'` in the `ba` column
# - Of successfully scraped columns, has ~1.5% error rate for rows (0.13% of cells are inaccurate), only in the `Fundraising Events` column due to inconsistent labeling in XMLs
#     - This error rate is lower than the human error rate
# - In 2013, they had a different way of tagging zip codes, so all 2013 zips will be 0
#
# `contact_grabber(fp, url=True)`
# - Returns a dataframe of each contact in the 990 form, according to section VII
# - Incomplete and edge cases aren't tested fully, as we didn't need the function.
#
# `get_xmls(ein)`
# - Takes the EIN of a company and returns a list of the URLs for each XML file that is linked on the ProPublica page for that given company
#
# `grabber(eins, verbose=False, clean=False)`
# - Takes a list of EINs and uses `get_xmls()` to find each XML file, then uses `info_grabber()` to scrape each XML for the relevant information.
# - Returns a pandas DataFrame, doesn't automatically save as csv.
# - Takes around 22 minutes on my laptop for 71 businesses
# - The `clean` parameter automatically cleans the dataframe by removing empty rows
#
# `find_errors(info)`
# - Data columns are supposed to add up to the total, if it doesn't this method will find it
# - Takes a dataframe of 990 rows from `grabber` and returns a tuple of incides that didn't properly grab all of the data
#     - Preferably indiced on `EIN_YEAR`

# %% [markdown]
# #### `scrape_website`

# %%
def scrape_website(url, attempts=0):
    # Send GET request to the website
    response = requests.get(url)
    time.sleep(1)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        if attempts > 0:
            print('Success')
        return response
    elif attempts < 3:
        print("Error:", response.status_code, "Trying again.")
        time.sleep(1)
        return scrape_website(url, attempts + 1)
    else:
        # Handle the request error
        print("Error: ", response.status_code, 'Failed on:', url)
        return None

# %% [markdown]
# #### `info_grabber`

# %%
def info_grabber(fp, url=True, errors=False):
    if url:
        xml = scrape_website(fp)
        xml.encoding = 'UTF-8'
        xml = xml.text.strip()
    else:
        try:
            with open(fp, 'r') as file:
                xml = file.read()
        except FileNotFoundError:
            print(f"File not found: {fp}")
            return dict()
    if xml is None:
        return dict()
    
    soup = BeautifulSoup(xml, 'xml')

    row = dict()
    row['ba'] = soup.find('BusinessName')
    row['EIN'] = soup.find('EIN')
    row['Tax Year'] = soup.find('TaxPeriodBeginDt')
    row['Location (Zipcode)'] = soup.find('USAddress')
    row['Federate Campaigns'] = soup.find('FederatedCampaignsAmt')
    row['Membership Dues'] = soup.find('MembershipDuesAmt')
    row['Fundraising Events'] = soup.find('ContriRptFundraisingEventAmt')
    
    row['Related Organizations'] = soup.find('RelatedOrganizationsAmt')
    row['Government Grants'] = soup.find('GovernmentGrantsAmt')
    row['All Other Contributions'] = soup.find('AllOtherContributionsAmt')
    row['Noncash Contributions'] = soup.find('NoncashContributionsAmt')
    row['Total'] = soup.find('TotalContributionsAmt')
    # Can make default=0

    if row['Location (Zipcode)'] is not None:
        row['Location (Zipcode)'] = row['Location (Zipcode)'].find('ZIPCd')
    else:
        row['Location (Zipcode)'] = None

    row = dict(map(lambda item: (item[0], item[1].text if item[1] is not None else None), row.items()))

    if row['ba'] is not None:
        row['ba'] = row['ba'].strip()
    else:
        row['ba'] = 'Not found'
    if row['Tax Year'] is not None:
        row['Tax Year'] = pd.Timestamp(row['Tax Year']).year
    else:
        row['Tax Year'] = np.nan
    
    if errors:
        sumKeys = ['Federate Campaigns', 'Membership Dues', 'Related Organizations', 'Government Grants', 'All Other Contributions']
        sumAmt = sum(float(row[key]) for key in sumKeys if key in row and row[key] is not None)
        fundAmt_element = soup.find('FundraisingAmt')
        fundAmt = int(fundAmt_element.text) if fundAmt_element is not None else 0
        sumAmt += fundAmt

        if sumAmt is None or row['Total'] is None:
            pass
        elif int(sumAmt) == int(row['Total']):
            row['Fundraising Events'] = fundAmt
        else:
            pass

    row = dict(map(lambda item: (item[0], item[1] if item[1] is not None else 0), row.items()))

    return row

# %% [markdown]
# #### `contact_grabber`

# %% [markdown]
# Old, might not work

# %%
def contact_grabber(fp, url=True):
    '''
    Return a dataframe of the important names and their positions in an organization for each year

    :param fp: filepath of the xml file
    :param url: Whether the fp is a url or not. Default = True
    '''
    if url:
        xml = scrape_website(fp)
    else:
        xml = requests.get(fp)
    if xml is None:
        return dict()
    xml.encoding = 'UTF-8'
    xml = xml.text.strip()
    soup = BeautifulSoup(xml, 'xml')

    people = soup.find_all('Form990PartVIISectionAGrp')
    names = [x.find('PersonNm').text for x in people if x.find('PersonNm') is not None]
    titles = [x.find('TitleTxt').text for x in people if x.find('TitleTxt') is not None]
    try:
        organization = [soup.find('BusinessName').text.strip()] * len(names)
    except AttributeError:
        organization = ['Not found'] * len(names)
    try:
        year = [pd.Timestamp(soup.find('TaxPeriodBeginDt').text).year] * len(names)
    except AttributeError:
        year = [0] * len(names)
        
    return pd.DataFrame({'organization': organization, 'year': year, 'names': names, 'titles': titles})

# %% [markdown]
# #### `get_xmls`

# %%
def get_xmls(ein):
    '''
    Return a list of xml urls from ProRepublica based on an organization's EIN

    :param ein: Employer Identification number as String or Int
    '''
    url = f'https://projects.propublica.org/nonprofits/organizations/{ein}'
    html = scrape_website(url)
    if html is None:
        return []
    soup = BeautifulSoup(html.text)
    links = soup.find_all('a', class_='action xml')
    base_url = 'https://projects.propublica.org'
    # urls = [base_url + x.get('href') for x in links if x.text == '990']
    urls = [x for x in soup.find_all(class_='action xml') if re.search(r'990\b', x.text)]
    urls = [base_url + x.get('href') if x.name == 'a' else base_url + x.select_one('select.action.xml option[data-href]').get('data-href') for x in urls]
    return urls

# %% [markdown]
# #### `grabber`

# %%
def grabber(eins, verbose=False, clean=False, errors=False):
    if type(eins) == int:
        eins = [eins]
    data = []
    # contacts = pd.DataFrame()
    overall_index = 0
    for index, ein in enumerate(eins):
        print(str(index) + (' / ') + str(len(eins)))
        xmls = get_xmls(ein)
        for xml in xmls:
            if verbose:
                print(f'{overall_index} {xml}')
            if errors:
                data.append(info_grabber(xml,errors=True))
            else:
                data.append(info_grabber(xml))
            #contacts = pd.concat([contacts, contact_grabber(xml)])
            overall_index += 1
    print(str(len(eins)) + (' / ') + str(len(eins)))
    info = pd.DataFrame(data)
    if not clean:
        return info

    no_error = info.dropna().reset_index(drop=True)
    no_error.loc[:, 'EIN':'Total'] = no_error.loc[:, 'EIN':'Total'].astype(int)
    no_error.loc[:, 'EIN_YEAR'] = no_error['EIN'].astype(str) + '_' + no_error['Tax Year'].astype(str)
    no_error = no_error.set_index('EIN_YEAR')

    return no_error

# %% [markdown]
# #### `find_errors`

# %%
def find_errors(info):
    '''
    Takes a dataframe of 990 rows and returns a tuple of the indices where it failed to grab the data properly

    :param info: The dataframe of 990 rows
    '''
    accurate = info[['Federate Campaigns', 'Membership Dues', 'Fundraising Events', 'Related Organizations', 'Government Grants', 'All Other Contributions']].sum(axis=1) == info['Total']
    return tuple(accurate[~accurate].index)

# %% [markdown]
# ### Using the `grabber()` method

# %% [markdown]
# `grabber()` takes a list of EINs. This was curated from the old "990 Manual Pull" spreadsheet by pasting and splitting the entire `EIN` column and putting it into a set.

# %%
all_eins = '''113723093
113723093
113723093
113723093
113723093
237279074
237279074
237279074
237279074
237279074
237334012
237334012
237334012
237334012
237334012
261712580
261712580
261712580
261712580
261712580
261712580
330006089
330006089
330006089
330006089
330215585
330215585
330215585
330215585
330215585
330317950
330317950
330317950
330317950
330433314
330433314
330433314
330433314
330433314
330492304
330492304
330492304
330492304
330492304
330496092
330496092
330496092
330496092
330623634
330623634
330623634
330623634
330623634
331029843
331029843
331029843
331029843
331146733
331146733
331146733
331146733
465055513
465055513
465055513
465055513
942358632
942358632
942358632
942358632
942358632
951644024
951644024
951644024
951644024
951869806
951869806
951869806
951869806
951869806
951869806
951874073
951874073
951874073
951874073
951874073
951874073
951944230
951944230
951944230
951944230
951944230
952039198
952039198
952039198
952039198
952157559
952157559
952157559
952157559
952157559
952648050
952648050
952648050
952648050
952648050
952648050
952653869
952653869
952653869
952653869
952653869
952833205
952833205
952833205
952833205
952833205
952850121
952850121
952850121
952850121
952850121
952880426
952880426
952880426
952880426
952880426
953244085
953244085
953244085
953244085
953244085
953248148
953248148
953248148
953248148
953248148
953302967
953302967
953302967
953302967
953302967
953302967
953315571
953315571
953315571
953315571
953315571
953649525
953649525
953649525
953649525
956379598
956379598
956379598
956379598
953497926
953497926
953497926
953497926
953497926
953497926
953837714
953837714
953837714
953837714
953837714
953140767
953140767
953140767
953140767
951648184
951648184
951648184
951648184
951648184
952693142
952693142
952693142
952693142
952693142
330217339
330217339
330217339
330217339
330217339
330217339
952794253
952794253
952794253
952794253
952794253
952794253
951945256
951945256
951945256
951945256
951945256
270865318
270865318
270865318
270865318
270865318
331146733
331146733
331146733
331146733
331146733
821946283
821946283
263405689
263405689
263405689
263405689
263405689
# 22 https://projects.propublica.org/nonprofits/download-xml?object_id=202301309349302465
# 23 https://projects.propublica.org/nonprofits/download-xml?object_id=202230769349301413
# 24 https://projects.propublica.org/nonprofits/download-xml?object_id=202140639349300834
# 25 https://projects.propublica.org/nonprofits/download-xml?object_id=202030099349300143
# 26 https://projects.propublica.org/nonprofits/download-xml?object_id=201900289349301270
# 27 https://projects.propublica.org/nonprofits/download-xml?object_id=201830409349301138
# 28 https://projects.propublica.org/nonprofits/download-xml?object_id=201740449349302579
# 29 https://projects.propublica.org/nonprofits/download-xml?object_id=201600439349303235
# 30 https://projects.propublica.org/nonprofits/download-xml?object_id=201500659349300210
# 31 https://projects.propublica.org/nonprofits/download-xml?object_id=201400349349300740
# 32 https://projects.propublica.org/nonprofits/download-xml?object_id=201340329349301009
# 33 https://projects.propublica.org/nonprofits/download-xml?object_id=201140189349300219
# 3 / 71
# 34 https://projects.propublica.org/nonprofits/download-xml?object_id=202310589349301711
# 35 https://projects.propublica.org/nonprofits/download-xml?object_id=202240459349300229
# 36 https://projects.propublica.org/nonprofits/download-xml?object_id=202100349349301560
# 37 https://projects.propublica.org/nonprofits/download-xml?object_id=202010449349300941
# 38 https://projects.propublica.org/nonprofits/download-xml?object_id=201920429349301232
# 39 https://projects.propublica.org/nonprofits/download-xml?object_id=201840519349301264
# 40 https://projects.propublica.org/nonprofits/download-xml?object_id=201700879349300610
# 41 https://projects.propublica.org/nonprofits/download-xml?object_id=201612219349301556
# 42 https://projects.propublica.org/nonprofits/download-xml?object_id=201531339349305568
# 43 https://projects.propublica.org/nonprofits/download-xml?object_id=201421219349301317
# 44 https://projects.propublica.org/nonprofits/download-xml?object_id=201310469349302701
# 45 https://projects.propublica.org/nonprofits/download-xml?object_id=201202089349301000
# 46 https://projects.propublica.org/nonprofits/download-xml?object_id=201122109349300347
# 4 / 71
# 47 https://projects.propublica.org/nonprofits/download-xml?object_id=202243489349301124
# 48 https://projects.propublica.org/nonprofits/download-xml?object_id=202143269349301334
# 49 https://projects.propublica.org/nonprofits/download-xml?object_id=202013579349300631
# 50 https://projects.propublica.org/nonprofits/download-xml?object_id=201923549349300542
# 51 https://projects.propublica.org/nonprofits/download-xml?object_id=201910649349300026
# 52 https://projects.propublica.org/nonprofits/download-xml?object_id=201743499349301374
# 53 https://projects.propublica.org/nonprofits/download-xml?object_id=201603209349309550
# 54 https://projects.propublica.org/nonprofits/download-xml?object_id=201503179349306455
# 55 https://projects.propublica.org/nonprofits/download-xml?object_id=201413189349309751
# 56 https://projects.propublica.org/nonprofits/download-xml?object_id=201302949349300725
# 57 https://projects.propublica.org/nonprofits/download-xml?object_id=201223259349300812
# 58 https://projects.propublica.org/nonprofits/download-xml?object_id=201133439349300703
# 59 https://projects.propublica.org/nonprofits/download-xml?object_id=201100329349301010
# 5 / 71
# 60 https://projects.propublica.org/nonprofits/download-xml?object_id=202321319349306387
# 61 https://projects.propublica.org/nonprofits/download-xml?object_id=202231319349303538
# 62 https://projects.propublica.org/nonprofits/download-xml?object_id=202130969349300643
# 63 https://projects.propublica.org/nonprofits/download-xml?object_id=202041299349300934
# 64 https://projects.propublica.org/nonprofits/download-xml?object_id=201900729349300635
# 65 https://projects.propublica.org/nonprofits/download-xml?object_id=201300979349300400
# 6 / 71
# 66 https://projects.propublica.org/nonprofits/download-xml?object_id=202340129349303669
# 67 https://projects.propublica.org/nonprofits/download-xml?object_id=202103409349300930
# 68 https://projects.propublica.org/nonprofits/download-xml?object_id=202043179349308559
# 69 https://projects.propublica.org/nonprofits/download-xml?object_id=201913199349310236
# 70 https://projects.propublica.org/nonprofits/download-xml?object_id=201940219349300434
# 71 https://projects.propublica.org/nonprofits/download-xml?object_id=201600269349300760
# 7 / 71
# 72 https://projects.propublica.org/nonprofits/download-xml?object_id=202232459349300923
# 73 https://projects.propublica.org/nonprofits/download-xml?object_id=202132379349300918
# 74 https://projects.propublica.org/nonprofits/download-xml?object_id=202043159349304559
# 75 https://projects.propublica.org/nonprofits/download-xml?object_id=201903169349306315
# 76 https://projects.propublica.org/nonprofits/download-xml?object_id=201812719349300441
# 77 https://projects.propublica.org/nonprofits/download-xml?object_id=201702969349301395
# 78 https://projects.propublica.org/nonprofits/download-xml?object_id=201622249349301597
# 79 https://projects.propublica.org/nonprofits/download-xml?object_id=201522409349300627
# 80 https://projects.propublica.org/nonprofits/download-xml?object_id=201442939349300324
# 81 https://projects.propublica.org/nonprofits/download-xml?object_id=201313169349303846
# 82 https://projects.propublica.org/nonprofits/download-xml?object_id=201203199349306350
# 83 https://projects.propublica.org/nonprofits/download-xml?object_id=201123199349310862
# 8 / 71
# 84 https://projects.propublica.org/nonprofits/download-xml?object_id=202232219349301203
# 85 https://projects.propublica.org/nonprofits/download-xml?object_id=202141049349301424
# 86 https://projects.propublica.org/nonprofits/download-xml?object_id=202020739349301002
# 87 https://projects.propublica.org/nonprofits/download-xml?object_id=201920849349301507
# 88 https://projects.propublica.org/nonprofits/download-xml?object_id=201821219349301477
# 89 https://projects.propublica.org/nonprofits/download-xml?object_id=201731799349300028
# 90 https://projects.propublica.org/nonprofits/download-xml?object_id=201611359349301251
# 91 https://projects.propublica.org/nonprofits/download-xml?object_id=201541949349300819
# 9 / 71
# 92 https://projects.propublica.org/nonprofits/download-xml?object_id=202341119349301419
# 93 https://projects.propublica.org/nonprofits/download-xml?object_id=202211239349301641
# 94 https://projects.propublica.org/nonprofits/download-xml?object_id=202032749349300628
# 10 / 71
# 95 https://projects.propublica.org/nonprofits/download-xml?object_id=202311159349300301
# 96 https://projects.propublica.org/nonprofits/download-xml?object_id=202241089349300824
# 97 https://projects.propublica.org/nonprofits/download-xml?object_id=202101109349300840
# 98 https://projects.propublica.org/nonprofits/download-xml?object_id=202020739349300702
# 99 https://projects.propublica.org/nonprofits/download-xml?object_id=201941309349301444
# 100 https://projects.propublica.org/nonprofits/download-xml?object_id=201830649349300853
# 101 https://projects.propublica.org/nonprofits/download-xml?object_id=201740459349301999
# 102 https://projects.propublica.org/nonprofits/download-xml?object_id=201640469349302904
# 103 https://projects.propublica.org/nonprofits/download-xml?object_id=201520489349301277
# 104 https://projects.propublica.org/nonprofits/download-xml?object_id=201420499349301722
# 105 https://projects.propublica.org/nonprofits/download-xml?object_id=201300389349300005
# 106 https://projects.propublica.org/nonprofits/download-xml?object_id=201200819349300610
# 107 https://projects.propublica.org/nonprofits/download-xml?object_id=201100459349301135
# 11 / 71
# 108 https://projects.propublica.org/nonprofits/download-xml?object_id=202201309349304960
# 109 https://projects.propublica.org/nonprofits/download-xml?object_id=202121349349305352
# 110 https://projects.propublica.org/nonprofits/download-xml?object_id=202001399349300845
# 111 https://projects.propublica.org/nonprofits/download-xml?object_id=201932949349300228
# 112 https://projects.propublica.org/nonprofits/download-xml?object_id=201821309349303792
# 113 https://projects.propublica.org/nonprofits/download-xml?object_id=201643549349300649
# 114 https://projects.propublica.org/nonprofits/download-xml?object_id=201523579349300322
# 115 https://projects.propublica.org/nonprofits/download-xml?object_id=201511149349300116
# 116 https://projects.propublica.org/nonprofits/download-xml?object_id=201400309349300120
# 117 https://projects.propublica.org/nonprofits/download-xml?object_id=201213199349304261
# 118 https://projects.propublica.org/nonprofits/download-xml?object_id=201201249349300815
# 119 https://projects.propublica.org/nonprofits/download-xml?object_id=201100839349300115
# 12 / 71
# 120 https://projects.propublica.org/nonprofits/download-xml?object_id=202301309349305605
# 121 https://projects.propublica.org/nonprofits/download-xml?object_id=202230749349301558
# 122 https://projects.propublica.org/nonprofits/download-xml?object_id=202101059349301630
# 123 https://projects.propublica.org/nonprofits/download-xml?object_id=202010349349300126
# 124 https://projects.propublica.org/nonprofits/download-xml?object_id=201901149349301370
# 125 https://projects.propublica.org/nonprofits/download-xml?object_id=201820329349302062
# 126 https://projects.propublica.org/nonprofits/download-xml?object_id=201730459349302858
# 127 https://projects.propublica.org/nonprofits/download-xml?object_id=201641179349300044
# 128 https://projects.propublica.org/nonprofits/download-xml?object_id=201541339349305214
# 129 https://projects.propublica.org/nonprofits/download-xml?object_id=201441339349304659
# 130 https://projects.propublica.org/nonprofits/download-xml?object_id=201320459349302322
# 13 / 71
# 131 https://projects.propublica.org/nonprofits/download-xml?object_id=202231329349307723
# 132 https://projects.propublica.org/nonprofits/download-xml?object_id=202002939349300685
# 133 https://projects.propublica.org/nonprofits/download-xml?object_id=202031779349300148
# 134 https://projects.propublica.org/nonprofits/download-xml?object_id=201901339349305115
# 135 https://projects.propublica.org/nonprofits/download-xml?object_id=201703389349300415
# 136 https://projects.propublica.org/nonprofits/download-xml?object_id=201710629349300321
# 137 https://projects.propublica.org/nonprofits/download-xml?object_id=201600129349300520
# 14 / 71
# 138 https://projects.propublica.org/nonprofits/download-xml?object_id=202340559349301554
# 139 https://projects.propublica.org/nonprofits/download-xml?object_id=202200559349301665
# 140 https://projects.propublica.org/nonprofits/download-xml?object_id=202120499349300842
# 141 https://projects.propublica.org/nonprofits/download-xml?object_id=201933129349303383
# 142 https://projects.propublica.org/nonprofits/download-xml?object_id=201822299349300642
# 143 https://projects.propublica.org/nonprofits/download-xml?object_id=201712419349300236
# 185 https://projects.propublica.org/nonprofits/download-xml?object_id=201613559349300771
# 186 https://projects.propublica.org/nonprofits/download-xml?object_id=201630429349302213
# 20 / 71
# 187 https://projects.propublica.org/nonprofits/download-xml?object_id=202243559349300224
# 188 https://projects.propublica.org/nonprofits/download-xml?object_id=202103199349328120
# 189 https://projects.propublica.org/nonprofits/download-xml?object_id=202002539349301195
# 190 https://projects.propublica.org/nonprofits/download-xml?object_id=201942059349301014
# 191 https://projects.propublica.org/nonprofits/download-xml?object_id=201802419349300235
# 192 https://projects.propublica.org/nonprofits/download-xml?object_id=201713179349302491
# 193 https://projects.propublica.org/nonprofits/download-xml?object_id=201633209349306243
# 194 https://projects.propublica.org/nonprofits/download-xml?object_id=201512889349301466
# 195 https://projects.propublica.org/nonprofits/download-xml?object_id=201443219349304499
# 21 / 71
# 196 https://projects.propublica.org/nonprofits/download-xml?object_id=202231749349301418
# 197 https://projects.propublica.org/nonprofits/download-xml?object_id=202131959349300828
# 198 https://projects.propublica.org/nonprofits/download-xml?object_id=202041959349302419
# 199 https://projects.propublica.org/nonprofits/download-xml?object_id=201901969349302410
# 200 https://projects.propublica.org/nonprofits/download-xml?object_id=201831789349300143
# 201 https://projects.propublica.org/nonprofits/download-xml?object_id=201601979349301000
# 202 https://projects.propublica.org/nonprofits/download-xml?object_id=201531969349302018
# 203 https://projects.propublica.org/nonprofits/download-xml?object_id=201421889349300487
# 204 https://projects.propublica.org/nonprofits/download-xml?object_id=201311969349301051
# 205 https://projects.propublica.org/nonprofits/download-xml?object_id=201231929349300248
# 206 https://projects.propublica.org/nonprofits/download-xml?object_id=201121899349300422
# 22 / 71
# 207 https://projects.propublica.org/nonprofits/download-xml?object_id=202211329349308361
# 208 https://projects.propublica.org/nonprofits/download-xml?object_id=202102519349300545
# 23 / 71
# 209 https://projects.propublica.org/nonprofits/download-xml?object_id=202311239349302956
# 210 https://projects.propublica.org/nonprofits/download-xml?object_id=202201309349302825
# 211 https://projects.propublica.org/nonprofits/download-xml?object_id=202131269349301773
# 212 https://projects.propublica.org/nonprofits/download-xml?object_id=202041719349301489
# 213 https://projects.propublica.org/nonprofits/download-xml?object_id=201920149349301167
# 214 https://projects.propublica.org/nonprofits/download-xml?object_id=201840129349301019
# 215 https://projects.propublica.org/nonprofits/download-xml?object_id=201741329349306744
# 216 https://projects.propublica.org/nonprofits/download-xml?object_id=201601349349305305
# 217 https://projects.propublica.org/nonprofits/download-xml?object_id=201521339349305167
# 218 https://projects.propublica.org/nonprofits/download-xml?object_id=201440279349300889
# 219 https://projects.propublica.org/nonprofits/download-xml?object_id=201330919349300318
# 220 https://projects.propublica.org/nonprofits/download-xml?object_id=201111259349301576
# 24 / 71
# 221 https://projects.propublica.org/nonprofits/download-xml?object_id=202223189349312322
# 222 https://projects.propublica.org/nonprofits/download-xml?object_id=202133169349305108
# 223 https://projects.propublica.org/nonprofits/download-xml?object_id=202043109349302219
# 224 https://projects.propublica.org/nonprofits/download-xml?object_id=201943179349306554
# 225 https://projects.propublica.org/nonprofits/download-xml?object_id=201842989349301039
# 267 https://projects.propublica.org/nonprofits/download-xml?object_id=201131329349301888
# 28 / 71
# 268 https://projects.propublica.org/nonprofits/download-xml?object_id=202321319349306632
# 269 https://projects.propublica.org/nonprofits/download-xml?object_id=202222089349300212
# 270 https://projects.propublica.org/nonprofits/download-xml?object_id=202111469349300911
# 271 https://projects.propublica.org/nonprofits/download-xml?object_id=202042549349301854
# 272 https://projects.propublica.org/nonprofits/download-xml?object_id=201911349349308321
# 273 https://projects.propublica.org/nonprofits/download-xml?object_id=201842269349302384
# 274 https://projects.propublica.org/nonprofits/download-xml?object_id=201712059349300346
# 275 https://projects.propublica.org/nonprofits/download-xml?object_id=201602289349305545
# 276 https://projects.propublica.org/nonprofits/download-xml?object_id=201502339349300520
# 277 https://projects.propublica.org/nonprofits/download-xml?object_id=201431359349305868
# 278 https://projects.propublica.org/nonprofits/download-xml?object_id=201333179349304958
# 29 / 71
# 279 https://projects.propublica.org/nonprofits/download-xml?object_id=202213569349301336
# 280 https://projects.propublica.org/nonprofits/download-xml?object_id=202200619349301205
# 281 https://projects.propublica.org/nonprofits/download-xml?object_id=202013159349303941
# 282 https://projects.propublica.org/nonprofits/download-xml?object_id=202030419349301403
# 283 https://projects.propublica.org/nonprofits/download-xml?object_id=201900269349300605
# 284 https://projects.propublica.org/nonprofits/download-xml?object_id=201723179349307002
# 285 https://projects.propublica.org/nonprofits/download-xml?object_id=201741379349300649
# 286 https://projects.propublica.org/nonprofits/download-xml?object_id=201643209349307094
# 30 / 71
# 287 https://projects.propublica.org/nonprofits/download-xml?object_id=202232459349301428
# 288 https://projects.propublica.org/nonprofits/download-xml?object_id=202112949349302301
# 289 https://projects.propublica.org/nonprofits/download-xml?object_id=202022629349300747
# 290 https://projects.propublica.org/nonprofits/download-xml?object_id=201932529349301163
# 291 https://projects.propublica.org/nonprofits/download-xml?object_id=201822329349301072
# 292 https://projects.propublica.org/nonprofits/download-xml?object_id=201701999349300140
# 293 https://projects.propublica.org/nonprofits/download-xml?object_id=201602189349301250
# 294 https://projects.propublica.org/nonprofits/download-xml?object_id=201512329349301051
# 295 https://projects.propublica.org/nonprofits/download-xml?object_id=201412599349300806
# 296 https://projects.propublica.org/nonprofits/download-xml?object_id=201321339349304822
# 297 https://projects.propublica.org/nonprofits/download-xml?object_id=201242559349300804
# 298 https://projects.propublica.org/nonprofits/download-xml?object_id=201143129349300944
# 31 / 71
# 299 https://projects.propublica.org/nonprofits/download-xml?object_id=202233069349302923
# 300 https://projects.propublica.org/nonprofits/download-xml?object_id=202112779349301261
# 301 https://projects.propublica.org/nonprofits/download-xml?object_id=202022379349300717
# 302 https://projects.propublica.org/nonprofits/download-xml?object_id=201902279349302655
# 303 https://projects.propublica.org/nonprofits/download-xml?object_id=201832619349300903
# 304 https://projects.propublica.org/nonprofits/download-xml?object_id=201712499349300236
# 305 https://projects.propublica.org/nonprofits/download-xml?object_id=201602949349300720
# 306 https://projects.propublica.org/nonprofits/download-xml?object_id=201512959349301286
# 307 https://projects.propublica.org/nonprofits/download-xml?object_id=201441899349301019
# 390 https://projects.propublica.org/nonprofits/download-xml?object_id=201400239349301215
# 391 https://projects.propublica.org/nonprofits/download-xml?object_id=201320329349300962
# 392 https://projects.propublica.org/nonprofits/download-xml?object_id=201230909349300238
# 393 https://projects.propublica.org/nonprofits/download-xml?object_id=201120329349300712
# 41 / 71
# 394 https://projects.propublica.org/nonprofits/download-xml?object_id=202301359349316195
# 395 https://projects.propublica.org/nonprofits/download-xml?object_id=202232109349301663
# 396 https://projects.propublica.org/nonprofits/download-xml?object_id=202140429349300029
# 397 https://projects.propublica.org/nonprofits/download-xml?object_id=202001339349300630
# 398 https://projects.propublica.org/nonprofits/download-xml?object_id=201941069349300329
# 399 https://projects.propublica.org/nonprofits/download-xml?object_id=201800449349301180
# 400 https://projects.propublica.org/nonprofits/download-xml?object_id=201700419349301365
# 401 https://projects.propublica.org/nonprofits/download-xml?object_id=201621239349300442
# 402 https://projects.propublica.org/nonprofits/download-xml?object_id=201530339349301108
# 403 https://projects.propublica.org/nonprofits/download-xml?object_id=201341649349300314
# 404 https://projects.propublica.org/nonprofits/download-xml?object_id=201231679349300823
# 405 https://projects.propublica.org/nonprofits/download-xml?object_id=201110749349300331
# 42 / 71
# 406 https://projects.propublica.org/nonprofits/download-xml?object_id=202210809349300966
# 407 https://projects.propublica.org/nonprofits/download-xml?object_id=202121099349301417
# 408 https://projects.propublica.org/nonprofits/download-xml?object_id=202010669349301306
# 409 https://projects.propublica.org/nonprofits/download-xml?object_id=201842969349300634
# 410 https://projects.propublica.org/nonprofits/download-xml?object_id=201841289349300714
# 411 https://projects.propublica.org/nonprofits/download-xml?object_id=201731319349305573
# 412 https://projects.propublica.org/nonprofits/download-xml?object_id=201621339349303402
# 43 / 71
# 413 https://projects.propublica.org/nonprofits/download-xml?object_id=202203159349307235
# 414 https://projects.propublica.org/nonprofits/download-xml?object_id=202113199349316051
# 44 / 71
# 415 https://projects.propublica.org/nonprofits/download-xml?object_id=202232169349301903
# 416 https://projects.propublica.org/nonprofits/download-xml?object_id=202141759349300919
# 417 https://projects.propublica.org/nonprofits/download-xml?object_id=202012209349300431
# 418 https://projects.propublica.org/nonprofits/download-xml?object_id=201912209349300341
# 419 https://projects.propublica.org/nonprofits/download-xml?object_id=201842199349301264
# 420 https://projects.propublica.org/nonprofits/download-xml?object_id=201702269349301270
# 421 https://projects.propublica.org/nonprofits/download-xml?object_id=201622239349302537
# 422 https://projects.propublica.org/nonprofits/download-xml?object_id=201512259349303656
# 423 https://projects.propublica.org/nonprofits/download-xml?object_id=201432259349300643
# 424 https://projects.propublica.org/nonprofits/download-xml?object_id=201312269349303311
# 425 https://projects.propublica.org/nonprofits/download-xml?object_id=201222279349304012
# 426 https://projects.propublica.org/nonprofits/download-xml?object_id=201112289349300891
# 45 / 71
# 427 https://projects.propublica.org/nonprofits/download-xml?object_id=202213139349301966
# 428 https://projects.propublica.org/nonprofits/download-xml?object_id=202103139349304345
# 429 https://projects.propublica.org/nonprofits/download-xml?object_id=202043189349313114
# 634 https://projects.propublica.org/nonprofits/download-xml?object_id=201520439349301752
# 635 https://projects.propublica.org/nonprofits/download-xml?object_id=201410179349300521
# 636 https://projects.propublica.org/nonprofits/download-xml?object_id=201330669349300723
# 68 / 71
# 637 https://projects.propublica.org/nonprofits/download-xml?object_id=202301329349305680
# 638 https://projects.propublica.org/nonprofits/download-xml?object_id=202201269349303180
# 639 https://projects.propublica.org/nonprofits/download-xml?object_id=202101349349307850
# 640 https://projects.propublica.org/nonprofits/download-xml?object_id=202031149349300423
# 641 https://projects.propublica.org/nonprofits/download-xml?object_id=201911349349304506
# 642 https://projects.propublica.org/nonprofits/download-xml?object_id=201840619349301029
# 643 https://projects.propublica.org/nonprofits/download-xml?object_id=201721329349303792
# 644 https://projects.propublica.org/nonprofits/download-xml?object_id=201601349349300245
# 645 https://projects.propublica.org/nonprofits/download-xml?object_id=201531049349300043
# 646 https://projects.propublica.org/nonprofits/download-xml?object_id=201400509349300220
# 647 https://projects.propublica.org/nonprofits/download-xml?object_id=201330889349300118
# 648 https://projects.propublica.org/nonprofits/download-xml?object_id=201231999349300043
# 649 https://projects.propublica.org/nonprofits/download-xml?object_id=201121299349302002
# 69 / 71
# 650 https://projects.propublica.org/nonprofits/download-xml?object_id=202320899349301857
# 651 https://projects.propublica.org/nonprofits/download-xml?object_id=202221389349301022
# 652 https://projects.propublica.org/nonprofits/download-xml?object_id=202110749349300046
# 653 https://projects.propublica.org/nonprofits/download-xml?object_id=202022669349300022
# 654 https://projects.propublica.org/nonprofits/download-xml?object_id=201932909349301313
# 655 https://projects.propublica.org/nonprofits/download-xml?object_id=201833199349312273
# 656 https://projects.propublica.org/nonprofits/download-xml?object_id=201733569349300623
# 657 https://projects.propublica.org/nonprofits/download-xml?object_id=201633159349303143
# 70 / 71
# 658 https://projects.propublica.org/nonprofits/download-xml?object_id=202311289349304461
# 659 https://projects.propublica.org/nonprofits/download-xml?object_id=202200249349300655
# 660 https://projects.propublica.org/nonprofits/download-xml?object_id=202043509349301814
# 661 https://projects.propublica.org/nonprofits/download-xml?object_id=202010309349300426
# 662 https://projects.propublica.org/nonprofits/download-xml?object_id=201910119349301201
# 663 https://projects.propublica.org/nonprofits/download-xml?object_id=201713139349302751
# 664 https://projects.propublica.org/nonprofits/download-xml?object_id=201720409349301452
# 665 https://projects.propublica.org/nonprofits/download-xml?object_id=201533139349303293
# 666 https://projects.propublica.org/nonprofits/download-xml?object_id=201510629349300041
# 667 https://projects.propublica.org/nonprofits/download-xml?object_id=201313229349300836
# 668 https://projects.propublica.org/nonprofits/download-xml?object_id=201243549349300119
# 71 / 71

# %% [markdown]
# ### Checking the missing cells

# %% [markdown]
# The following two cells should both be 1.0.
#
# The first checks the conditional probability that if the name is not found in a row, the tax year wasn't found.
#
# The second checks the inverse conditional probability. Sometimes, if the request attempt tried and failed three times, the row will be entirely empty, where the name is `''` and not `'Not Found'`

# %%
# Every time the name isn't found, nothing is found
info990.loc[info990['ba'] == 'Not found']['Tax Year'].isna().mean()
# Out:
# 1.0

# %%
# And every time the tax year isn't found the name isn't found
(info990[['ba', 'Tax Year']].loc[info990['Tax Year'].isna()]['ba'] == 'Not found').mean()
# Out:
# 1.0

# %% [markdown]
# This cell indicates how many XML files failed to be accessed

# %%
info990['ba'].isna().sum()
# Out:
# 0

# %% [markdown]
# If the following cell returns 0.0, that indicates that every time the tax year is missing, every single financial cell is zero. All of these rows can be dropped and no information is lost.

# %%
info990.loc[info990['Tax Year'].isna(), 'Federate Campaigns':].sum(axis=1).sum()
# Out:
# 0

# %% [markdown]
# ### Cleaning the raw information

# %% [markdown]
# Assuming the prior three checks are all adequate, we can drop rows with any nan values.

# %%
no_error = info990.dropna().reset_index(drop=True)
no_error.loc[:, 'EIN':'Total'] = no_error.loc[:, 'EIN':'Total'].astype(int)
no_error.loc[:, 'EIN_YEAR'] = no_error['EIN'].astype(str) + '_' + no_error['Tax Year'].astype(str)
no_error = no_error.set_index('EIN_YEAR')

# %% [markdown]
# ### Export here!

# %% [markdown]
# <b>REMEMBER TO EXPORT</b>
#
# `no_error` is the cleaned dataframe
#
# `info990` is the raw dataframe with missing rows

# %%
 no_error.to_csv('no_errors.csv')

# %%
 info990.to_csv('full_table.csv')

# %% [markdown]
# The following line appends the rows to the bottom of the existing dataframe titled `'no_errors.csv'` instead.
#
# It creates a new CSV and it is recommended to rename it back to `no_errors.csv` in the case it is exported successfully

# %%
extended = pd.concat([pd.read_csv('no_errors.csv'), no_error]).reset_index(drop=True).drop_duplicates()
extended.to_csv('no_errors_appended.csv')

# %% [markdown]
# ## Testing Zone

# %%
url = 'https://projects.propublica.org/nonprofits/organizations/263405689'
html = scrape_website(url)
soup = BeautifulSoup(html.text)
links = soup.find_all('a', class_='action xml')
base_url = 'https://projects.propublica.org'
urls = [base_url + x.get('href') for x in links if x.text == '990']

# %%
test = [x for x in soup.find_all(class_='action xml') if re.search(r'990\b', x.text)]
test2 = [base_url + x.get('href') if x.name == 'a' else base_url + x.select_one('select.action.xml option[data-href]').get('data-href') for x in test]

# %%
info990
# Out:
#                                                     ba        EIN  Tax Year  \
# 0    Metropolitan Area Advisory Committee on Anti-P...  952457354    2021.0
# 1    Metropolitan Area Advisory Committee on Anti-P...  952457354    2020.0
# 2    Metropolitan Area Advisory Committee on Anti-P...  952457354    2019.0
# 3    Metropolitan Area Advisory Committee on Anti-P...  952457354    2018.0
# 4    Metropolitan Area Advisory Committee on Anti-P...  952457354    2017.0
# ..                                                 ...        ...       ...
# 664                     ALPHA PROJECT FOR THE HOMELESS  330215585    2015.0
# 665                     ALPHA PROJECT FOR THE HOMELESS  330215585    2014.0
# 666                     ALPHA PROJECT FOR THE HOMELESS  330215585    2013.0
# 667                                          Not found  330215585       NaN
# 668                                          Not found  330215585       NaN
#
#     Location (Zipcode) Federate Campaigns Membership Dues Fundraising Events  \
# 0                91911                  0               0                  0
# 1                91911                  0               0                  0
# 2                91911                  0               0             204555
# 3                91911                  0               0              35000
# 4                91911                  0               0              36800
# ..                 ...                ...             ...                ...
# 664              92103                  0               0                  0
# 665              92103                  0               0                  0
# 666                  0                  0               0                  0
# 667                  0                  0               0                  0
# 668                  0                  0               0                  0
#
#     Related Organizations Government Grants All Other Contributions  \
# 0                       0          44408141                 3256460
# 1                       0          35941636                 3522954
# 2                       0          35487026                 2434789
# 3                       0          29811044                 2412572
# 4                       0          27582015                 2269306
# ..                    ...               ...                     ...
# 664                     0           2827016                 2417961
# 665                     0           4037724                 1847458
# 666                     0           2065058                 4124494
# 667                     0                 0                       0
# 668                     0                 0                       0
#
#     Noncash Contributions     Total
# 0                 2136983  47664601
# 1                 2632688  39464590
# 2                 2298104  38126370
# 3                 1869374  32258616
# 4                 2049541  29888121
# ..                    ...       ...
# 664               1086372   5244977
# 665                676252   5885182
# 666                469651   6189552
# 667                     0         0
# 668                     0         0
#
# [669 rows x 12 columns]

# %%
extended = pd.concat([pd.read_csv('no_errors.csv'), no_error]).reset_index(drop=True).drop_duplicates()

# %%
extended.loc[:, 'EIN':'Total'] = extended.loc[:, 'EIN':'Total'].astype(int)

# %%
extended = extended.drop_duplicates()

# %%
info = pd.read_csv('no_errors.csv')

# %%
info = info.set_index('EIN_YEAR')
# accurate = info[['Federate Campaigns', 'Membership Dues', 'Fundraising Events', 'Related Organizations', 'Government Grants', 'All Other Contributions']].sum(axis=1) == info['Total']

# %%
info
# Out:
#                                                                  ba  \
# EIN_YEAR
# 952457354_2021.0  Metropolitan Area Advisory Committee on Anti-P...
# 952457354_2020.0  Metropolitan Area Advisory Committee on Anti-P...
# 952457354_2019.0  Metropolitan Area Advisory Committee on Anti-P...
# 952457354_2018.0  Metropolitan Area Advisory Committee on Anti-P...
# 952457354_2017.0  Metropolitan Area Advisory Committee on Anti-P...
# ...                                                             ...
# 330215585_2017.0                     ALPHA PROJECT FOR THE HOMELESS
# 330215585_2016.0                     ALPHA PROJECT FOR THE HOMELESS
# 330215585_2015.0                     ALPHA PROJECT FOR THE HOMELESS
# 330215585_2014.0                     ALPHA PROJECT FOR THE HOMELESS
# 330215585_2013.0                     ALPHA PROJECT FOR THE HOMELESS
#
#                         EIN  Tax Year  Location (Zipcode)  Federate Campaigns  \
# EIN_YEAR
# 952457354_2021.0  952457354    2021.0               91911                   0
# 952457354_2020.0  952457354    2020.0               91911                   0
# 952457354_2019.0  952457354    2019.0               91911                   0
# 952457354_2018.0  952457354    2018.0               91911                   0
# 952457354_2017.0  952457354    2017.0               91911                   0
# ...                     ...       ...                 ...                 ...
# 330215585_2017.0  330215585    2017.0               92103                   0
# 330215585_2016.0  330215585    2016.0               92103                   0
# 330215585_2015.0  330215585    2015.0               92103                   0
# 330215585_2014.0  330215585    2014.0               92103                   0
# 330215585_2013.0  330215585    2013.0                   0                   0
#
#                   Membership Dues  Fundraising Events  Related Organizations  \
# EIN_YEAR
# 952457354_2021.0                0                   0                      0
# 952457354_2020.0                0                   0                      0
# 952457354_2019.0                0              204555                      0
# 952457354_2018.0                0               35000                      0
# 952457354_2017.0                0               36800                      0
# ...                           ...                 ...                    ...
# 330215585_2017.0                0                   0                      0
# 330215585_2016.0                0                   0                      0
# 330215585_2015.0                0                   0                      0
# 330215585_2014.0                0                   0                      0
# 330215585_2013.0                0                   0                      0
#
#                   Government Grants  All Other Contributions  \
# EIN_YEAR
# 952457354_2021.0           44408141                  3256460
# 952457354_2020.0           35941636                  3522954
# 952457354_2019.0           35487026                  2434789
# 952457354_2018.0           29811044                  2412572
# 952457354_2017.0           27582015                  2269306
# ...                             ...                      ...
# 330215585_2017.0            1972019                  8974475
# 330215585_2016.0            1251303                  6178785
# 330215585_2015.0            2827016                  2417961
# 330215585_2014.0            4037724                  1847458
# 330215585_2013.0            2065058                  4124494
#
#                   Noncash Contributions     Total
# EIN_YEAR
# 952457354_2021.0                2136983  47664601
# 952457354_2020.0                2632688  39464590
# 952457354_2019.0                2298104  38126370
# 952457354_2018.0                1869374  32258616
# 952457354_2017.0                2049541  29888121
# ...                                 ...       ...
# 330215585_2017.0                1743782  10946494
# 330215585_2016.0                1876303   7430088
# 330215585_2015.0                1086372   5244977
# 330215585_2014.0                 676252   5885182
# 330215585_2013.0                 469651   6189552
#
# [547 rows x 12 columns]

# %%
# tuple(accurate[~accurate].index)

# %%
info_EINerrs = find_errors(info)

# %%
info_errs = info[info.index.isin(info_EINerrs)]

# %%
info_errs = [int(err[:-7]) for (err) in info_EINerrs]
info_errs
# Out:
# [951874073,
#  953368020,
#  272917644,
#  952039198,
#  952039198,
#  263405689,
#  331146733,
#  953497926,
#  953302967,
#  550806460]

# %%
filtered_info_errs = grabber(info_errs, errors=True)
# Out:
# 0 / 10
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# 1 / 10
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# 2 / 10
# woot woot
# woot woot
# woot woot
# woot woot
# 3 / 10
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# 4 / 10
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# 5 / 10
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# 6 / 10
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# 7 / 10
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# 8 / 10
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# 9 / 10
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# woot woot
# 10 / 10

# %%
info_no_errors = filtered_info_errs.dropna().reset_index(drop=True)
info_no_errors.loc[:, 'EIN':'Total'] = info_no_errors.loc[:, 'EIN':'Total'].astype(int)
info_no_errors.loc[:, 'EIN_YEAR'] = info_no_errors['EIN'].astype(str) + '_' + info_no_errors['Tax Year'].astype(str)
info_no_errors = info_no_errors.set_index('EIN_YEAR')

# %%
info_no_errors.to_csv('info_no_errors.csv')
EINinfoerrs = pd.read_csv('info_no_errors.csv')
EINinfoerrs = EINinfoerrs.set_index('EIN_YEAR')

# %%
find_errors(EINinfoerrs)
# Out:
# ('951874073_2015.0',)

# %%
EINinfoerrs.loc[['951874073_2015.0']]
# Out:
#                                             ba        EIN  Tax Year  \
# EIN_YEAR
# 951874073_2015.0  San Diego Rescue Mission Inc  951874073    2015.0
#
#                   Location (Zipcode)  Federate Campaigns  Membership Dues  \
# EIN_YEAR
# 951874073_2015.0               92138                   0                0
#
#                   Fundraising Events  Related Organizations  \
# EIN_YEAR
# 951874073_2015.0              265175                      0
#
#                   Government Grants  All Other Contributions  \
# EIN_YEAR
# 951874073_2015.0                  0                 15535669
#
#                   Noncash Contributions     Total
# EIN_YEAR
# 951874073_2015.0                9304663  15535669

# %% [markdown]
# # Testing EINs from Manual Pull

# %%
csvfile_eins = pd.read_csv('990 Manual Pull - Cleaned EIN List.csv')
eins = list(csvfile_eins.get('EIN').dropna())
eins = [int(ein) for ein in eins]
#eins

# %%
parsedEINs = grabber(eins)#, verbose=True)
# Out:
# 0 / 84
# 1 / 84
# 2 / 84
# 3 / 84
# 4 / 84
# 5 / 84
# 6 / 84
# 7 / 84
# 8 / 84
# 9 / 84
# 10 / 84
# 11 / 84
# 12 / 84
# 13 / 84
# 14 / 84
# 15 / 84
# 16 / 84
# 17 / 84
# 18 / 84
# 19 / 84
# 20 / 84
# 21 / 84
# 22 / 84
# 23 / 84
# 24 / 84
# 25 / 84
# 26 / 84
# 27 / 84
# 28 / 84
# 29 / 84
# 30 / 84
# 31 / 84
# 32 / 84
# 33 / 84
# 34 / 84
# 35 / 84
# 36 / 84
# 37 / 84
# 38 / 84
# 39 / 84
# 40 / 84
# 41 / 84
# 42 / 84
# 43 / 84
# 44 / 84
# 45 / 84
# 46 / 84
# 47 / 84
# 48 / 84
# 49 / 84
# 50 / 84
# 51 / 84
# 52 / 84
# 53 / 84
# 54 / 84
# 55 / 84
# 56 / 84
# 57 / 84
# 58 / 84
# 59 / 84
# 60 / 84
# 61 / 84
# 62 / 84
# 63 / 84
# 64 / 84
# 65 / 84
# 66 / 84
# 67 / 84
# 68 / 84
# 69 / 84
# 70 / 84
# 71 / 84
# 72 / 84
# 73 / 84
# 74 / 84
# 75 / 84
# 76 / 84
# 77 / 84
# 78 / 84
# 79 / 84
# 80 / 84
# 81 / 84
# 82 / 84
# 83 / 84
# 84 / 84

# %%
no_errorsEIN = parsedEINs.dropna().reset_index(drop=True)
no_errorsEIN.loc[:, 'EIN':'Total'] = no_errorsEIN.loc[:, 'EIN':'Total'].astype(int)
no_errorsEIN.loc[:, 'EIN_YEAR'] = no_errorsEIN['EIN'].astype(str) + '_' + no_errorsEIN['Tax Year'].astype(str)
no_errorsEIN = no_errorsEIN.set_index('EIN_YEAR')

# %%
no_errorsEIN.to_csv('no_errorsEIN.csv')

# %%
EINinfo = pd.read_csv('no_errors.csv')

# %%
EINinfo = EINinfo.set_index('EIN_YEAR')

# %%
EINinfo
# Out:
#                                                                  ba  \
# EIN_YEAR
# 952457354_2021.0  Metropolitan Area Advisory Committee on Anti-P...
# 952457354_2020.0  Metropolitan Area Advisory Committee on Anti-P...
# 952457354_2019.0  Metropolitan Area Advisory Committee on Anti-P...
# 952457354_2018.0  Metropolitan Area Advisory Committee on Anti-P...
# 952457354_2017.0  Metropolitan Area Advisory Committee on Anti-P...
# ...                                                             ...
# 330215585_2017.0                     ALPHA PROJECT FOR THE HOMELESS
# 330215585_2016.0                     ALPHA PROJECT FOR THE HOMELESS
# 330215585_2015.0                     ALPHA PROJECT FOR THE HOMELESS
# 330215585_2014.0                     ALPHA PROJECT FOR THE HOMELESS
# 330215585_2013.0                     ALPHA PROJECT FOR THE HOMELESS
#
#                         EIN  Tax Year  Location (Zipcode)  Federate Campaigns  \
# EIN_YEAR
# 952457354_2021.0  952457354    2021.0               91911                   0
# 952457354_2020.0  952457354    2020.0               91911                   0
# 952457354_2019.0  952457354    2019.0               91911                   0
# 952457354_2018.0  952457354    2018.0               91911                   0
# 952457354_2017.0  952457354    2017.0               91911                   0
# ...                     ...       ...                 ...                 ...
# 330215585_2017.0  330215585    2017.0               92103                   0
# 330215585_2016.0  330215585    2016.0               92103                   0
# 330215585_2015.0  330215585    2015.0               92103                   0
# 330215585_2014.0  330215585    2014.0               92103                   0
# 330215585_2013.0  330215585    2013.0                   0                   0
#
#                   Membership Dues  Fundraising Events  Related Organizations  \
# EIN_YEAR
# 952457354_2021.0                0                   0                      0
# 952457354_2020.0                0                   0                      0
# 952457354_2019.0                0              204555                      0
# 952457354_2018.0                0               35000                      0
# 952457354_2017.0                0               36800                      0
# ...                           ...                 ...                    ...
# 330215585_2017.0                0                   0                      0
# 330215585_2016.0                0                   0                      0
# 330215585_2015.0                0                   0                      0
# 330215585_2014.0                0                   0                      0
# 330215585_2013.0                0                   0                      0
#
#                   Government Grants  All Other Contributions  \
# EIN_YEAR
# 952457354_2021.0           44408141                  3256460
# 952457354_2020.0           35941636                  3522954
# 952457354_2019.0           35487026                  2434789
# 952457354_2018.0           29811044                  2412572
# 952457354_2017.0           27582015                  2269306
# ...                             ...                      ...
# 330215585_2017.0            1972019                  8974475
# 330215585_2016.0            1251303                  6178785
# 330215585_2015.0            2827016                  2417961
# 330215585_2014.0            4037724                  1847458
# 330215585_2013.0            2065058                  4124494
#
#                   Noncash Contributions     Total
# EIN_YEAR
# 952457354_2021.0                2136983  47664601
# 952457354_2020.0                2632688  39464590
# 952457354_2019.0                2298104  38126370
# 952457354_2018.0                1869374  32258616
# 952457354_2017.0                2049541  29888121
# ...                                 ...       ...
# 330215585_2017.0                1743782  10946494
# 330215585_2016.0                1876303   7430088
# 330215585_2015.0                1086372   5244977
# 330215585_2014.0                 676252   5885182
# 330215585_2013.0                 469651   6189552
#
# [547 rows x 12 columns]

# %%
EIN_errs = find_errors(EINinfo)
EIN_errs
# Out:
# ('951874073_2015.0',
#  '953368020_2015.0',
#  '272917644_2017.0',
#  '952039198_2020.0',
#  '952039198_2013.0',
#  '263405689_2015.0',
#  '331146733_2017.0',
#  '953497926_2016.0',
#  '953302967_2013.0',
#  '550806460_2022.0')

# %% [markdown]
# #### Find errors, then prep data to double filter

# %%
errs1 =EINinfo[EINinfo.index.isin(EIN_errs)]

# %%
EINerrs = [int(err[:-7]) for err in EIN_errs]

# %% [markdown]
# #### Double filter testing

# %%
parsedErrEINs = grabber(EINerrs, errors=True)
# Out:
# 0 / 10
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10

# %%
no_errors2 = parsedErrEINs.dropna().reset_index(drop=True)
no_errors2.loc[:, 'EIN':'Total'] = no_errors2.loc[:, 'EIN':'Total'].astype(int)
no_errors2.loc[:, 'EIN_YEAR'] = no_errors2['EIN'].astype(str) + '_' + no_errors2['Tax Year'].astype(str)
no_errors2 = no_errors2.set_index('EIN_YEAR')

# %%
no_errors2.to_csv('no_errors2.csv')

# %%
EINErrinfo = pd.read_csv('no_errors2.csv')

# %%
EINErrinfo = EINErrinfo.set_index('EIN_YEAR')

# %%
EINErr_errs = find_errors(EINErrinfo)
EINErr_errs
# Out:
# ('951874073_2015.0',)

# %%
errs2 = EINErrinfo[EINErrinfo.index.isin(EINErr_errs)]

# %%
[err for err in EINErr_errs if err in EIN_errs]
# Out:
# ['951874073_2015.0']

# %%
pd.merge(errs1, errs2, how='inner')
# Out:
#                              ba        EIN  Tax Year  Location (Zipcode)  \
# 0  San Diego Rescue Mission Inc  951874073    2015.0               92138
#
#    Federate Campaigns  Membership Dues  Fundraising Events  \
# 0                   0                0              265175
#
#    Related Organizations  Government Grants  All Other Contributions  \
# 0                      0                  0                 15535669
#
#    Noncash Contributions     Total
# 0                9304663  15535669
