# %%
'''
Make sure you have these installations to run the code. Add any if I missed anything.
'''
# pip install notebook
# pip install chardet
# # pip install tiktoken
# pip install fuzzywuzzy
# pip install python-Levenshtein

# python -m spacy download en_core_web_sm
# Out:
# '\nMake sure you have these installations to run the code. Add any if I missed anything.\n'

# %%
import nltk
import re

# function to remove non_ascii text
def remove_non_ascii(text):
    for letter in text: 
        if letter.isascii() == False: 
            text = text.replace(letter,'')
    return text

# %%
import pandas as pd

# %%
import os
import openai

# %%
import chardet
import shutil

# %%
import csv

# %%
import tiktoken

# %%
import spacy

# %%
import numpy as np

# %%
import string

# %%
from fuzzywuzzy import fuzz

# %%
'''
This store's the API key and has a function that creates a response from the created engine. 
To adjust finetuning outputs, edit this function.
'''
# pj's API key: "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"
# Danny's API key: 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
    # curie:ft-personal-2023-07-11-22-45-26
    # curie:ft-personal-2023-07-14-02-12-12  - in use

api_key = "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"
openai.api_key = api_key    
    
def create_response(prompt):
    response = openai.Completion.create(
        engine = "curie:ft-personal-2023-07-14-02-12-12",
        prompt = prompt,
        temperature = 0.7, 
        max_tokens = 100,
        stop = "END")
    confidence = response['choices'][0]['confidence']
    return response["choices"][0]["text"], confidence

# %%
'''
This function is used to count tokens to check if a prompt exceeds the token limit - used in the test_files() function.
'''

def count_tokens(prompt):
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(prompt)
    token_count = len(doc)
    return token_count

# %%
"""
In this cell, we are reading in my most recent version of ML Workflow - Data from my active directory (if working from another computer)
the directory should be adjusted as necessary.  It gets all of the information we are looking for (train/test, grantor, grantee, program, date
end date, amount, funding source, and text_id.)  Afterwards, we drop all columns with NA values in text_id. 
It clears the NaN values then sorts the testing and training data into separate dataframes.

"""

# path needs to be updated based on machine and directories
# pj: C:\Users\asapp\Desktop\SDCTA\SDCTA\mlWorkflow.csv
ml = pd.read_csv("ML Workflow - Data.csv")
ml = ml.get(["Train/Test", "Grantor", "Grantee", "Program", "Date", "EndDate", "Amount", "Funding Source", "text_id"])
ml = ml.dropna(subset = ["text_id"]).reset_index().drop(columns = 'index')
train = ml[ml['Train/Test'] == 'Train']
test = ml[ml['Train/Test'] == 'Test']

# %%
"""
This cell loops through all of the rows in our "ml" dataframe and creates the Completion pairs we would like to use for the
data-preparation tool and fine-tune separated by training and test data, for comparison.

"""

# train_completionPairs = []
# for i in range(train.shape[0]): 
#     train_completionPairs += [[train.get('text_id').iloc[i] , "Grantor: " + train.get('Grantor').iloc[i] + "\nGrantee: " + train.get('Grantee').iloc[i] + "\nProgram: " + train.get('Program').iloc[i] + "\nStart: " + train.get('Date').iloc[i] + "\nStop: " + train.get('EndDate').iloc[i] +"\nAmount: " + str(train.get('Amount').iloc[i]) + "\nFunding Source: " + str(train.get('Funding Source').iloc[i])]]
    
# test_completionPairs = []
# for i in range(test.shape[0]): 
#     test_completionPairs += [[test.get('text_id').iloc[i] , "Grantor: " + test.get('Grantor').iloc[i] + "\nGrantee: " + test.get('Grantee').iloc[i] + "\nProgram: " + train.get('Program').iloc[i] + "\nStart: " + test.get('Date').iloc[i] + "\nStop: " + test.get('EndDate').iloc[i] +"\nAmount: " + str(test.get('Amount').iloc[i]) + "\nFunding Source: " + str(test.get('Funding Source').iloc[i])]]

# %%
# train_completionPairs

# %%
#test_completionPairs

# %%
"""
This cell starts by saving the directory where all of the original training files should be located.  The directory
should be edited accordingly.  The script subsequently loops through all of these training documents, strips the text-files
of new-line & unrecognizable characters, tokenizes the text-files, and takes the first 1500 textfiles and adds the \n\n###\n\n
character (essential to get the fine-tune to work.)  Afterwards, the cell adds each "prompt" and text-id into a double nested
list which will be used to create a DataFrame in future cells.  This cell also overwrites the original text-files, so it makes it
so each individual text file can be used in the OpenAI preparation tool/used to test.

"""
# train_prompts = []
# # pj: directory = r"C:\Users\asapp\Desktop\SDCTA\SDCTA\text_docs"
# directory = "test_txt"

# for filename in os.listdir(directory):
#     file_path = os.path.join(directory, filename)

#     with open(file_path, 'r', encoding = "latin-1") as file: 
#         filedata = file.readlines()
#         filedata = ' '.join([s.rstrip('\n') for s in filedata])
#         filedata = remove_non_ascii(filedata)

#         nltk_tokens = nltk.word_tokenize(filedata)
#         filedata = ' '.join(nltk_tokens[:1500]) + "\n\n###\n\n"
#     train_prompts += [[filename, filedata]]

#     #print(len(nltk_tokens))

#     with open(file_path,'w') as file: 
#         file.write(filedata)
# Out:
#   Cell In[61], line 29
#     file.write(filedata)"""
#                            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 41-42: truncated \UXXXXXXXX escape

# %%
'''
This is for the folder containing all the training and testing data documents and create the prompts for them.
'''
prompts = []
# pj: directory = r"C:\Users\asapp\Desktop\SDCTA\SDCTA\text_docs"
#     os.listdir(r"C:\Users\asapp\Desktop\SDCTA\SDCTA\text_docs")
directory = "all_text_docs"
for filename in os.listdir("all_text_docs"): 
    f = os.path.join(directory, filename)
    # print(filename)
    # checking if it is a file
    if filename.endswith('.txt'):
        with open(f, 'r', encoding = "latin-1") as file: 
            filedata = file.readlines()
            filedata = ' '.join([s.rstrip('\n') for s in filedata])
            filedata = remove_non_ascii(filedata)

            nltk_tokens = nltk.word_tokenize(filedata)
            filedata = ' '.join(nltk_tokens[:1500]) + "\n\n###\n\n"
        prompts += [[filename, filedata]]

        #print(len(nltk_tokens))

        with open(f,'w') as file: 
            file.write(filedata)

# %%
# test_prompts = []
# # pj: directory = r"C:\Users\asapp\Desktop\SDCTA\SDCTA\text_docs"

# directory = "sorted_files/test_txt"

# for filename in os.listdir(directory):
#     file_path = os.path.join(directory, filename)

#     with open(file_path, 'r', encoding = "latin-1") as file: 
#         filedata = file.readlines()
#         filedata = ' '.join([s.rstrip('\n') for s in filedata])
#         filedata = remove_non_ascii(filedata)

#         nltk_tokens = nltk.word_tokenize(filedata)
#         filedata = ' '.join(nltk_tokens[:1500]) + "\n\n###\n\n"
#     test_prompts += [[filename, filedata]]

#     #print(len(nltk_tokens))

#     with open(file_path,'w') as file: 
#         file.write(filedata)

# %%
"""
This cell creates two DataFrames of the prompts and completions, and the cell under merges the files under their text_ids, 
drops the text_ids, and saves as a CSV.  The directory should be editted accordingly dependent on which device you are using 
this on.  I originally named my "prompt-completion pairs" finetuneTrain0608.csv
"""
# train_prompt_df = pd.DataFrame(train_prompts, columns = ["text_id", "prompt"])
# test_prompt_df = pd.DataFrame(test_prompts, columns = ["text_id", "prompt"])

# train_completion_df = pd.DataFrame(train_completionPairs, columns = ["text_id", "completion"])
# test_completion_df = pd.DataFrame(test_completionPairs, columns = ["text_id", "completion"])

# train_completion_df.iloc[0].get('completion')
# test_completionPairs

# %%
'''
This is used to create the jsonl file to train the data for the AI engine using the prompt-completion pairs created above.
Directions on how to turn a csv into a jsonl file and creating an AI engine via terminal are linked below.

https://platform.openai.com/docs/guides/fine-tuning

'''
# train_prompt_df.merge(train_completion_df, left_on = "text_id", right_on = "text_id").drop(columns = "text_id").set_index("prompt").to_csv(r"dir_finetuneTrain0608.csv")
# C:\Users\asapp\Desktop\SDCTA\json_testing\finetuneTrain0608.csv

# %%
'''
This is to clean up the input from the txt document to a readable prompt for testing files by cleaning white spaces, random characters, 
and ensuring the necessary "\n\n###\n\n" is added at the end,

'''
def condense_file(file_path):
    # Read the contents of the file
    with open(file_path, "r") as file:
        content = file.read().replace("\n", " ").replace("\r", "").replace('###', "")

    return content.strip() + "\n\n###\n\n"

# %% [markdown]
# # <b>TESTING

# %%
'''
Edit the directory. Mine is connected to the GitHub repo and my jupyterhub to automatically update them.
This cell was just being used to test individual files - it might be good to know that there is a max usage on each API key based on tokens inputted, 
so I've been testing indiivdual files to note differences in outputs.
'''
current_directory = os.getcwd()
cf = os.path.join(current_directory, 'all_text_docs', 'City of Lemon Grove Home Start.txt')

testFile = condense_file(cf)
create_response(testFile)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[141], line 10
#       7 cf = os.path.join(current_directory, 'all_text_docs', 'City of Lemon Grove Home Start.txt')
#       9 testFile = condense_file(cf)
# ---> 10 create_response(testFile)
#
# Cell In[140], line 20, in create_response(prompt)
#      13 def create_response(prompt):
#      14     response = openai.Completion.create(
#      15         engine = "curie:ft-personal-2023-07-14-02-12-12",
#      16         prompt = prompt,
#      17         temperature = 0.7,
#      18         max_tokens = 100,
#      19         stop = "END")
# ---> 20     confidence = response['choices'][0]['confidence']
#      21     return response["choices"][0]["text"], confidence
#
# KeyError: 'confidence'

# %%
"""
This script is used to test the data. This is using the functions created earlier in the code to clean the txt file prompts, 
check token limit and outputs a print line for the files that are over the limit before attempting to test them. It then tests 
the files that are within the token limit. This just tests one file at a time given the filepath.

"""

##Script to test our "testing" data.  Enter new text into testFile variable and completion example is found under "text"

def test_files(file_path):
    # Read and condense the file contents
    condensed_file = condense_file(file_path)

    # Count the number of tokens in the condensed file
    token_count = count_tokens(condensed_file)

    # Check if the token count exceeds the limit
    if token_count > 2048:
        return "Error: The file {file_path} contains more than 2048 tokens."

    # Create a response using the condensed file
    response,confidence = create_response(condensed_file)

    return response,confidence

# %%
"""
This cell is using an automated process to loop through all the downloaded text documents and creates a nested list to be turned into a csv file, 
a list that contains the names of the files that were too large to test, and prints out any errors with reading the inputted files. 
The data is expanded in the cells below.

"""

csvRows = []
largeFiles = [] # list of txt doc names that had too large of a token size to test
skipped = [] # list of other files skipped

# Get the current working directory (JupyterHub project directory)
current_directory = os.getcwd()

# Specify the folder name within the current directory
folder_path = os.path.join(current_directory, 'all_text_docs')

# Loop through each file in the folder
for file_name in os.listdir(folder_path):
    # Get the full path of the file
    file_path = os.path.join(folder_path, file_name)

    try:
        # Perform fine-tuning on the file here
        string_munip = test_files(file_path)
        csvRows.append(string_munip)

    except ValueError as e:
        print(f"Skipping file {file_name}: {str(e)}")
        skipped.append(file_name)
        continue

    except Exception as e:
        print(f"Error processing file {file_name}: {str(e)}")
        largeFiles.append(file_name)
        continue

#for row in csvRows:
    #print(row)
# Out:
# Error processing file CRC - CDBG FY 2021-22 (Executed) (1).txt: This model's maximum context length is 2049 tokens, however you requested 9668 tokens (9568 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file CRC 2020-21 Facility Improvement (2.22.2021) (1).txt: This model's maximum context length is 2049 tokens, however you requested 9607 tokens (9507 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file CRC Homeless Prevention - FY19-20 Executed Agreement (1).txt: This model's maximum context length is 2049 tokens, however you requested 12017 tokens (11917 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file CRC MOU Motel Voucher (1).txt: This model's maximum context length is 2049 tokens, however you requested 10523 tokens (10423 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file CRC MOU Motel Voucher.txt: This model's maximum context length is 2049 tokens, however you requested 10523 tokens (10423 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file East County Transitional Living Center     Emergency Shelter Program for Homeless.txt: This model's maximum context length is 2049 tokens, however you requested 2444 tokens (2344 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file Elderhelp of San Diego - 3rd Amendment.txt: This model's maximum context length is 2049 tokens, however you requested 6742 tokens (6642 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file Executed Agreement CDBG CATHOLIC CHARITIES.txt: This model's maximum context length is 2049 tokens, however you requested 11904 tokens (11804 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file Executed_First Amendment_ JFS Safe Parking Contract.txt: This model's maximum context length is 2049 tokens, however you requested 10260 tokens (10160 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file HHI-21-04 Agreement - Storage Connect Center II (MHS) (1).txt: This model's maximum context length is 2049 tokens, however you requested 5212 tokens (5112 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file HHI-21-13 Agreement - Day Center (FJV) (1).txt: This model's maximum context length is 2049 tokens, however you requested 5816 tokens (5716 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file Home Start Inc.txt: This model's maximum context length is 2049 tokens, however you requested 10387 tokens (10287 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file Interfaith Community Services - Second Amendment.txt: This model's maximum context length is 2049 tokens, however you requested 7203 tokens (7103 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file Interfaith_Community_Services_Inc__2020-03-23_.txt: This model's maximum context length is 2049 tokens, however you requested 2396 tokens (2296 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file Jewish Family Service of San Diego - First Amendment.txt: This model's maximum context length is 2049 tokens, however you requested 8726 tokens (8626 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file McAlister Agreement - Executed (10.22.2021) (1).txt: This model's maximum context length is 2049 tokens, however you requested 12038 tokens (11938 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file Mental Health Systems Transitional Storage Agreement-executed.txt: This model's maximum context length is 2049 tokens, however you requested 10599 tokens (10499 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file Opening Doors MOU 21-22.txt: This model's maximum context length is 2049 tokens, however you requested 11685 tokens (11585 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file PRA 4058 - 5466_211 SD.txt: This model's maximum context length is 2049 tokens, however you requested 10427 tokens (10327 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file PRA 4058 - 6446_NC Lifeline.txt: This model's maximum context length is 2049 tokens, however you requested 7400 tokens (7300 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file PRA 4058 - 6455_Interfaith.txt: This model's maximum context length is 2049 tokens, however you requested 7209 tokens (7109 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.
# Error processing file PRA 4058 - Contract 6482 MOU w. ARS.txt: This model's maximum context length is 2049 tokens, however you requested 6314 tokens (6214 in your prompt; 100 for the completion). Please reduce your prompt; or completion length.

# %%
largeFiles
# Out:
# ['CRC - CDBG FY 2021-22 (Executed) (1).txt',
#  'CRC 2020-21 Facility Improvement (2.22.2021) (1).txt',
#  'CRC Homeless Prevention - FY19-20 Executed Agreement (1).txt',
#  'CRC MOU Motel Voucher (1).txt',
#  'CRC MOU Motel Voucher.txt',
#  'East County Transitional Living Center     Emergency Shelter Program for Homeless.txt',
#  'Elderhelp of San Diego - 3rd Amendment.txt',
#  'Executed Agreement CDBG CATHOLIC CHARITIES.txt',
#  'Executed_First Amendment_ JFS Safe Parking Contract.txt',
#  'HHI-21-04 Agreement - Storage Connect Center II (MHS) (1).txt',
#  'HHI-21-13 Agreement - Day Center (FJV) (1).txt',
#  'Home Start Inc.txt',
#  'Interfaith Community Services - Second Amendment.txt',
#  'Interfaith_Community_Services_Inc__2020-03-23_.txt',
#  'Jewish Family Service of San Diego - First Amendment.txt',
#  'McAlister Agreement - Executed (10.22.2021) (1).txt',
#  'Mental Health Systems Transitional Storage Agreement-executed.txt',
#  'Opening Doors MOU 21-22.txt',
#  'PRA 4058 - 5466_211 SD.txt',
#  'PRA 4058 - 6446_NC Lifeline.txt',
#  'PRA 4058 - 6455_Interfaith.txt',
#  'PRA 4058 - Contract 6482 MOU w. ARS.txt']

# %% [markdown]
# ## might need to check for white space issues

# %%
data = []
for row in csvRows:
    string_munip = row.strip()
    cleanedValues = string_munip.replace("Grantor: ","").replace("Grantee: ","").replace("Program: ","").replace("Start: ","").replace("Stop: ","").replace("Amount: ","").replace("Funding Source: ","")
    removedNewLines = cleanedValues.replace("\n", ",")
    data.append(removedNewLines.split(','))

# %%
colNames = ['Grantor', 'Grantee', 'Program', 'Start', 'Stop', 'Amount', 'Funding Source']

# %%
filename = 'data.csv'

# Check if the file exists
file_exists = False
try:
    with open(filename, 'r') as file:
        reader = csv.reader(file)
        if any(row for row in reader):
            file_exists = True
except FileNotFoundError:
    pass

# Open the file in 'a' mode (append mode) with newline=''
with open(filename, 'a', newline='') as file:
    writer = csv.writer(file)

    # Write column names if the file is empty
    if not file_exists:
        column_names = ['Grantor', 'Grantee', 'Program', 'Start', 'Stop', 'Amount', 'Funding Source']
        writer.writerow(column_names)

    # Write the data as rows
    writer.writerows(data)

# %%
csvfile = pd.read_csv('data.csv')
csvfile
# Out:
#                                       Grantor  \
# 0                          City of San Marcos
# 1                         City of Chula Vista
# 2                         City of Chula Vista
# 3                               City of Vista
# 4                           City of Escondido
# 5                         City of Lemon Grove
# 6                            City of El Cajon
#
#        Amount                               Funding Source
# 0      125000                          Fiscal Year 2020-21
# 1      100000                                         ARPA
# 2       30000                                         CDBG
# 3       50000                                         CDBG
# 4       15000                                         CDBG
# 5       30000                                          NaN
# 6      192525                                         CDBG
# 7      485000                                         CDBG
# 8        6852                                         CDBG
# 9       15000                                      CDBG-CV
# 10      66600                                         CDBG
# 11       5000                                         CDBG
# 12       5000                                         CDBG
# 13       5200                                         CDBG
# 14     188809                                         PLHA
# 15      50000                                      CDBG-CV
# 16     185294                                      CDBG-CV
# 17      25000                                         CDBG
# 18      25000                                         CDBG
# 19      23000                                         CDBG
# 20     199000                                  City Budget
# 21     338000                                      CDBG-CV
# 22     155000                                      CDBG-CV
# 23      45000                                      CDBG-CV
# 24      75000                                          NaN
# 25     200000                                       LMIHAF
# 26     168976                                      CDBG-CV
# 27      30000                                      CDBG-CV
# 28     552803                                       ESG-CV
# 29      30000                                         CDBG
# 30      78335                                       ESG-CV
# 31     168976                                      CDBG-CV
# 32      31242                                          NaN
# 33     244944                                          NaN
# 34     598772                                         CDBG
# 35      50000                                         CDBG
# 36    5743525                                         ARPA
# 37      20550                                         CDBG
# 38       3132                                          NaN
# 39     203986                                         CDBG
# 40     10 000                                         CDBG
# 41     255000                                      CDBG-CV
# 42       2998                                         CDBG
# 43     262416                                      CDBG-CV
# 44     200000                                          NaN
# 45       4000                    Community Support Program
# 46      14000                                         CDBG
# 47      50000                                         CDBG
# 48     234475                                         ARPA
# 49  188147.42                                         HOME
# 50  364245.85                                         HOME
# 51     287401  Affordable Housing Fund account 266490-8030
# 52      10700                                  City Budget
# 53      35000                                          NaN
# 54     148996                                         CDBG
# 55       1200                                         CDBG

# %%
def standardize_text(text):
    return re.sub(r'[{}\'‘’]'.format(string.punctuation), '', text).upper().strip()
to_std = ['Grantor', 'Grantee', 'Program', 'Funding Source','Amount']

# %%
csvfile[to_std] = csvfile[to_std].applymap(lambda x: standardize_text(x) if isinstance(x, str) else x)
csvfile
# Out:
#                                       Grantor  \
# 0                          CITY OF SAN MARCOS
# 1                         CITY OF CHULA VISTA
# 2                         CITY OF CHULA VISTA
# 3                               CITY OF VISTA
# 4                           CITY OF ESCONDIDO
# 5                         CITY OF LEMON GROVE
# 6                            CITY OF EL CAJON
# 7                            CITY OF EL CAJON
# 8                              CITY OF SANTEE
# 9                              CITY OF SANTEE
# 10                             CITY OF SANTEE
# 11                             CITY OF SANTEE
# 12                             CITY OF SANTEE
# 13                             CITY OF SANTEE
# 14  CALIFORNIA DEPARTMENT OF GENERAL SERVICES
# 15                             CITY OF SANTEE
# 16                           CITY OF EL CAJON
# 17                           CITY OF EL CAJON
# 18                           CITY OF EL CAJON
# 19                        CITY OF CHULA VISTA
# 20                           CITY OF CARLSBAD
# 21                            CITY OF LA MESA
# 22                           CITY OF EL CAJON
# 23                           CITY OF EL CAJON
# 24                            CITY OF LA MESA
# 25                           CITY OF EL CAJON
# 26                             CITY OF SANTEE
# 27                          CITY OF ENCINITAS
# 28                          CITY OF ESCONDIDO
# 29                           CITY OF EL CAJON
# 30                          CITY OF ESCONDIDO
# 31                             CITY OF SANTEE
# 32                           CITY OF CARLSBAD
# 33                           CITY OF CARLSBAD
# 34                           CITY OF CARLSBAD
# 35                        CITY OF CHULA VISTA
# 36                        CITY OF CHULA VISTA
# 37                           CITY OF CARLSBAD
# 38                      CITY OF NATIONAL CITY
# 39                        CITY OF CHULA VISTA
# 40                           CITY OF CARLSBAD
# 41                              CITY OF VISTA
# 42                              CITY OF VISTA
# 43                            CITY OF LA MESA
# 44                           CITY OF CARLSBAD
# 45                            CITY OF DEL MAR
# 46                             CITY OF SANTEE
# 47                        CITY OF CHULA VISTA
# 48                        CITY OF CHULA VISTA
# 49                      CITY OF NATIONAL CITY
# 50                      CITY OF NATIONAL CITY
# 51                           CITY OF CORONADO
# 52                           CITY OF EL CAJON
# 53                           CITY OF CARLSBAD
# 54                           CITY OF CARLSBAD
# 55                           CITY OF CARLSBAD
#
#                                               Grantee  \
# 0                     ALLIANCE FOR REGIONAL SOLUTIONS
# 1                                       ALPHA PROJECT
# 2                                       ALPHA PROJECT
# 3                                       ALPHA PROJECT
# 4                       INTERFAITH COMMUNITY SERVICES
# 5                                          HOME START
# 6                                        CRISIS HOUSE
# 7                                        CRISIS HOUSE
# 8                                        CRISIS HOUSE
# 9                                        CRISIS HOUSE
# 10                                       CRISIS HOUSE
# 11                                       CRISIS HOUSE
# 12                                       CRISIS HOUSE
# 13                                       CRISIS HOUSE
# 14                                    CITY OF LA MESA
# 15         EAST COUNTY CHAMBER OF COMMERCE FOUNDATION
# 16             EAST COUNTY TRANSITIONAL LIVING CENTER
# 17             EAST COUNTY TRANSITIONAL LIVING CENTER
# 18             EAST COUNTY TRANSITIONAL LIVING CENTER
# 19                 FAMILY HEALTH CENTERS OF SAN DIEGO
# 20                           URBAN CORPS OF SAN DIEGO
# 21                                     HOME START INC
# 22                                         HOME START
# 23                                         HOME START
# 24                                         HOME START
# 25                                         HOME START
# 26                                     HOME START INC
# 27                      INTERFAITH COMMUNITY SERVICES
# 28                      INTERFAITH COMMUNITY SERVICES
# 29            INTERFAITH SHELTER NETWORK OF SAN DIEGO
# 30                      INTERFAITH COMMUNITY SERVICES
# 31            INTERFAITH SHELTER NETWORK OF SAN DIEGO
# 32                      INTERFAITH COMMUNITY SERVICES
# 33                      INTERFAITH COMMUNITY SERVICES
# 34                      INTERFAITH COMMUNITY SERVICES
# 35                JACOBS  CUSHMAN SAN DIEGO FOOD BANK
# 36             JACOBS AND CUSHMAN SAN DIEGO FOOD BANK
# 37                     LEGAL AID SOCIETY OF SAN DIEGO
# 38   MCALISTER INSTITUTE FOR TREATMENT  EDUCATION INC
# 39  MCALISTER INSTITUTE FOR TREATMENT AND EDUCATIO...
# 40                                    MEALS ON WHEELS
# 41                              NORTH COUNTY LIFELINE
# 42                                     OPERATION HOPE
# 43                      PEOPLE ASSISTING THE HOMELESS
# 44                                   ROCKET JOHNS INC
# 45      SAN DIEGO REGIONAL TASK FORCE ON THE HOMELESS
#
# 41                                   RENTAL ASSITANCE    07/01/20    06/30/22
# 42                     CV  EMERGENCY SHELTER SERVICES    07/01/19    06/30/20
# 43                              CV  OUTREACH SERVICES    11/21/20    10/31/21
# 44                    PORTA POTTY RENTAL AND SERVICES    06/01/17    06/01/21
# 45                                           SERVICES    07/01/21    06/30/23
# 46                            EMERGENCY FOOD PROGRAMS    06/01/18    06/30/20
# 47                  FAMILY VIOLENCE TREATMENT PROGRAM    06/01/21    06/30/22
# 48                     CV  DOMESTIC VIOLENCE SERVICES    04/26/22    04/26/23
# 49                      TENANT BASED RENTAL ASSITANCE     12/5/17    12/12/18
# 50                      TENANT BASED RENTAL ASSITANCE    07/01/20    06/30/22
# 51                                   SHELTER SERVICES    05/01/21    05/01/24
# 52                                    A WAY BACK HOME     10/6/20    10/05/21
# 53               NEIGHBORHOOD REVITALIZATION SERVICES    06/19/20    06/19/22
# 54                                  OUTREACH SERVICES    07/01/17    06/30/18
# 55                                   GRANTEE SERVICES    07/01/18    06/30/20
#
#       Amount                              Funding Source
# 0     125000                          FISCAL YEAR 202021
# 1     100000                                        ARPA
# 2      30000                                        CDBG
# 3      50000                                        CDBG
# 4      15000                                        CDBG
# 5      30000                                         NaN
# 6     192525                                        CDBG
# 7     485000                                        CDBG
# 8       6852                                        CDBG
# 9      15000                                      CDBGCV
# 10     66600                                        CDBG
# 11      5000                                        CDBG
# 12      5000                                        CDBG
# 13      5200                                        CDBG
# 14    188809                                        PLHA
# 15     50000                                      CDBGCV
# 16    185294                                      CDBGCV
# 17     25000                                        CDBG
# 18     25000                                        CDBG
# 19     23000                                        CDBG
# 20    199000                                 CITY BUDGET
# 21    338000                                      CDBGCV
# 22    155000                                      CDBGCV
# 23     45000                                      CDBGCV
# 24     75000                                         NaN
# 25    200000                                      LMIHAF
# 26    168976                                      CDBGCV
# 27     30000                                      CDBGCV
# 28    552803                                       ESGCV
# 29     30000                                        CDBG
# 30     78335                                       ESGCV
# 31    168976                                      CDBGCV
# 32     31242                                         NaN
# 33    244944                                         NaN
# 34    598772                                        CDBG
# 35     50000                                        CDBG
# 36   5743525                                        ARPA
# 37     20550                                        CDBG
# 38      3132                                         NaN
# 39    203986                                        CDBG
# 40    10 000                                        CDBG
# 41    255000                                      CDBGCV
# 42      2998                                        CDBG
# 43    262416                                      CDBGCV
# 44    200000                                         NaN
# 45      4000                   COMMUNITY SUPPORT PROGRAM
# 46     14000                                        CDBG
# 47     50000                                        CDBG
# 48    234475                                        ARPA
# 49  18814742                                        HOME
# 50  36424585                                        HOME
# 51    287401  AFFORDABLE HOUSING FUND ACCOUNT 2664908030
# 52     10700                                 CITY BUDGET
# 53     35000                                         NaN
# 54    148996                                        CDBG
# 55      1200                                        CDBG

# %% [markdown]
# # Data Cleaning / Calculating Accuracy

# %%
'''
Filters out data that isn't used in training/testing data and files that were skipped or too large.
'''
new_ml = ml[~ml.get('text_id').isin(largeFiles)]#+skipped)]
new_ml = new_ml[new_ml.get('Train/Test').isin(['Train','Test'])]
new_ml[to_std] = new_ml[to_std].applymap(lambda x: standardize_text(x) if isinstance(x, str) else x)
new_ml = new_ml.drop(labels=58, axis=0)
new_ml
# Out:
#    Train/Test              Grantor                                 Grantee  \
# 0       Train  CITY OF CHULA VISTA                           ALPHA PROJECT
# 1       Train  CITY OF CHULA VISTA  JACOBS AND CUSHMAN SAN DIEGO FOOD BANK
# 2       Train  CITY OF CHULA VISTA                           ALPHA PROJECT
# 3       Train  CITY OF CHULA VISTA                                    SBCS
# 4       Train  CITY OF CHULA VISTA      FAMILY HEALTH CENTERS OF SAN DIEGO
# ..        ...                  ...                                     ...
# 82       Test                 SDHC                     FATHER JOES VILLAGE
# 83       Test                 SDHC                SAN DIEGO YOUTH SERVICES
# 84       Test                 SDHC                SAN DIEGO YOUTH SERVICES
# 85       Test                 SDHC         SAN DIEGO LGBT COMMUNITY CENTER
# 86       Test                 SDHC                     URBAN STREET ANGLES
#
#                                      Program      Date   EndDate    Amount  \
# 0                      TAKE BACK THE STREETS  06/01/21  06/30/22     45000
# 1                          CV  FOOD SERVICES  11/16/21  11/16/22    100000
# 2       CV  TRANSITIONAL EMPLOYMENT SERVICES  12/07/21  12/16/22    100000
# 3   CV  EMERGENCY DOMESTIC VIOLENCE SERVICES  04/26/22  04/26/23    200000
# 4               20212022 MOBILE MEDICAL UNIT  06/01/21  06/30/22     30000
# ..                                       ...       ...       ...       ...
# 82                  CASE MANAGEMENT SERVICES  7/1/2020   5/31/21  11945463
# 83                   SAFETAY NETWORK PROGRAM   1/15/21   6/30/21  10025166
# 84                   YOUTH EMERGENCY SHELTER   1/15/21   6/30/21   7248922
# 85                   SAFETAY NETWORK PROGRAM   1/15/21   6/30/21   6501977
# 86                   SAFETAY NETWORK PROGRAM   1/15/21   6/30/21   7662393
#
#    Funding Source                                            text_id
# 0            CDBG      Alpha Project _Take Back the Streets_text.txt
# 1            ARPA  Jacobs and Cushman San Diego Food Bank_CV - Fo...
# 2            ARPA  Alpha Project _CV - Transitional Employment Se...
# 3            ARPA  SBCS_CV - Emergency Domestic Violence Services...
# 4            CDBG  Family Health Centers of San Diego_2021-2022 M...
# ..            ...                                                ...
# 82            NaN    HHI-21-21 Agreement - Case Management (FJV).pdf
# 83            NaN  HHI-21-31 Agreement (SafeTAY Network Program -...
# 84            NaN  HHI-21-32 Agreement (Youth Emergency Shelter -...
# 85            NaN  HHI-21-33 Agreement (SafeTAY Network Program -...
# 86            NaN  HHI-21-34 Agreement (SafeTAY Network Program -...
#
# [71 rows x 9 columns]

# %%
'''
Filters out files in the largeFiles list that weren't able to be tested due to token size or that were skipped and stores in new variable txt_csvfile.
'''

filenames=[]

current_directory = os.getcwd()
folder_path = os.path.join(current_directory, 'all_text_docs')

# Loop through each file in the folder
for file_name in os.listdir(folder_path):
    if file_name not in (largeFiles) and file_name.endswith('.txt'):
         filenames.append(file_name)

txt_csvfile = csvfile.assign(text_id=filenames)
# Out:
#    Train/Test           Grantor                        Grantee  \
# 58       Test  CITY OF CARLSBAD  INTERFAITH COMMUNITY SERVICES
#
#                               Program      Date EndDate Amount Funding Source  \
# 58  RENTAL HOUSING ASSISTANCE PROGRAM  07/01/18  6/2021    REF           CDBG
#
#                                     text_id
# 58  Interfaith_Community_Services__2019.txt

# %%
'''
Outputs a dataframe that shows outputs for the files via testing data and the manually collected data aligned by text_id so you can see where
there are errors.
'''
merged = pd.merge(new_ml, txt_csvfile, on='text_id', how='outer')
merged = merged.dropna(thresh=merged.shape[1] - 2)
merged['Amount_x'] = merged['Amount_x'].astype(int).astype(str)
merged
# Out:
#    Train/Test              Grantor_x  \
# 0       Train    CITY OF CHULA VISTA
# 1       Train    CITY OF CHULA VISTA
# 2       Train    CITY OF CHULA VISTA
# 3       Train    CITY OF CHULA VISTA
# 4       Train    CITY OF CHULA VISTA
# 5       Train    CITY OF CHULA VISTA
# 6       Train    CITY OF CHULA VISTA
# 7       Train    CITY OF CHULA VISTA
# 10      Train       CITY OF CORONADO
# 11      Train        CITY OF DEL MAR
# 12      Train       CITY OF EL CAJON
# 13      Train       CITY OF EL CAJON
# 14      Train       CITY OF EL CAJON
# 15      Train       CITY OF EL CAJON
# 16      Train       CITY OF EL CAJON
# 17      Train       CITY OF EL CAJON
# 18      Train       CITY OF EL CAJON
# 19      Train       CITY OF EL CAJON
# 20      Train       CITY OF EL CAJON
# 21      Train       CITY OF EL CAJON
# 22      Train      CITY OF ESCONDIDO
# 23      Train      CITY OF ESCONDIDO
# 24       Test      CITY OF ESCONDIDO
# 25      Train        CITY OF LA MESA
# 26      Train        CITY OF LA MESA
# 27      Train        CITY OF LA MESA
# 28      Train        CITY OF LA MESA
# 29      Train    CITY OF LEMON GROVE
# 30      Train  CITY OF NATIONAL CITY
# 31      Train  CITY OF NATIONAL CITY
# 32      Train  CITY OF NATIONAL CITY
# 33      Train     CITY OF SAN MARCOS
# 34      Train         CITY OF SANTEE
# 36      Train         CITY OF SANTEE
# 37      Train         CITY OF SANTEE
# 38      Train         CITY OF SANTEE
# 39      Train         CITY OF SANTEE
# 40      Train         CITY OF SANTEE
# 41      Train         CITY OF SANTEE
# 42      Train         CITY OF SANTEE
# 43      Train         CITY OF SANTEE
# 44      Train          CITY OF VISTA
# 45      Train          CITY OF VISTA
# 46      Train          CITY OF VISTA
# 47       Test       CITY OF CARLSBAD
# 48       Test       CITY OF CARLSBAD
# 49       Test       CITY OF CARLSBAD
# 50       Test       CITY OF CARLSBAD
# 51       Test       CITY OF CARLSBAD
# 52       Test       CITY OF CARLSBAD
# 53       Test       CITY OF CARLSBAD
# 54       Test       CITY OF CARLSBAD
# 55       Test       CITY OF CARLSBAD
# 57       Test      CITY OF ENCINITAS
#
#                                             Grantee_x  \
# 0                                       ALPHA PROJECT
# 1              JACOBS AND CUSHMAN SAN DIEGO FOOD BANK
# 2                                       ALPHA PROJECT
# 3                                                SBCS
# 4                  FAMILY HEALTH CENTERS OF SAN DIEGO
# 5   MCALISTER INSTITUTE FOR TREATMENT AND EDUCATIO...
# 6                 JACOBS  CUSHMAN SAN DIEGO FOOD BANK
# 7                                                SBCS
# 10                         ST VINCENT DE PAUL VILLAGE
# 11      SAN DIEGO REGIONAL TASK FORCE ON THE HOMELESS
#
# 47            Womens_Resource_Center__2018-01-23_.txt
# 48                   Women_s_Resource_Center_2019.txt
# 49          Urban_Corps_of_San_Diego_County__2019.txt
# 50             Fully_Executed_UC_PW_contract_FY19.txt
# 51                           Rocket_John_Contract.txt
# 52                           Meals_on_Wheels_2019.txt
# 53    Legal_Aid_Society_of_San_Diego__2018-11-05_.txt
# 54  Interfaith_Community_Services_Inc__2018-06-01_...
# 55  Interfaith_Community_Services_Contract_FY2020-...
# 57       ICS - Amendment #2 (Executed) 10.11.2021.txt
#
#                                     Grantor_y  \
# 0                         CITY OF CHULA VISTA
# 1                         CITY OF CHULA VISTA
# 2                         CITY OF CHULA VISTA
# 3                         CITY OF CHULA VISTA
# 4                         CITY OF CHULA VISTA
# 5                         CITY OF CHULA VISTA
# 6                         CITY OF CHULA VISTA
# 7                         CITY OF CHULA VISTA
# 10                           CITY OF CORONADO
# 11                            CITY OF DEL MAR
# 12                           CITY OF EL CAJON
# 13                           CITY OF EL CAJON
# 14                           CITY OF EL CAJON
# 15                           CITY OF EL CAJON
# 16                           CITY OF EL CAJON
# 17                           CITY OF EL CAJON
# 18                           CITY OF EL CAJON
# 19                           CITY OF EL CAJON
# 20                           CITY OF EL CAJON
# 21                           CITY OF EL CAJON
# 22                          CITY OF ESCONDIDO
# 23                          CITY OF ESCONDIDO
# 24                          CITY OF ESCONDIDO
# 25                            CITY OF LA MESA
# 26                            CITY OF LA MESA
# 27  CALIFORNIA DEPARTMENT OF GENERAL SERVICES
# 28                            CITY OF LA MESA
# 29                        CITY OF LEMON GROVE
# 30                      CITY OF NATIONAL CITY
# 31                      CITY OF NATIONAL CITY
# 32                      CITY OF NATIONAL CITY
# 33                         CITY OF SAN MARCOS
# 34                             CITY OF SANTEE
# 36                             CITY OF SANTEE
# 37                             CITY OF SANTEE
# 38                             CITY OF SANTEE
# 39                             CITY OF SANTEE
# 40                             CITY OF SANTEE
# 41                             CITY OF SANTEE
# 42                             CITY OF SANTEE
# 43                             CITY OF SANTEE
# 44                              CITY OF VISTA
# 45                              CITY OF VISTA
# 46                              CITY OF VISTA
# 47                           CITY OF CARLSBAD
# 48                           CITY OF CARLSBAD
# 49                           CITY OF CARLSBAD
# 50                           CITY OF CARLSBAD
# 51                           CITY OF CARLSBAD
# 52                           CITY OF CARLSBAD
# 53                           CITY OF CARLSBAD
# 54                           CITY OF CARLSBAD
# 55                           CITY OF CARLSBAD
# 57                          CITY OF ENCINITAS
#
#                                             Grantee_y  \
# 0                                       ALPHA PROJECT
# 1              JACOBS AND CUSHMAN SAN DIEGO FOOD BANK
# 2                                       ALPHA PROJECT
# 3                                                SBCS
# 4                  FAMILY HEALTH CENTERS OF SAN DIEGO
# 5   MCALISTER INSTITUTE FOR TREATMENT AND EDUCATIO...
# 6                 JACOBS  CUSHMAN SAN DIEGO FOOD BANK
# 7                                                SBCS
# 10                         ST VINCENT DE PAUL VILLAGE
# 11      SAN DIEGO REGIONAL TASK FORCE ON THE HOMELESS
# 12                                         HOME START
# 13                                     SALVATION ARMY
# 14             EAST COUNTY TRANSITIONAL LIVING CENTER
# 15             EAST COUNTY TRANSITIONAL LIVING CENTER
# 16            INTERFAITH SHELTER NETWORK OF SAN DIEGO
# 17                                       CRISIS HOUSE
# 18                                       CRISIS HOUSE
# 19             EAST COUNTY TRANSITIONAL LIVING CENTER
# 20                                         HOME START
# 21                                         HOME START
# 22                      INTERFAITH COMMUNITY SERVICES
# 23                      INTERFAITH COMMUNITY SERVICES
# 24                      INTERFAITH COMMUNITY SERVICES
# 25                                         HOME START
# 26                      PEOPLE ASSISTING THE HOMELESS
# 27                                    CITY OF LA MESA
# 28                                     HOME START INC
# 29                                         HOME START
# 30   MCALISTER INSTITUTE FOR TREATMENT  EDUCATION INC
# 31                       SOUTH BAY COMMUNITY SERVICES
# 32                       SOUTH BAY COMMUNITY SERVICES
# 33                    ALLIANCE FOR REGIONAL SOLUTIONS
# 34                                       CRISIS HOUSE
# 36                                       CRISIS HOUSE
# 37            INTERFAITH SHELTER NETWORK OF SAN DIEGO
# 38         EAST COUNTY CHAMBER OF COMMERCE FOUNDATION
# 39                                       CRISIS HOUSE
# 40                                       CRISIS HOUSE
# 41                                       CRISIS HOUSE
# 42                                       CRISIS HOUSE
# 43                                   SANTEE FOOD BANK
# 44                                      ALPHA PROJECT
# 45                                     OPERATION HOPE
# 46                              NORTH COUNTY LIFELINE
# 47                            WOMEN S RESOURCE CENTER
# 48                            WOMEN S RESOURCE CENTER
# 49                    URBAN CORPS OF SAN DIEGO COUNTY
# 50                           URBAN CORPS OF SAN DIEGO
# 51                                   ROCKET JOHNS INC
# 52                                    MEALS ON WHEELS
# 53                     LEGAL AID SOCIETY OF SAN DIEGO
# 54                      INTERFAITH COMMUNITY SERVICES
# 55                      INTERFAITH COMMUNITY SERVICES
# 57                      INTERFAITH COMMUNITY SERVICES
#
#                                             Program_y       Start        Stop  \
# 0                               TAKE BACK THE STREETS    06/01/21    06/30/22
# 1                                   CV  FOOD SERVICES    11/16/21    11/16/22
# 2                CV  TRANSITIONAL EMPLOYMENT SERVICES    12/07/21    12/07/23
# 3                      CV  DOMESTIC VIOLENCE SERVICES    04/26/22    04/26/23
# 4                        20212022 MOBILE MEDICAL UNIT    06/01/21    06/30/22
# 5                                       WORK FOR HOPE    06/01/21    06/30/22
# 6                        FOOD 4 KIDS BACKPACK PROGRAM    06/01/21    06/30/22
# 7                   FAMILY VIOLENCE TREATMENT PROGRAM    06/01/21    06/30/22
# 10                                   SHELTER SERVICES    05/01/21    05/01/24
# 11                                           SERVICES    07/01/21    06/30/23
# 12                                  OUTREACH SERVICES    09/01/20    08/31/21
# 13                                    A WAY BACK HOME     10/6/20    10/05/21
# 14                                RAILING REPLACEMENT    07/01/18    06/30/21
# 15                                   SECURITY FENCING    07/01/19    06/30/21
# 16               ROTATIONAL EMERGENCY SHELTER PROGRAM    07/01/20    06/30/21
# 17       IMPROVED FENCING AT 1034 N MAGNOLIA FACILITY    07/01/18    06/30/19
# 18                                  HVAC REPLACEMENTS    07/01/19    06/30/20
# 19                                  EMERGENCY SHELTER    05/13/20    06/30/21
# 20                        CVOUTREACH SUPPORT SERVICES    06/01/22    03/31/23
# 21                              MOTEL VOUCHER PROGRAM    05/13/20    06/30/21
# 22           QUARANTINED ENTRY INTO EMERGENCY SHELTER    12/16/20    12/30/21
# 27    188809                                        PLHA
# 28    338000                                      CDBGCV
# 29     30000                                         NaN
# 30      3132                                         NaN
# 31  36424585                                        HOME
# 32  18814742                                        HOME
# 33    125000                          FISCAL YEAR 202021
# 34      6852                                        CDBG
# 36     15000                                      CDBGCV
# 37    168976                                      CDBGCV
# 38     50000                                      CDBGCV
# 39      5200                                        CDBG
# 40      5000                                        CDBG
# 41      5000                                        CDBG
# 42     66600                                        CDBG
# 43     14000                                        CDBG
# 44     50000                                        CDBG
# 45      2998                                        CDBG
# 46    255000                                      CDBGCV
# 47    148996                                        CDBG
# 48      1200                                        CDBG
# 49     35000                                         NaN
# 50    199000                                 CITY BUDGET
# 51    200000                                         NaN
# 52    10 000                                        CDBG
# 53     20550                                        CDBG
# 54    244944                                         NaN
# 55     31242                                         NaN
# 57     30000                                      CDBGCV

# %%
# Assuming you have already loaded the merged DataFrame as 'merged'.

for i in range(merged.shape[0]):
    # Compare 'Grantor' column
    similarity = fuzz.ratio(merged['Grantor_y'].iloc[i], merged['Grantor_x'].iloc[i])
    if similarity >= 80:
        merged['Grantor_y'].iloc[i] = merged['Grantor_x'].iloc[i]

    # Compare 'Grantee' column
    similarity = fuzz.ratio(merged['Grantee_y'].iloc[i], merged['Grantee_x'].iloc[i])
    if similarity >= 80:
        merged['Grantee_y'].iloc[i] = merged['Grantee_x'].iloc[i]

    # Compare 'Program' column
    similarity = fuzz.ratio(merged['Program_y'].iloc[i], merged['Program_x'].iloc[i])
    if similarity >= 80:
        merged['Program_y'].iloc[i] = merged['Program_x'].iloc[i]

#     # Compare 'Amount' column (if applicable)
#     if pd.notna(merged['Amount_y'].iloc[i]) and pd.notna(merged['Amount_x'].iloc[i]):
#         similarity = fuzz.ratio(str(merged['Amount_y'].iloc[i]), str(merged['Amount_x'].iloc[i]))
#         if similarity >= 80:
#             merged['Amount_y'].iloc[i] = merged['Amount_x'].iloc[i]

    # Compare 'Funding Source' column
    if pd.notna(merged['Funding Source_y'].iloc[i]) and pd.notna(merged['Funding Source_x'].iloc[i]):
        similarity = fuzz.ratio(merged['Funding Source_y'].iloc[i], merged['Funding Source_x'].iloc[i])
        if similarity >= 80:
            merged['Funding Source_y'].iloc[i] = merged['Funding Source_x'].iloc[i]

# 'merged' now contains the modified values after comparing with itself
merged
# Out:
#    Train/Test              Grantor_x  \
# 0       Train    CITY OF CHULA VISTA
# 1       Train    CITY OF CHULA VISTA
# 2       Train    CITY OF CHULA VISTA
# 3       Train    CITY OF CHULA VISTA
# 4       Train    CITY OF CHULA VISTA
# 5       Train    CITY OF CHULA VISTA
# 6       Train    CITY OF CHULA VISTA
# 7       Train    CITY OF CHULA VISTA
# 10      Train       CITY OF CORONADO
# 11      Train        CITY OF DEL MAR
# 12      Train       CITY OF EL CAJON
# 13      Train       CITY OF EL CAJON
# 14      Train       CITY OF EL CAJON
# 15      Train       CITY OF EL CAJON
# 16      Train       CITY OF EL CAJON
# 17      Train       CITY OF EL CAJON
# 18      Train       CITY OF EL CAJON
# 19      Train       CITY OF EL CAJON
# 20      Train       CITY OF EL CAJON
# 21      Train       CITY OF EL CAJON
# 22      Train      CITY OF ESCONDIDO
# 23      Train      CITY OF ESCONDIDO
# 24       Test      CITY OF ESCONDIDO
# 25      Train        CITY OF LA MESA
# 26      Train        CITY OF LA MESA
# 27      Train        CITY OF LA MESA
# 28      Train        CITY OF LA MESA
# 29      Train    CITY OF LEMON GROVE
# 30      Train  CITY OF NATIONAL CITY
# 31      Train  CITY OF NATIONAL CITY
# 32      Train  CITY OF NATIONAL CITY
# 33      Train     CITY OF SAN MARCOS
# 34      Train         CITY OF SANTEE
# 36      Train         CITY OF SANTEE
# 37      Train         CITY OF SANTEE
# 38      Train         CITY OF SANTEE
# 39      Train         CITY OF SANTEE
# 40      Train         CITY OF SANTEE
# 41      Train         CITY OF SANTEE
# 42      Train         CITY OF SANTEE
# 43      Train         CITY OF SANTEE
# 44      Train          CITY OF VISTA
# 45      Train          CITY OF VISTA
# 46      Train          CITY OF VISTA
# 47       Test       CITY OF CARLSBAD
# 48       Test       CITY OF CARLSBAD
# 49       Test       CITY OF CARLSBAD
# 50       Test       CITY OF CARLSBAD
# 51       Test       CITY OF CARLSBAD
# 52       Test       CITY OF CARLSBAD
# 53       Test       CITY OF CARLSBAD
# 54       Test       CITY OF CARLSBAD
# 55       Test       CITY OF CARLSBAD
# 57       Test      CITY OF ENCINITAS
#
#                                             Grantee_x  \
# 0                                       ALPHA PROJECT
# 1              JACOBS AND CUSHMAN SAN DIEGO FOOD BANK
# 2                                       ALPHA PROJECT
# 3                                                SBCS
# 4                  FAMILY HEALTH CENTERS OF SAN DIEGO
# 5   MCALISTER INSTITUTE FOR TREATMENT AND EDUCATIO...
# 6                 JACOBS  CUSHMAN SAN DIEGO FOOD BANK
# 7                                                SBCS
# 10                         ST VINCENT DE PAUL VILLAGE
# 11      SAN DIEGO REGIONAL TASK FORCE ON THE HOMELESS
# 12                                         HOME START
# 13                                 THE SALVATION ARMY
# 14             EAST COUNTY TRANSITIONAL LIVING CENTER
# 15             EAST COUNTY TRANSITIONAL LIVING CENTER
# 16                      INTERFAITH COMMUNITY SERVICES
# 17                                       CRISIS HOUSE
# 18                                       CRISIS HOUSE
# 19             EAST COUNTY TRANSITIONAL LIVING CENTER
# 20                                         HOME START
# 21                                         HOME START
# 22                      INTERFAITH COMMUNITY SERVICES
# 23                      INTERFAITH COMMUNITY SERVICES
# 24                      INTERFAITH COMMUNITY SERVICES
# 25                                         HOME START
# 26                      PEOPLE ASSISTING THE HOMELESS
# 27    DEPARTMENT OF HOUSING AND COMMUNITY DEVELOPMENT
# 28                                         HOME START
# 29                                         HOME START
# 30       MCALISTER INSTITUTE FOR TREATMENT  EDUCATION
# 31                       SOUTH BAY COMMUNITY SERVICES
# 32                       SOUTH BAY COMMUNITY SERVICES
# 33                    ALLIANCE FOR REGIONAL SOLUTIONS
# 34                                       CRISIS HOUSE
# 36                                       CRISIS HOUSE
# 37            INTERFAITH SHELTER NETWORK OF SAN DIEGO
#
# 2   Alpha Project _CV - Transitional Employment Se...
# 3   SBCS_CV - Emergency Domestic Violence Services...
# 4   Family Health Centers of San Diego_2021-2022 M...
# 5   McAlister Institute for Treatment and Educatio...
# 6   Jacobs & Cushman San Diego Food Bank 2021-2022...
# 7   SBCS 2021-2022 Family Violence Treatment Progr...
# 10  St. Vincent de Paul Village Temporary Housing ...
# 11  San Diego Regional Task Force on the Homeless ...
# 12                Home Start    Outreach Services.txt
# 13      The Salvation Army     Supportive Service.txt
# 14  East County Transitional Living Center     Rai...
# 15  East County Transitional Living Center     Sec...
# 16  Interfaith Community Services     Rotational S...
# 17          Crisis House      Improve Fencing_OCR.txt
# 18             Crisis House     HVAC Replacements.txt
# 19  East County Transitional Living Center     Eme...
# 20  Home Start     CV - Outreach Support Services ...
# 21           Home Start     Motel Voucher Program.txt
# 22  Interfaith Community Services     CV - Quarant...
# 23  Interfaith Community Services July Outreach Se...
# 24  CDBG Emergency Shelter Subrecipient Agreement ...
# 25               Home Start     Rental Assistance.txt
# 26  People Assisting the Homeless      CV - Outrea...
# 27  Department of Housing and Community Developmen...
# 28  Home Start     CV - Housing Stability Services...
# 29                 City of Lemon Grove Home Start.txt
# 30  McAlister Institute for Treatment & Education ...
# 31  South Bay Community Services Tenant Based Rent...
# 32  South Bay Community Services Tenant Based Rent...
# 33  20 Alliance for Regional Solutions Shelter Ser...
# 34  Crisis House    Homelessness Prevention Case M...
# 36    Crisis House  CV - Rapid Rehousing Services.txt
# 37  Interfaith Shelter Network of San Diego   CV -...
# 38  East County Chamber of Commerce Interprovider ...
# 39               Crisis House Prevention Programs.txt
# 40           Crisis House Prevention Programs (1).txt
# 41           Crisis House Prevention Programs (2).txt
# 42    Crisis House  General Homelessness Services.txt
# 43       Santee Food Bank Emergency Food Supplies.txt
# 44                                  Alpha Project.txt
# 45                           OH Executed Contract.txt
# 46                      North County Lifeline RAP.txt
# 47            Womens_Resource_Center__2018-01-23_.txt
# 48                   Women_s_Resource_Center_2019.txt
# 49          Urban_Corps_of_San_Diego_County__2019.txt
# 50             Fully_Executed_UC_PW_contract_FY19.txt
# 51                           Rocket_John_Contract.txt
# 52                           Meals_on_Wheels_2019.txt
# 53    Legal_Aid_Society_of_San_Diego__2018-11-05_.txt
# 54  Interfaith_Community_Services_Inc__2018-06-01_...
# 55  Interfaith_Community_Services_Contract_FY2020-...
# 57       ICS - Amendment #2 (Executed) 10.11.2021.txt
#
#                                     Grantor_y  \
# 0                         CITY OF CHULA VISTA
# 1                         CITY OF CHULA VISTA
# 2                         CITY OF CHULA VISTA
# 3                         CITY OF CHULA VISTA
# 4                         CITY OF CHULA VISTA
# 5                         CITY OF CHULA VISTA
# 6                         CITY OF CHULA VISTA
# 7                         CITY OF CHULA VISTA
# 10                           CITY OF CORONADO
# 11                            CITY OF DEL MAR
# 12                           CITY OF EL CAJON
# 13                           CITY OF EL CAJON
# 14                           CITY OF EL CAJON
# 15                           CITY OF EL CAJON
# 16                           CITY OF EL CAJON
# 17                           CITY OF EL CAJON
# 18                           CITY OF EL CAJON
# 19                           CITY OF EL CAJON
# 20                           CITY OF EL CAJON
# 21                           CITY OF EL CAJON
# 22                          CITY OF ESCONDIDO
# 23                          CITY OF ESCONDIDO
# 24                          CITY OF ESCONDIDO
# 25                            CITY OF LA MESA
# 26                            CITY OF LA MESA
# 27  CALIFORNIA DEPARTMENT OF GENERAL SERVICES
# 28                            CITY OF LA MESA
# 29                        CITY OF LEMON GROVE
# 30                      CITY OF NATIONAL CITY
# 31                      CITY OF NATIONAL CITY
# 32                      CITY OF NATIONAL CITY
# 33                         CITY OF SAN MARCOS
# 34                             CITY OF SANTEE
# 36                             CITY OF SANTEE
# 37                             CITY OF SANTEE
# 38                             CITY OF SANTEE
# 39                             CITY OF SANTEE
# 40                             CITY OF SANTEE
# 41                             CITY OF SANTEE
# 42                             CITY OF SANTEE
# 43                             CITY OF SANTEE
# 44                              CITY OF VISTA
# 45                              CITY OF VISTA
# 46                              CITY OF VISTA
# 47                           CITY OF CARLSBAD
# 48                           CITY OF CARLSBAD
# 49                           CITY OF CARLSBAD
# 50                           CITY OF CARLSBAD
# 51                           CITY OF CARLSBAD
# 52                           CITY OF CARLSBAD
# 53                           CITY OF CARLSBAD
# 54                           CITY OF CARLSBAD
# 55                           CITY OF CARLSBAD
# 57                          CITY OF ENCINITAS
#
#                                             Grantee_y  \
# 0                                       ALPHA PROJECT
# 1              JACOBS AND CUSHMAN SAN DIEGO FOOD BANK
# 2                                       ALPHA PROJECT
# 3                                                SBCS
# 4                  FAMILY HEALTH CENTERS OF SAN DIEGO
# 5   MCALISTER INSTITUTE FOR TREATMENT AND EDUCATIO...
# 6                 JACOBS  CUSHMAN SAN DIEGO FOOD BANK
# 7                                                SBCS
# 10                         ST VINCENT DE PAUL VILLAGE
# 11      SAN DIEGO REGIONAL TASK FORCE ON THE HOMELESS
# 12                                         HOME START
# 13                                 THE SALVATION ARMY
# 14             EAST COUNTY TRANSITIONAL LIVING CENTER
# 15             EAST COUNTY TRANSITIONAL LIVING CENTER
# 16            INTERFAITH SHELTER NETWORK OF SAN DIEGO
# 17                                       CRISIS HOUSE
# 18                                       CRISIS HOUSE
# 19             EAST COUNTY TRANSITIONAL LIVING CENTER
# 20                                         HOME START
# 21                                         HOME START
# 22                      INTERFAITH COMMUNITY SERVICES
# 23                      INTERFAITH COMMUNITY SERVICES
# 24                      INTERFAITH COMMUNITY SERVICES
# 25                                         HOME START
# 26                      PEOPLE ASSISTING THE HOMELESS
# 27                                    CITY OF LA MESA
# 28                                         HOME START
# 29                                         HOME START
# 30       MCALISTER INSTITUTE FOR TREATMENT  EDUCATION
# 31                       SOUTH BAY COMMUNITY SERVICES
# 32                       SOUTH BAY COMMUNITY SERVICES
# 33                    ALLIANCE FOR REGIONAL SOLUTIONS
# 34                                       CRISIS HOUSE
# 36                                       CRISIS HOUSE
# 37            INTERFAITH SHELTER NETWORK OF SAN DIEGO
# 38                    EAST COUNTY CHAMBER OF COMMERCE
# 39                                       CRISIS HOUSE
# 40                                       CRISIS HOUSE
# 41                                       CRISIS HOUSE
# 42                                       CRISIS HOUSE
# 43                                   SANTEE FOOD BANK
# 44                                      ALPHA PROJECT
# 45                                     OPERATION HOPE
# 46                              NORTH COUNTY LIFELINE
# 47                             WOMENS RESOURCE CENTER
# 48                             WOMENS RESOURCE CENTER
# 40                                PREVENTION SERVICES      7/1/18    06/30/19
# 41                                PREVENTION SERVICES      7/1/17    06/30/20
# 42                         DOMESTIC VIOLENCE SERVICES    11/19/21    06/30/22
# 43                            EMERGENCY FOOD PROGRAMS    06/01/18    06/30/20
# 44                              HOMELESSNESS SERVICES    07/01/19    06/30/21
# 45                     CV  EMERGENCY SHELTER SERVICES    07/01/19    06/30/20
# 46                                   RENTAL ASSITANCE    07/01/20    06/30/22
# 47                                  OUTREACH SERVICES    07/01/17    06/30/18
# 48                                   GRANTEE SERVICES    07/01/18    06/30/20
# 49               NEIGHBORHOOD REVITALIZATION SERVICES    06/19/20    06/19/22
# 50          ABANDON ITEMS AND LITTER REMOVAL SERVICES    09/17/18    09/15/20
# 51                    PORTA POTTY RENTAL AND SERVICES    06/01/17    06/01/21
# 52                                  OUTREACH SERVICES    07/20/18    06/30/20
# 53                                     BASIC SERVICES    07/01/18    06/30/19
# 54                           CASE MANAGEMENT SERVICES    07/01/19    06/30/20
# 55                       OUTREACH AND CASE MANAGEMENT    07/01/20    06/30/21
# 57                              CV  EMERGENCY SHELTER    07/01/21    06/30/22
#
#     Amount_y                            Funding Source_y
# 0      30000                                        CDBG
# 1    5743525                                        ARPA
# 2     100000                                        ARPA
# 3     234475                                        ARPA
# 4      23000                                        CDBG
# 5     203986                                        CDBG
# 6      50000                                        CDBG
# 7      50000                                        CDBG
# 10    287401  AFFORDABLE HOUSING FUND ACCOUNT 2664908030
# 11      4000                   COMMUNITY SUPPORT PROGRAM
# 12    200000                                      LMIHAF
# 13     10700                                 CITY BUDGET
# 14     25000                                        CDBG
# 15     25000                                        CDBG
# 16     30000                                        CDBG
# 17    192525                                        CDBG
# 18    485000                                        CDBG
# 19    185294                                      CDBGCV
# 20    155000                                        CDBG
# 21     45000                                      CDBGCV
# 22    552803                                       ESGCV
# 23     78335                                       ESGCV
# 24     15000                                        CDBG
# 25     75000                                         NaN
# 26    262416                                      CDBGCV
# 27    188809                                        PLHA
# 28    338000                                      CDBGCV
# 29     30000                                         NaN
# 30      3132                                         NaN
# 31  36424585                                        HOME
# 32  18814742                                        HOME
# 33    125000                          FISCAL YEAR 202021
# 34      6852                                        CDBG
# 36     15000                                      CDBGCV
# 37    168976                                      CDBGCV
# 38     50000                                      CDBGCV
# 39      5200                                        CDBG
# 40      5000                                        CDBG
# 41      5000                                        CDBG
# 42     66600                                        CDBG
# 43     14000                                        CDBG
# 44     50000                                        CDBG
# 45      2998                                        CDBG
# 46    255000                                      CDBGCV
# 47    148996                                        CDBG
# 48      1200                                        CDBG
# 49     35000                                         NaN
# 50    199000                                 CITY BUDGET
# 51    200000                                         NaN
# 52    10 000                                        CDBG
# 53     20550                                        CDBG
# 54    244944                                         NaN
# 55     31242                                         NaN
# 57     30000                                      CDBGCV

# %%
def calculate_accuracy_rates(merged):
    # Calculate accuracy rate for each column
    accuracy_rates = {}

    # Compare 'Grantor' columns
    grantor_accuracy = np.where(merged['Grantor_x'] == merged['Grantor_y'], 1, 0)
    accuracy_rates['Grantor'] = sum(grantor_accuracy) / len(merged)

    # Compare 'Grantee_x' and 'Grantee_y' columns
    grantee_accuracy = np.where(merged['Grantee_x'] == merged['Grantee_y'], 1, 0)
    accuracy_rates['Grantee'] = sum(grantee_accuracy) / len(merged)

    # Compare 'Program_x' and 'Program_y' columns
    program_accuracy = np.where(merged['Program_x'] == merged['Program_y'], 1, 0)
    accuracy_rates['Program'] = sum(program_accuracy) / len(merged)

    # Compare 'Date' and 'Start' columns
    date_accuracy = np.where(merged['Date'] == merged['Start'], 1, 0)
    accuracy_rates['Date'] = sum(date_accuracy) / len(merged)

    # Compare 'EndDate' and 'Stop' columns
    enddate_accuracy = np.where(merged['EndDate'] == merged['Stop'], 1, 0)
    accuracy_rates['EndDate'] = sum(enddate_accuracy) / len(merged)

    # Compare 'Amount_x' and 'Amount_y' columns
    amount_accuracy = np.where(merged['Amount_x'] == merged['Amount_y'], 1, 0)
    accuracy_rates['Amount'] = sum(amount_accuracy) / len(merged)

    # Compare 'Funding Source_x' and 'Funding Source_y' columns
    funding_accuracy = np.where(merged['Funding Source_x'] == merged['Funding Source_y'], 1, 0)
    accuracy_rates['Funding Source'] = sum(funding_accuracy) / len(merged)

    return accuracy_rates

accuracy_rates = calculate_accuracy_rates(merged)

# Print the accuracy rates
for column, accuracy in accuracy_rates.items():
    print(f"Accuracy rate for '{column}': {accuracy}")
# Out:
# Accuracy rate for 'Grantor': 0.9814814814814815
# Accuracy rate for 'Grantee': 0.7777777777777778
# Accuracy rate for 'Program': 0.42592592592592593
# Accuracy rate for 'Date': 0.5185185185185185
# Accuracy rate for 'EndDate': 0.6111111111111112
# Accuracy rate for 'Amount': 0.46296296296296297
# Accuracy rate for 'Funding Source': 0.7407407407407407

# %%
def find_inaccurate_rows(merged_df, threshold=60):
    inaccurate_rows = []
    error_columns = []

    for i in range(merged_df.shape[0]):
        # Compare 'Grantor' column
        similarity_grantor = fuzz.ratio(merged_df['Grantor_y'].iloc[i], merged_df['Grantor_x'].iloc[i])

        # Compare 'Grantee' column
        similarity_grantee = fuzz.ratio(merged_df['Grantee_y'].iloc[i], merged_df['Grantee_x'].iloc[i])

        # Compare 'Program' column
        similarity_program = fuzz.ratio(merged_df['Program_y'].iloc[i], merged_df['Program_x'].iloc[i])

        # Check if the name of 'Program_x' is in 'Program_y'
        if merged_df['Program_x'].iloc[i] in merged_df['Program_y'].iloc[i] or \
           merged_df['Program_y'].iloc[i] in merged_df['Program_x'].iloc[i]:
            similarity_program = 100
        
        # Compare 'Amount' column (if applicable)
        if pd.notna(merged_df['Amount_y'].iloc[i]) and pd.notna(merged_df['Amount_x'].iloc[i]):
            similarity_amount = fuzz.ratio(str(merged_df['Amount_y'].iloc[i]), str(merged_df['Amount_x'].iloc[i]))
        else:
            similarity_amount = 0  # If any of the 'Amount' values is NaN, set similarity to 0

        # Compare 'Funding Source' column
        if pd.notna(merged_df['Funding Source_y'].iloc[i]) and pd.notna(merged_df['Funding Source_x'].iloc[i]):
            similarity_funding = fuzz.ratio(merged_df['Funding Source_y'].iloc[i], merged_df['Funding Source_x'].iloc[i])
        else:
            similarity_funding = 100  # If any of the 'Funding Source' values is NaN, set similarity to 0

        if pd.isna(merged_df['Funding Source_x'].iloc[i]) or str(merged_df['Funding Source_x'].iloc[i]) == 'nan':
            similarity_funding = 100

        # Compare 'Date' and 'Start' columns
        date_start_similarity = 100
        if pd.notna(merged_df['Date'].iloc[i]) and pd.notna(merged_df['Start'].iloc[i]):
            date_similarity = pd.to_datetime(merged_df['Date'].iloc[i]).date() == pd.to_datetime(merged_df['Start'].iloc[i]).date()
            date_start_similarity = 100 if date_similarity else 0

        # Compare 'EndDate' and 'Stop' columns
        enddate_stop_similarity = 100
        if pd.notna(merged_df['EndDate'].iloc[i]) and pd.notna(merged_df['Stop'].iloc[i]):
            enddate_similarity = pd.to_datetime(merged_df['EndDate'].iloc[i]).date() == pd.to_datetime(merged_df['Stop'].iloc[i]).date()
            enddate_stop_similarity = 100 if enddate_similarity else 0

        # Check which columns caused the accuracy errors
        error_cols = []
        if similarity_grantor < 100:
            error_cols.append('Grantor')
        if similarity_grantee < 50:
            error_cols.append('Grantee')
        if similarity_program < 30:
            error_cols.append('Program')
        if similarity_amount < 90:
            error_cols.append('Amount')
        if similarity_funding < threshold:
            error_cols.append('Funding Source')
        if date_start_similarity < 100:
            error_cols.append('Start')
        if enddate_stop_similarity < 100:
            error_cols.append('Stop')

        # Append the row index and error columns to the lists
        if error_cols:
            inaccurate_rows.append(i)
            error_columns.append(error_cols)

    # Create a new DataFrame containing only the inaccurate rows
    inaccurate_df = merged_df.iloc[inaccurate_rows].reset_index(drop=True)

    # Add the 'Error Columns' column to indicate which columns caused the accuracy errors
    inaccurate_df.insert(0, 'Error Columns', error_columns)

    return inaccurate_df

inaccurate_data = find_inaccurate_rows(merged)
inaccurate_data
# Out:
#                                      Error Columns Train/Test  \
# 0                                         [Amount]      Train
# 1                                         [Amount]      Train
# 2                                           [Stop]      Train
# 3                                         [Amount]      Train
# 4                                         [Amount]      Train
# 5                                         [Amount]      Train
# 6                                         [Amount]      Train
# 7                                         [Amount]      Train
# 8                                         [Amount]      Train
# 9   [Program, Amount, Funding Source, Start, Stop]      Train
# 10                                         [Start]      Train
# 11                                          [Stop]      Train
# 12                                         [Start]      Train
# 13                                        [Amount]      Train
# 14                                         [Start]      Train
# 15                                 [Amount, Start]       Test
# 16                                   [Start, Stop]      Train
# 17                                         [Start]      Train
# 18       [Grantor, Grantee, Funding Source, Start]      Train
# 19                                         [Start]      Train
# 20                                         [Start]      Train
# 21                                 [Amount, Start]      Train
# 22                           [Amount, Start, Stop]      Train
# 23                                          [Stop]      Train
# 24                 [Amount, Funding Source, Start]      Train
# 25                                        [Amount]      Train
# 26                                 [Amount, Start]      Train
# 27                                        [Amount]      Train
# 28                                          [Stop]      Train
# 29                                        [Amount]      Train
# 30                                 [Amount, Start]      Train
# 31                           [Amount, Start, Stop]      Train
# 32                        [Program, Amount, Start]      Train
# 33                          [Funding Source, Stop]      Train
# 34                                 [Amount, Start]       Test
# 35                                   [Start, Stop]       Test
# 36                        [Amount, Funding Source]       Test
# 37                                   [Start, Stop]       Test
# 38                                         [Start]       Test
# 39                                  [Amount, Stop]       Test
# 40                                   [Start, Stop]       Test
# 41                                          [Stop]       Test
# 42                                 [Amount, Start]       Test
#
#                 Grantor_x                                          Grantee_x  \
# 0     CITY OF CHULA VISTA                                      ALPHA PROJECT
# 1     CITY OF CHULA VISTA             JACOBS AND CUSHMAN SAN DIEGO FOOD BANK
# 2     CITY OF CHULA VISTA                                      ALPHA PROJECT
# 3     CITY OF CHULA VISTA                                               SBCS
# 4     CITY OF CHULA VISTA                 FAMILY HEALTH CENTERS OF SAN DIEGO
# 5     CITY OF CHULA VISTA  MCALISTER INSTITUTE FOR TREATMENT AND EDUCATIO...
# 6     CITY OF CHULA VISTA                JACOBS  CUSHMAN SAN DIEGO FOOD BANK
# 7     CITY OF CHULA VISTA                                               SBCS
# 8        CITY OF CORONADO                         ST VINCENT DE PAUL VILLAGE
# 9        CITY OF EL CAJON                                 THE SALVATION ARMY
# 10       CITY OF EL CAJON             EAST COUNTY TRANSITIONAL LIVING CENTER
# 11       CITY OF EL CAJON             EAST COUNTY TRANSITIONAL LIVING CENTER
# 12       CITY OF EL CAJON                      INTERFAITH COMMUNITY SERVICES
# 13       CITY OF EL CAJON                                       CRISIS HOUSE
# 14      CITY OF ESCONDIDO                      INTERFAITH COMMUNITY SERVICES
# 15      CITY OF ESCONDIDO                      INTERFAITH COMMUNITY SERVICES
# 16        CITY OF LA MESA                                         HOME START
# 17        CITY OF LA MESA                      PEOPLE ASSISTING THE HOMELESS
# 18        CITY OF LA MESA    DEPARTMENT OF HOUSING AND COMMUNITY DEVELOPMENT
# 19        CITY OF LA MESA                                         HOME START
# 20    CITY OF LEMON GROVE                                         HOME START
# 21  CITY OF NATIONAL CITY       MCALISTER INSTITUTE FOR TREATMENT  EDUCATION
# 22  CITY OF NATIONAL CITY                       SOUTH BAY COMMUNITY SERVICES
# 23  CITY OF NATIONAL CITY                       SOUTH BAY COMMUNITY SERVICES
# 24     CITY OF SAN MARCOS                    ALLIANCE FOR REGIONAL SOLUTIONS
# 25         CITY OF SANTEE                    EAST COUNTY CHAMBER OF COMMERCE
# 26         CITY OF SANTEE                                       CRISIS HOUSE
# 27         CITY OF SANTEE                                       CRISIS HOUSE
# 28         CITY OF SANTEE                                       CRISIS HOUSE
# 29         CITY OF SANTEE                                       CRISIS HOUSE
# 30         CITY OF SANTEE                                   SANTEE FOOD BANK
# 31          CITY OF VISTA                                      ALPHA PROJECT
# 32          CITY OF VISTA                                     OPERATION HOPE
# 33          CITY OF VISTA                              NORTH COUNTY LIFELINE
# 34       CITY OF CARLSBAD                             WOMENS RESOURCE CENTER
# 35       CITY OF CARLSBAD                                        URBAN CORPS
# 36       CITY OF CARLSBAD                                        URBAN CORPS
# 37       CITY OF CARLSBAD                                       ROCKET JOHNS
# 38       CITY OF CARLSBAD                                    MEALS ON WHEELS
# 39       CITY OF CARLSBAD                                  LEGAL AID SOCIETY
# 40       CITY OF CARLSBAD                      INTERFAITH COMMUNITY SERVICES
# 41       CITY OF CARLSBAD                      INTERFAITH COMMUNITY SERVICES
# 35          Urban_Corps_of_San_Diego_County__2019.txt
# 36             Fully_Executed_UC_PW_contract_FY19.txt
# 37                           Rocket_John_Contract.txt
# 38                           Meals_on_Wheels_2019.txt
# 39    Legal_Aid_Society_of_San_Diego__2018-11-05_.txt
# 40  Interfaith_Community_Services_Inc__2018-06-01_...
# 41  Interfaith_Community_Services_Contract_FY2020-...
# 42       ICS - Amendment #2 (Executed) 10.11.2021.txt
#
#                                     Grantor_y  \
# 0                         CITY OF CHULA VISTA
# 1                         CITY OF CHULA VISTA
# 2                         CITY OF CHULA VISTA
# 3                         CITY OF CHULA VISTA
# 4                         CITY OF CHULA VISTA
# 5                         CITY OF CHULA VISTA
# 6                         CITY OF CHULA VISTA
# 7                         CITY OF CHULA VISTA
# 8                            CITY OF CORONADO
# 9                            CITY OF EL CAJON
# 10                           CITY OF EL CAJON
# 11                           CITY OF EL CAJON
# 12                           CITY OF EL CAJON
# 13                           CITY OF EL CAJON
# 14                          CITY OF ESCONDIDO
# 15                          CITY OF ESCONDIDO
# 16                            CITY OF LA MESA
# 17                            CITY OF LA MESA
# 18  CALIFORNIA DEPARTMENT OF GENERAL SERVICES
# 19                            CITY OF LA MESA
# 20                        CITY OF LEMON GROVE
# 21                      CITY OF NATIONAL CITY
# 22                      CITY OF NATIONAL CITY
# 23                      CITY OF NATIONAL CITY
# 24                         CITY OF SAN MARCOS
# 25                             CITY OF SANTEE
# 26                             CITY OF SANTEE
# 27                             CITY OF SANTEE
# 28                             CITY OF SANTEE
# 29                             CITY OF SANTEE
# 30                             CITY OF SANTEE
# 31                              CITY OF VISTA
# 32                              CITY OF VISTA
# 33                              CITY OF VISTA
# 34                           CITY OF CARLSBAD
# 35                           CITY OF CARLSBAD
# 36                           CITY OF CARLSBAD
# 37                           CITY OF CARLSBAD
# 38                           CITY OF CARLSBAD
# 39                           CITY OF CARLSBAD
# 40                           CITY OF CARLSBAD
# 41                           CITY OF CARLSBAD
# 42                          CITY OF ENCINITAS
#
#                                             Grantee_y  \
# 0                                       ALPHA PROJECT
# 1              JACOBS AND CUSHMAN SAN DIEGO FOOD BANK
# 2                                       ALPHA PROJECT
# 3                                                SBCS
# 4                  FAMILY HEALTH CENTERS OF SAN DIEGO
# 5   MCALISTER INSTITUTE FOR TREATMENT AND EDUCATIO...
# 6                 JACOBS  CUSHMAN SAN DIEGO FOOD BANK
# 7                                                SBCS
# 8                          ST VINCENT DE PAUL VILLAGE
# 9                                      SALVATION ARMY
# 10             EAST COUNTY TRANSITIONAL LIVING CENTER
# 11             EAST COUNTY TRANSITIONAL LIVING CENTER
# 12            INTERFAITH SHELTER NETWORK OF SAN DIEGO
# 13                                       CRISIS HOUSE
# 14                      INTERFAITH COMMUNITY SERVICES
# 15                      INTERFAITH COMMUNITY SERVICES
# 16                                         HOME START
# 17                      PEOPLE ASSISTING THE HOMELESS
# 18                                    CITY OF LA MESA
# 19                                     HOME START INC
# 20                                         HOME START
# 21   MCALISTER INSTITUTE FOR TREATMENT  EDUCATION INC
# 22                       SOUTH BAY COMMUNITY SERVICES
# 23                       SOUTH BAY COMMUNITY SERVICES
# 31                         HOMELESSNESS SERVICES    07/01/19    06/30/21
# 32                CV  EMERGENCY SHELTER SERVICES    07/01/19    06/30/20
# 33                              RENTAL ASSITANCE    07/01/20    06/30/22
# 34                              GRANTEE SERVICES    07/01/18    06/30/20
# 35          NEIGHBORHOOD REVITALIZATION SERVICES    06/19/20    06/19/22
# 36     ABANDON ITEMS AND LITTER REMOVAL SERVICES    09/17/18    09/15/20
# 37               PORTA POTTY RENTAL AND SERVICES    06/01/17    06/01/21
# 38                             OUTREACH SERVICES    07/20/18    06/30/20
# 39                                BASIC SERVICES    07/01/18    06/30/19
# 40                      CASE MANAGEMENT SERVICES    07/01/19    06/30/20
# 41         OUTREACH AND CASE MANAGEMENT SERVICES    07/01/20    06/30/21
# 42                         CV  EMERGENCY SHELTER    07/01/21    06/30/22
#
#     Amount_y                            Funding Source_y
# 0      30000                                        CDBG
# 1    5743525                                        ARPA
# 2     100000                                        ARPA
# 3     234475                                        ARPA
# 4      23000                                        CDBG
# 5     203986                                        CDBG
# 6      50000                                        CDBG
# 7      50000                                        CDBG
# 8     287401  AFFORDABLE HOUSING FUND ACCOUNT 2664908030
# 9      10700                                 CITY BUDGET
# 10     25000                                        CDBG
# 11     25000                                        CDBG
# 12     30000                                        CDBG
# 13    192525                                        CDBG
# 14    552803                                       ESGCV
# 15     15000                                        CDBG
# 16     75000                                         NaN
# 17    262416                                      CDBGCV
# 18    188809                                        PLHA
# 19    338000                                      CDBGCV
# 20     30000                                         NaN
# 21      3132                                         NaN
# 22  36424585                                        HOME
# 23  18814742                                        HOME
# 24    125000                          FISCAL YEAR 202021
# 25     50000                                      CDBGCV
# 26      5200                                        CDBG
# 27      5000                                        CDBG
# 28      5000                                        CDBG
# 29     66600                                        CDBG
# 30     14000                                        CDBG
# 31     50000                                        CDBG
# 32      2998                                        CDBG
# 33    255000                                      CDBGCV
# 34      1200                                        CDBG
# 35     35000                                         NaN
# 36    199000                                 CITY BUDGET
# 37    200000                                         NaN
# 38    10 000                                        CDBG
# 39     20550                                        CDBG
# 40    244944                                         NaN
# 41     31242                                         NaN
# 42     30000                                      CDBGCV

# %%
# alpha project_CV - transitional employment... .txt end date 11/16/22?
# The Salvation Army Supportive Service.txt amount = $10,000?

# %%
accuracy_rates_inaccurate = calculate_accuracy_rates(inaccurate_data)

# Print the accuracy rates for inaccurate_data
for column, accuracy in accuracy_rates_inaccurate.items():
    print(f"Accuracy rate for '{column}': {accuracy}")
# Out:
# Accuracy rate for 'Grantor': 0.9767441860465116
# Accuracy rate for 'Grantee': 0.7441860465116279
# Accuracy rate for 'Program': 0.3953488372093023
# Accuracy rate for 'Date': 0.4186046511627907
# Accuracy rate for 'EndDate': 0.5581395348837209
# Accuracy rate for 'Amount': 0.37209302325581395
# Accuracy rate for 'Funding Source': 0.6976744186046512

# %%
filter_by_grantor = lambda x: 'Program' in x['Error Columns']

# Use the lambda function with DataFrame's apply method to filter rows
filtered_data_grantor = inaccurate_data[inaccurate_data.apply(filter_by_grantor, axis=1)]

# Display the filtered DataFrame
filtered_data_grantor
# Out:
#                                   Error Columns Train/Test          Grantor_x  \
# 8                                     [Program]      Train    CITY OF DEL MAR
# 9             [Program, Amount, Funding Source]      Train   CITY OF EL CAJON
# 13  [Grantor, Grantee, Program, Funding Source]      Train    CITY OF LA MESA
# 18                                    [Program]      Train     CITY OF SANTEE
# 19                                    [Program]      Train     CITY OF SANTEE
# 20                            [Program, Amount]      Train     CITY OF SANTEE
# 26                            [Program, Amount]      Train      CITY OF VISTA
# 28                                    [Program]       Test   CITY OF CARLSBAD
# 29                            [Program, Amount]       Test   CITY OF CARLSBAD
# 32                    [Program, Funding Source]       Test   CITY OF CARLSBAD
# 33                                    [Program]       Test   CITY OF CARLSBAD
# 34                            [Program, Amount]       Test   CITY OF CARLSBAD
# 37            [Program, Amount, Funding Source]       Test  CITY OF ENCINITAS
#
#                                           Grantee_x  \
# 8     SAN DIEGO REGIONAL TASK FORCE ON THE HOMELESS
# 9                                THE SALVATION ARMY
# 13  DEPARTMENT OF HOUSING AND COMMUNITY DEVELOPMENT
# 18                                     CRISIS HOUSE
# 19          INTERFAITH SHELTER NETWORK OF SAN DIEGO
# 20                  EAST COUNTY CHAMBER OF COMMERCE
# 26                                   OPERATION HOPE
# 28                           WOMENS RESOURCE CENTER
# 29                           WOMENS RESOURCE CENTER
# 32                                     ROCKET JOHNS
# 33                                  MEALS ON WHEELS
# 34                                LEGAL AID SOCIETY
# 37                    INTERFAITH COMMUNITY SERVICES
#
#                                             Program_x       Date    EndDate  \
# 8                   ANNUAL POINTINTIME COUNT SERVICES   07/01/21   06/30/23
# 9                                  SUPPORTIVE SERVICE   05/16/19   10/05/22
# 13          GENERAL FUNDING FOR HOMELESSNESS SERVICES   09/03/21   06/30/30
# 18   HOMELESSNESS PREVENTION CASE MANAGEMENT SERVICES   09/04/20   06/30/21
# 19                              CV  RENTAL ASSISTANCE   12/31/20   07/30/21
# 20  INTERPROVIDER NETWORKING AND PROGRAM FACILITATION   03/22/21   07/30/21
# 26                                     OPERATION HOPE   07/01/18   06/30/20
# 28                          DOMESTIC VIOLENCE SHELTER   7/1/2017  6/30/2018
# 29                          MEAL DELIVERY FOR SENIORS   7/1/2019  6/30/2020
# 32                                    RESTROOM RENTAL  3/11/2020  3/11/2022
# 33                          MEAL DELIVERY FOR SENIORS   7/1/2019  6/30/2020
# 34          FAIR HOUSING AND TENANT LANDLORD SERVICES   07/01/18     6/2020
# 37   ALLIANCE FOR SOLUTIONS BRIDGE TO HOUSING NETWORK     7/1/18    6/30/22
#
#    Amount_x                                   Funding Source_x  \
# 8      4000                          COMMUNITY SUPPORT PROGRAM
# 9     40000              A WAY BACK HOME REUNIFICATION PROJECT
# 13   188809  PERMANENT LOCAL HOUSING ALLOCATION PLHA PROGRA...
# 18     6852                                               CDBG
# 19   168976                                             CDBGCV
# 20     5000                                             CDBGCV
# 26    50740                                               CDBG
# 28    14896                                               CDBG
# 29    10000                                               CDBG
# 32   200000                                                NaN
# 33    10000                                               CDBG
# 34    43294                                               CDBG
# 37   252017                                                NaN
#
#                                               text_id  \
# 8   San Diego Regional Task Force on the Homeless ...
# 9       The Salvation Army     Supportive Service.txt
# 13  Department of Housing and Community Developmen...
# 18  Crisis House    Homelessness Prevention Case M...
# 19  Interfaith Shelter Network of San Diego   CV -...
# 20  East County Chamber of Commerce Interprovider ...
# 26                           OH Executed Contract.txt
# 28            Womens_Resource_Center__2018-01-23_.txt
# 29                   Women_s_Resource_Center_2019.txt
# 32                           Rocket_John_Contract.txt
# 33                           Meals_on_Wheels_2019.txt
# 34    Legal_Aid_Society_of_San_Diego__2018-11-05_.txt
# 37       ICS - Amendment #2 (Executed) 10.11.2021.txt
#
#                                     Grantor_y  \
# 8                             CITY OF DEL MAR
# 9                            CITY OF EL CAJON
# 13  CALIFORNIA DEPARTMENT OF GENERAL SERVICES
# 18                             CITY OF SANTEE
# 19                             CITY OF SANTEE
# 20                             CITY OF SANTEE
# 26                              CITY OF VISTA
# 28                           CITY OF CARLSBAD
# 29                           CITY OF CARLSBAD
# 32                           CITY OF CARLSBAD
# 33                           CITY OF CARLSBAD
# 34                           CITY OF CARLSBAD
# 37                          CITY OF ENCINITAS
#
#                                         Grantee_y  \
# 8   SAN DIEGO REGIONAL TASK FORCE ON THE HOMELESS
# 9                                  SALVATION ARMY
# 13                                CITY OF LA MESA
# 18                                   CRISIS HOUSE
# 19        INTERFAITH SHELTER NETWORK OF SAN DIEGO
# 20     EAST COUNTY CHAMBER OF COMMERCE FOUNDATION
# 26                                 OPERATION HOPE
# 28                        WOMEN S RESOURCE CENTER
# 29                        WOMEN S RESOURCE CENTER
# 32                               ROCKET JOHNS INC
# 33                                MEALS ON WHEELS
# 34                 LEGAL AID SOCIETY OF SAN DIEGO
# 37                  INTERFAITH COMMUNITY SERVICES
#
#                                             Program_y       Start        Stop  \
# 8                                            SERVICES    07/01/21    06/30/23
# 9                                     A WAY BACK HOME     10/6/20    10/05/21
# 13                 PERMANENT LOCAL HOUSING ALLOCATION  06/30/2030  06/30/2030
# 18                                PREVENTION PROGRAMS    09/04/20    06/30/21
# 19  CV  TENANTSHIP AND ROOMING HOUSE SUBSIDY SERVICES    12/31/20    07/30/21
# 20                       CV  RAPID REHOUSING SERVICES    03/22/21    07/30/21
# 26                     CV  EMERGENCY SHELTER SERVICES    07/01/19    06/30/20
# 28                                  OUTREACH SERVICES    07/01/17    06/30/18
# 29                                   GRANTEE SERVICES    07/01/18    06/30/20
# 32                    PORTA POTTY RENTAL AND SERVICES    06/01/17    06/01/21
# 33                                  OUTREACH SERVICES    07/20/18    06/30/20
# 34                                     BASIC SERVICES    07/01/18    06/30/19
# 37                              CV  EMERGENCY SHELTER    07/01/21    06/30/22
#
#    Amount_y           Funding Source_y
# 8      4000  COMMUNITY SUPPORT PROGRAM
# 9     10700                CITY BUDGET
# 13   188809                       PLHA
# 18     6852                       CDBG
# 19   168976                     CDBGCV
# 20    50000                     CDBGCV
# 26     2998                       CDBG
# 28   148996                       CDBG
# 29     1200                       CDBG
# 32   200000                        NaN
# 33   10 000                       CDBG
# 34    20550                       CDBG
# 37    30000                     CDBGCV

# %%
inaccurate_data.drop(labels=)
